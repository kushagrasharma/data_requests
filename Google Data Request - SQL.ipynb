# %% [markdown]
# # Template for all parsing
# ```python
# @require(iter_json_gzip,'ujson','datetime','re','gzip','csv')
# def DUMPNAME(file_in,out_base,compress=1):
#     headers = [] # list of column names
#     out_filename = out_base.format('DUMPNAME')
#
#     # Things to remmember as having "seen"
#     seen = set()
#     running = {}
#     with gzip.open(out_filename,'wt',compress) as out_file:
#         csv_writer = csv.writer(out_file)
#         csv_writer.writerow(headers)
#         for json in iter_json_gzip(file_in):
#             # get some attribute, cast to strting if need be
#             # what you're "remmebering" can also be a tuple (not list, they're not hashable)
#             SOMEFIELD = json.get('SOMEFIELD','')
#             if isinstance(category,str):
#                 category = category.strip()
#                 # double check that it's a valid field, non empty and not seen, etc.
#                 if running.get(json['app_id'],'')!=SOMEFIELD and len(SOMEFIELD)>0:
#                     # SOME CODE HERE
#                     csv_writer.writerow(obs)
#     return out_filename
# ```

# %% [markdown]
# Things to keep in mind:
# 1. `file_in,out_base,compress` are *always* the only parameters to the function
# 2. Function name exactly equals what is passed to `format` on the second line.
# 3. Must use GZIP module with mode 'wt'
# 4. Must use python 3.4+ CSV writer
# 5. All functions only make a single pass through the data.
# 6. Write code that is rigid and assume fields exist and are not null. If they *are missing or null*, then you'll get an exception and have to deal with it then. This is to prevent potential scrape errors from passing unnoticed.
# 7. Use `debug()` It comes in super handy.
# 8. Functions always return the complete filename of the parsed file.

# %% [markdown]
# # Initialize Environment

# %% [markdown]
# ### Compatibility notes

# %% [markdown]
# The following code is only compatible with a python 3.4+ kernel and the notebook must be opened with ipython 3.0+.
#
# The following libraries must be installed to run this code:
#
# ```pip install ujson```

# %%
from pdb import set_trace as debug
from pandas.io.parsers import read_csv
from IPython.parallel import Client,require
from collections import Counter

# %%
import ujson
import datetime
import re
import gzip
import csv

# %% [markdown]
# __`RAW_FILE_DIR`__  The directory that contains google_play__main.json.gz
#
# __`OUT_DIR`__ with the directory of where you want the processed files to go
#
# __`DEBUG`__ whether to print out created CSV files or not
#
# __`COMPRESS_LEVEL`__ gzip compression level. Severely impacts runtime.
#
# __`LINE_LIMIT`__ how many lines to iterate through in the raw file. For debugging.

# %%
DUMP_DATE = '2015_02_26_23_12'
RAW_FILE_DIR = '/home/cgaray/data'
OUT_DIR = '/home/cgaray/data/out'
DEBUG = 1
COMPRESS_LEVEL = 1
LINE_LIMIT = 1000 # -1 means run for the entire file
NO_VERIFY_APP_ID_AND_TIMESTAMP = 1
PARALLEL = 0

# %%
# Don't change these!
RAW_FILE = '{}/google_play__main_sql.json.gz'.format(RAW_FILE_DIR)
OUT_BASE = OUT_DIR+'/{}__google_play__main_sql__'+DUMP_DATE+'.csv.gz'

# %%
def iter_json_gzip(filename,LINE_LIMIT=LINE_LIMIT,NO_VERIFY_APP_ID_AND_TIMESTAMP=NO_VERIFY_APP_ID_AND_TIMESTAMP):
    with gzip.open(filename,'rt') as file_iter:
        for c,line in enumerate(file_iter):
            if c > LINE_LIMIT and LINE_LIMIT>0:
                break
            if isinstance(line,str):
                if len(line)>0:        
                    out = ujson.loads(line)
                    if isinstance(out,dict):
                        if 'app_id' in out and 'timestamp' in out \
                        or NO_VERIFY_APP_ID_AND_TIMESTAMP:
                            yield out

# %% [markdown]
# Print a couple observations to inspect raw data.

# %%
# !zcat "$RAW_FILE" | head -n 100 | tail -n2
# Out:
# {"overallrating":4.5,"dev_website":"http:\/\/greenlifeapps.appspot.com","appname":"Italian Translator\/Dictionary","devname":"GreenLife Apps","permission5":"TITLE: Network communication \n DESCRIPTION: view network state\n DESCRIPTION_FULL: Allows the app to view the state of all networks.\n","appdescription":"Its fun to translate!\nTranslate from\/to Italian and English\nIncludes dictionary\nWord of the day\nSpeak an English sentence and hear Italian translation\n** The app does not stop working after any number of uses. It simply displays a message. This is our full time job and we need to pay bills too.\nNOTE: the app now uses SMS permission so you can translate incoming SMS. The app will not read your SMS for any other purpose, or send SMS to you or anyone.\n** Requires active internet connection\n- Voice recognition for English and Italian\n- Share translation on Facebook\n- Copy to other apps\n- send as SMS or eMail\n- Hear pronunciation\n- Word of the day\n- new feature: translation history\ntraduttore dizionario Italy language\n","permission9":null,"app_news":"1-version 2.2: \n2-Added more languages \n3-Fixed issue with voice, and improved performance. \n4-New UI! \n5-New feature: translation history \n6-Word of the day \n","size":"2.2M","cur_version":"2.3","reportdate":"04-07-2012","related4":"Free English Dictionary","permission2":"TITLE: Your messages \n DESCRIPTION: read SMS or MMS\n DESCRIPTION_FULL: Allows the app to read SMS messages stored on your tablet or SIM card. Malicious apps may read your confidential messages. Allows the app to read SMS messages stored on your phone or SIM card. Malicious apps may read your confidential messages.\n","phone_only":null,"category":"Books & Reference","permission10":null,"dev_email":null,"app_id":"com.greenleaf.android.translator.enit.a","permission4":"TITLE: Phone calls \n DESCRIPTION: read phone state and identity\n DESCRIPTION_FULL: Allows the app to access the phone features of the device. An app with this permission can determine the phone number and serial number of this phone, whether a call is active, the number that call is connected to and the like.\n","NewApp":"","coinstall2":"Italian Translator TransZilla","permission6":null,"dev_other1":"Talking Spanish Translator","installs":"50,000 - 100,000","num_reviews":null,"num_ratings":697,"permission1":"TITLE: Your location \n DESCRIPTION: coarse (network-based) location\n DESCRIPTION_FULL: Access coarse location sources such as the cellular network database to determine an approximate tablet location, where available. Malicious apps may use this to determine approximately where you are. Access coarse location sources such as the cellular network database to determine an approximate phone location, where available. Malicious apps may use this to determine approximately where you are.\n","app_url":"https:\/\/play.google.com\/store\/apps\/details?id=com.greenleaf.android.translator.enit.a&feature=apps_topselling_free","coinstall3":"English<->Italian Dictionary","permission7":null,"updated":"01-29-2012","permission8":null,"android_requirement":"2.3","related2":"Dictionary.com","dev_other3":"Dream Dictionary","related3":"ColorDict Dictionary Wikipedia","price":0.0,"content_rating":"Low Maturity","dev_other4":"Funny Jokes for Kids","dev_other2":"Talking Translator Pro","coinstall4":"LL English Italian Dictionary","permission3":"TITLE: Network communication \n DESCRIPTION: full Internet access\n DESCRIPTION_FULL: Allows the app to create network sockets.\n","related1":"Italian Translator","coinstall1":"Italian Translator Premium"}
# {"overallrating":4.8,"dev_website":"http:\/\/jo.linkedin.com\/pub\/yehya-titi\/4\/9b0\/575","appname":"\u00d8\u00a3\u00d8\u00b0\u00d9\u0083\u00d8\u00a7\u00d8\u00b1 \u00d8\u00a7\u00d9\u0084\u00d8\u00b5\u00d8\u00a8\u00d8\u00a7\u00d8\u00ad \u00d9\u0088 \u00d8\u00a7\u00d9\u0084\u00d9\u0085\u00d8\u00b3\u00d8\u00a7\u00d8\u00a1","devname":"Yehya Titi","permission5":null,"appdescription":"\u00d8\u00af\u00d8\u00b9\u00d8\u00a7\u00d8\u00a1 \u00d9\u0088 \u00d8\u00a3\u00d8\u00b0\u00d9\u0083\u00d8\u00a7\u00d8\u00b1 \u00d8\u00a7\u00d9\u0084\u00d8\u00b5\u00d8\u00a8\u00d8\u00a7\u00d8\u00ad \u00d9\u0088 \u00d8\u00a7\u00d9\u0084\u00d9\u0085\u00d8\u00b3\u00d8\u00a7\u00d8\u00a1\n\u00d8\u00a7\u00d9\u0084\u00d8\u00aa\u00d9\u0086\u00d9\u0082\u00d9\u0084 \u00d8\u00b9\u00d8\u00a8\u00d8\u00b1 \u00d8\u00a7\u00d9\u0084\u00d8\u00b5\u00d9\u0081\u00d8\u00ad\u00d8\u00a7\u00d8\u00aa  \u00d9\u008a\u00d8\u00aa\u00d9\u0085 \u00d8\u00a8\u00d8\u00a7\u00d9\u0084\u00d9\u0084\u00d9\u0085\u00d8\u00b3 \u00d9\u0088 \u00d8\u00a7\u00d9\u0084\u00d8\u00ac\u00d8\u00b1 \u00d8\u00a7\u00d9\u0084\u00d9\u0089 \u00d8\u00a7\u00d9\u0084\u00d9\u008a\u00d9\u0085\u00d9\u008a\u00d9\u0086 \u00d9\u0088 \u00d8\u00a7\u00d9\u0084\u00d9\u008a\u00d8\u00b3\u00d8\u00a7\u00d8\u00b1.\nMorning and Night Athkar and Doa`a in Arabic.\n.Few Pages of dhikr\n","permission9":null,"app_news":"1-\u00d8\u00aa\u00d9\u0085 \u00d8\u00a7\u00d9\u0084\u00d8\u00aa\u00d8\u00b9\u00d8\u00af\u00d9\u008a\u00d9\u0084 \u00d9\u0084\u00d9\u0084\u00d8\u00aa\u00d9\u0088\u00d8\u00a7\u00d9\u0081\u00d9\u0082 \u00d9\u0085\u00d8\u00b9 \u00d8\u00a7\u00d9\u0086\u00d8\u00b8\u00d9\u0085\u00d9\u0087 \u00d8\u00a7\u00d9\u0086\u00d8\u00af\u00d8\u00b1\u00d9\u0088\u00d9\u008a\u00d8\u00af \u00d8\u00a7\u00d9\u0084\u00d8\u00a7\u00d9\u0082\u00d8\u00af\u00d9\u0085 \u00d9\u0085\u00d9\u0086 2.3.1 \n2-Added Compatibility with pre 2.3.1 android \n3-First Edition \n","size":"1.3M","cur_version":"1.3","reportdate":"04-07-2012","related4":"Do3aKomel \u00d8\u00af\u00d8\u00b9\u00d8\u00a7\u00d8\u00a1 \u00d9\u0083\u00d9\u0085\u00d9\u008a\u00d9\u0084","permission2":null,"phone_only":null,"category":"Books & Reference","permission10":null,"dev_email":null,"app_id":"com.tt.athkar","permission4":null,"NewApp":"","coinstall2":"\u00d8\u00aa\u00d8\u00ad\u00d9\u0081\u00d8\u00a9 \u00d8\u00a7\u00d9\u0084\u00d8\u00a7\u00d8\u00b7\u00d9\u0081\u00d8\u00a7\u00d9\u0084 \u00d9\u0088 \u00d8\u00a7\u00d9\u0084\u00d9\u0085\u00d9\u0082\u00d8\u00af\u00d9\u0085\u00d9\u0087 \u00d8\u00a7\u00d9\u0084\u00d8\u00ac\u00d8\u00b2\u00d8\u00b1\u00d9\u008a\u00d9\u0087","permission6":null,"dev_other1":"\u00d8\u00aa\u00d8\u00b9\u00d9\u0084\u00d9\u0085 \u00d8\u00a7\u00d9\u0084\u00d8\u00a7\u00d8\u00ad\u00d8\u00b1\u00d9\u0081 \u00d8\u00a7\u00d9\u0084\u00d8\u00b9\u00d8\u00a8\u00d8\u00b1\u00d9\u008a\u00d8\u00a9","installs":"10,000 - 50,000","num_reviews":null,"num_ratings":73,"permission1":"TITLE: Storage \n DESCRIPTION: modify\/delete USB storage contents modify\/delete SD card contents\n DESCRIPTION_FULL: Allows the app to write to the USB storage. Allows the app to write to the SD card.\n","app_url":"https:\/\/play.google.com\/store\/apps\/details?id=com.tt.athkar&feature=apps_topselling_free","coinstall3":"Thamali - \u00d8\u00af\u00d8\u00b9\u00d8\u00a7\u00d8\u00a1 \u00d8\u00a7\u00d9\u0084\u00d8\u00ab\u00d9\u0085\u00d8\u00a7\u00d9\u0084\u00d9\u008a","permission7":null,"updated":"02-24-2012","permission8":null,"android_requirement":"1.3","related2":"\u00d8\u00af\u00d9\u0084\u00d9\u008a\u00d9\u0084 \u00d9\u0088 \u00d8\u00a3\u00d8\u00b0\u00d9\u0083\u00d8\u00a7\u00d8\u00b1 \u00d8\u00a7\u00d9\u0084\u00d8\u00b5\u00d9\u0084\u00d8\u00a7\u00d8\u00a9","dev_other3":"","related3":"Time 4 Dhikr","price":0.0,"content_rating":"Everyone","dev_other4":"","dev_other2":"Russian Alphabets Flash Cards","coinstall4":"Tafseer Tafheem-ul-Quran Urdu","permission3":null,"related1":"DuAa (Hisn AlMuslim)\u00d8\u00ad\u00d8\u00b5\u00d9\u0086 \u00d8\u00a7\u00d9\u0084\u00d9\u0085\u00d8\u00b3\u00d9\u0084\u00d9\u0085","coinstall1 ...
#
# gzip: stdout: Broken pipe

# %% [markdown]
# # NEWNAME

# %%
def NEWNAME(file_in,out_base,compress=1):
    headers = ['app_id','date','name']
    out_filename = out_base.format('NEWNAME')
    running = {}
    re_app_id=re.compile(r'id=(.*?)\&')
    with gzip.open(out_filename,'wt',compress) as out_file:
        csv_writer = csv.writer(out_file)
        csv_writer.writerow(headers)
        for json in iter_json_gzip(file_in):
            appname = json.get('appname','')
            if isinstance(appname,str) and len(appname)>0:
                appname = appname.strip()
                app_id = re_app_id.findall(json.get('app_url',''))[0]
                if running.get(json['app_id'],'')!=appname and len(appname)>0 and len(app_id)>0:
                    date = datetime.datetime.strptime(json['reportdate'], '%M-%d-%Y').strftime('%Y-%m-%d')
                    running[app_id] = appname
                    obs = (app_id,date,appname)
                    csv_writer.writerow(obs)
    return out_filename

# %%
df_debug = None
if DEBUG:
    df_debug = read_csv(NEWNAME(RAW_FILE,OUT_BASE,COMPRESS_LEVEL),compression='gzip',header=0)
df_debug
# Out:
#                                            app_id        date  \
# 0                   com.dekryptedit.LinuxCommands  2012-01-07
# 1                          com.phonegap.nwtsearch  2012-01-07
# 2                               william.need.fuck  2012-01-16
# 3                            com.shivay.SBGitaHi4  2012-01-07
# 4           com.v1_4.B99AFC3E903FC49482901EC3.com  2012-01-07
# 5                       com.Ababneh.face.language  2012-01-07
# 6                               RedBinary.OhmsLaw  2012-01-07
# 7                         com.deviac.wikipedia.es  2012-01-07
# 8                    com.andromo.dev4168.app38050  2012-01-07
# 9                          com.ebooks.ebookreader  2012-01-07
# 10                     com.moises.diarioana.libro  2012-01-07
# 11                                     com.kvt.EK  2012-01-07
# 12                        com.wProfeciasMayas2012  2012-01-07
# 13                        com.EaseApps.AllahNames  2012-01-07
# 14                        copenhagen.toddlerbible  2012-01-07
# 15                          org.anymals.anymallog  2012-01-07
# 16         com.appflute.quotes.bestfriendsforever  2012-01-07
# 17                             com.apps.webreader  2012-01-07
# 18                             com.over.story.eng  2012-01-07
# 19                        net.yoers.android.bible  2012-01-07
# 20                 vn.shareplus.app.chioianhyeuem  2012-01-07
# 21                       com.gsmdev.worldfactbook  2012-01-07
# 22                         blink.apps.lds_temples  2012-01-07
# 23      com.socialnmobile.dictdata.spanish.i2ee2i  2012-01-07
# 24                 vn.com.itisus.android.sachmang  2012-01-07
# 25                                     sa.android  2012-01-07
# 26                              com.aboYazn.Quran  2012-01-07
# 27                       com.hanajobs.flashlight6  2012-01-07
# 28   com.TheSecretOfSuccess.book.AOTJFDHUIECIRHQY  2012-01-07
# 29      nadsoft.cplusplusprogrammingreferencefree  2012-01-07
# ..                                            ...         ...
# 965                              com.psw.jokeaday  2012-01-07
# 966                           com.ruli.sexsecrets  2012-01-07
# 967                                com.dm2photo23  2012-01-07
# 968                        com.eddie.comic_reader  2012-01-07
# 969                          com.sunny.ragecomics  2012-01-07
# 970                  com.perfection.wlCrystalGirl  2012-01-07
# 971                           com.wtalkingdograps  2012-01-07
# 972                       com.grace.books.hlau.id  2012-01-07
# 973                                com.dm2photo20  2012-01-07
# 974            com.wikilibs.fan_funny_baby_videos  2012-01-07
# 975       com.royaltyfreestockvideofootage.app.hb  2012-01-07
# 976                   jp.candyball.magneticreader  2012-01-07
# 977                              com.htaiken.rino  2012-01-07
# 978                                  lesgeeks.lpg  2012-01-07
# 979                                 com.jcwp.I1ca  2012-01-07
# 980                    com.gdfans.wallpaper.gdwp9  2012-01-07
# 981                        com.gq.thandongdatviet  2012-01-07
# 982                        com.Jaaru.BestJokes500  2012-01-07
# 983                      lms.cartoons.wallpapers5  2012-01-07
# 984                  com.androidskyteam.phdcomics  2012-01-07
# 985                                com.dm3photo43  2012-01-07
# 986                      lms.cartoons.wallpapers3  2012-01-07
# 987                       hdf.cartoons.wallpaper9  2012-01-07
# 988                               com.reddit.rage  2012-01-07
# 989                        com.zeddev.quotesfunny  2012-01-07
# 990                                 com.dm2photo3  2012-01-07
# 991                            com.syariati.manga  2012-01-07
# 992             com.gau.go.launcherex.theme.Kuiba  2012-01-07
# 993     net.robotcomics.android.massiveawesome.e1  2012-01-07
# 994             jp.dcworks.digitalehon.kaguyahime  2012-01-07
#
#                                                   name
# 0                                       Linux Commands
# 1                                           NWT Search
# 2                                 Homegrown Dandelions
# 3                                Shrimad Bhagavad Gita
# 4                                            Como Orar
# 5    ØªØ­ÙÙÙ Ø§ÙØ´Ø®ØµÙØ© : Ù
# ÙØ§Ù
# Ø­ Ø§ÙÙØ¬Ù
# 6                                            Ohm's Law
# 7                                    Wikipedia Espanol
# 8                                   Landscaping Ideas!
# 9                                         Ebook Reader
# 10                       Libro: El Diario de Ana Frank
# 11                                     Phum Dictionary
# 12                                Profecias Mayas 2012
# 13                              99 Allah Names (Islam)
# 14                                       Toddler Bible
# 15                         Identify animals and plants
# 16                         Best Friends Forever Quotes
# 17                                   Fanfiction Reader
# 18                                         Scary Story
# 19                        ALKITAB dengan Kidung Jemaat
# 20                           Chá» Æ¡i... Anh yÃªu Em!
# 21                                      World Factbook
# 22                                         LDS Temples
# 23                          Spanish English Dictionary
# 24                            SÃ¡ch Máº¡ng (vnthuquan)
# 25                         SermonAudio Android Edition
# 26                    Quran - Ø§ÙÙØ±Ø¢Ù Ø§ÙÙØ±ÙÙ
# 27                                                Lamp
# 28                               The Secret Of Success
# 29                      C++ Programming Reference FREE
# ..                                                 ...
# 965                                         Joke A Day
# 966                                        Sex Secrets
# 967                                      DotA Allstars
# 968                                        Comic Books
# 969                                        Rage Comics
# 970                              Sweet Girly Wallpaper
# 971                        Talking dog sings rap songs
# 972                           Dia Hidup Di Antara Kita
# 973                                 Astrological Signs
# 974                                  Funny Baby Videos
# 975                      Best Kept Secrets About Women
# 976                              Magnetic Manga Reader
# 977                     èä¹ã®ã¨ãããªä½é¨è«
# 978                                        Geek Quotes
# 979                           Cartoon Fairy Tale World
# 980                                 Gundam Wallpaper 9
# 981                                 Than Dong Dat Viet
# 982                                     500 Best Jokes
# 983                         Beautiful Anime Wallpapers
# 984                                   PhD Comic Viewer
# 985                        Beautiful Sunrise Wallpaper
# 986                          Beautiful Anime Wallpaper
# 987                              HD Evangelion Gallery
# 988                                        Reddit Rage
# 989                              Funniest Random Quote
# 990                              Fiery Girls Wallpaper
# 991                                   Mangahere Feeder
# 992                         KUIBA Theme GO Launcher EX
# 993                                    Massive Awesome
# 994                      Storytelling book Kaguya-hime
#
# [995 rows x 3 columns]

# %% [markdown]
# # NEWCATEGORY

# %%
df_debug = None
if DEBUG:
    df_debug = read_csv(NEWCATEGORY(RAW_FILE,OUT_BASE,COMPRESS_LEVEL),compression='gzip',header=0)
df_debug

# %% [markdown]
# # NEWVERSION

# %%
df_debug = None
if DEBUG:
    df_debug = read_csv(NEWVERSION(RAW_FILE,OUT_BASE,COMPRESS_LEVEL),compression='gzip',header=0)
df_debug

# %% [markdown]
# # NEWINSTALL

# %%
df_debug = None
if DEBUG:
    df_debug = read_csv(NEWINSTALL(RAW_FILE,OUT_BASE,COMPRESS_LEVEL),compression='gzip',header=0)
df_debug

# %% [markdown]
# # NEWPRICE

# %%
df_debug = None
if DEBUG:
    df_debug = read_csv(NEWPRICE(RAW_FILE,OUT_BASE,COMPRESS_LEVEL),compression='gzip',header=0)
df_debug

# %% [markdown]
# # Run them all!

# %%
programs = """
NEWNAME
NEWINSTALL
NEWVERSION
NEWCATEGORY
NEWPRICE
""".split()

def run_function(f,RAW_FILE=RAW_FILE,OUT_BASE=OUT_BASE,COMPRESS_LEVEL=COMPRESS_LEVEL):
    return f(RAW_FILE ,OUT_BASE,COMPRESS_LEVEL)

for file in map(run_function,[globals()[x] for x in programs]):
    print(file)

# %%
print("DONE")
# Out:
# DONE
