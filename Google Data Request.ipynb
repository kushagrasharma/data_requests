# %% [markdown]
# # Initialize Environment

# %% [markdown]
# ### Compatibility notes

# %% [markdown]
# The following code is only compatible with a python 3.4 kernel and the notebook must be opened with ipython 3.0+.

# %%
from pdb import set_trace as debug
from pandas.io.parsers import read_csv
from IPython.parallel import Client,require
from collections import Counter

# %%
import ujson
import datetime
import re
import gzip
import csv

# %%
#--> RAW_FILE_DIR with the directory that contains google_play__main.json.gz
#--> OUT_DIR with the directory of where you want the processed files to go
#--> DEBUG whether to print out created CSV files or not
#--> COMPRESS_LEVEL gzip compression level. warning: severely impacts runtime.
#--> LINE_LIMIT how many lines to iterate through in the raw file. For debugging.
DUMP_DATE = '2015_02_26_23_12'
RAW_FILE_DIR = '/data'
OUT_DIR = '/raid/out'
DEBUG = 1
COMPRESS_LEVEL = 9
LINE_LIMIT = 1000
PARALLEL = 1
PIGZ = 1
OBS_SKIP = 100
OBS_PRINT = 5

# %%
# Don't change these!
RAW_FILE_NEWDATA = '{}/googletail.json.gz'.format(RAW_FILE_DIR)
RAW_FILE = '{}/google_play__main.json.gz'.format(RAW_FILE_DIR)
OUT_BASE = OUT_DIR+'/{}__google_play__main__'+DUMP_DATE+'.csv.gz'

# %%
if PIGZ:
    @require(gzip)
    def iter_json_gzip(filename,LINE_LIMIT=LINE_LIMIT):
        return gzip.iter_json_gzip(filename,LINE_LIMIT=LINE_LIMIT)    
else:
    @require(gzip,ujson)
    def iter_json_gzip(filename,LINE_LIMIT=LINE_LIMIT):
        with gzip.open(filename,'rt') as file_iter:
            for c,line in enumerate(file_iter):
                if c > LINE_LIMIT and LINE_LIMIT>0:
                    break
                if isinstance(line,str):
                    if len(line)>0:        
                        out = ujson.loads(line)
                        if isinstance(out,dict):
                            if 'app_id' in out and 'timestamp' in out:
                                yield out

# %% [markdown]
# # Print Sample Observations

# %%
try:
    from sh import zcat,head,tail
    print(tail(head(zcat(RAW_FILE_NEWDATA, _piped =True),
                    "-n{}".format(OBS_SKIP)
                   ),"-n{}".format(OBS_PRINT)))
except:
    pass
# Out:
# {"app_id":"com.iceberg.KuShow","ratings":[8,4,6,2,2],"updated":"February 25, 2010","installs":"1,000 - 5,000","developer_other":["com.iPhand.SexQuotes","com.iPhand.LifeQuotes","com.iPhand.LoveQuotes","com.iPhand.BizQuotes","com.GOQO.ChineseBook","com.mingfai","com.iPhand.MotivQuotes","com.iPhand.Quotes","com.iceberg.Jokes","com.mingfaiEn","com.poqop.estate","com.poqop.dolcevita","com.poqop.shangmeijia","com.poqop.DoubanGroup","com.poqop.Beauty100","com.iPhand.FirstAid"],"requires":"1.5 and up","size":"3.1M","version":"1.0.1","category":"LIFESTYLE","developer_name":"skyblue.huang","screenshots":0,"timestamp":1424945337,"description":"\u300a\u9177\u79c0\u300b\u53ef\u4ee5\u8ba9\u4f60\u968f\u5fc3\u6240\u6b32\u5730\u521b\u5efa\u4f60\u559c\u6b22\u7684\u5f62\u8c61\uff0c\u53ef\u4ee5\u4fdd\u6301\u6210\u56fe\u7247\u6587\u4ef6\u505a\u5404\u79cd\u7f51\u7edc\u793e\u533a\u7684\u5f62\u8c61\uff0c\u8fd8\u53ef\u4ee5\u8bbe\u7f6e\u4e3a\u6765\u7535\u79c0\uff0cSo Cool!\u6b64\u7248\u672c\u4e3a\u300a\u9177\u5934\u50cf\u300b\u59ca\u59b9\u7248\uff01\u5982\u559c\u6b22\u5934\u50cf\u5f62\u8c61\u8bf7\u4e0b\u8f7d\u300a\u9177\u5934\u50cf\u300b\uff01","price":0,"badges":[],"recent_changes":[],"developer_id":"skyblue.huang","content":"High Maturity","app_name":"\u9177\u79c0","SCRAPER_VERSION":3,"current_rating":3.6363637447,"similar_apps":["com.tjcow.android.ixiureject"]}
# {"app_id":"com.iceberg.Jokes","ratings":[104,41,16,10,20],"updated":"February 10, 2010","installs":"50,000 - 100,000","developer_other":["com.iPhand.SexQuotes","com.iPhand.LifeQuotes","com.iPhand.LoveQuotes","com.iPhand.BizQuotes","com.GOQO.ChineseBook","com.mingfai","com.iPhand.MotivQuotes","com.iPhand.Quotes","com.mingfaiEn","com.poqop.estate","com.poqop.dolcevita","com.poqop.shangmeijia","com.poqop.DoubanGroup","com.poqop.Beauty100","com.iPhand.FirstAid","com.iceberg.KuAvator"],"requires":"1.5 and up","size":"1.7M","version":"1.0.0","category":"ENTERTAINMENT","developer_name":"skyblue.huang","screenshots":0,"timestamp":1424945337,"description":"\u7b11\u8bdd\u5927\u5168\u2014\u2014\u91cc\u9762\u6536\u96c6\u4e865000\u591a\u5404\u79cd\u7c7b\u578b\u7684\u7b11\u6599\uff0c\u8ba9\u4f60\u5168\u5929\u4e50\u5475\u5475!\u4f60\u8fd8\u53ef\u4ee5\u628a\u7b11\u8bdd\u901a\u8fc7\u77ed\u4fe1\u3001\u90ae\u7bb1\u53d1\u7ed9\u4f60\u7684\u540c\u5b66\u3001\u540c\u4e8b\u3001\u597d\u53cb\u5206\u4eab\u5206\u4eab\u54e6!","price":0,"badges":[],"recent_changes":[],"developer_id":"skyblue.huang","content":"High Maturity","app_name":"\u7b11\u8bdd\u5927\u5168","SCRAPER_VERSION":3,"current_rating":4.0418848991,"similar_apps":["org.nice.joke.ymxhdq","com.miraclesapp.laughdieme","book.revisiongroup.brockengag","com.ypex.jokes","com.matthewgao.ijokes","joke.content","com.jawua.joke.freea","com.coldworks.coldjoke","com.omesoft.bestjokes","com.feibo.joke","com.onlyshake.coolphing","com.emusic.joke","com.moregoodmobile.joke","com.tiantian.xiaohua","com.boxsoaroathyx.clearglass","com.softuthupsigrusoogef.unusualcontrol"]}
# {"app_id":"com.iceberg.KuAvator","ratings":[7,5,8,0,8],"updated":"February 27, 2010","installs":"5,000 - 10,000","developer_other":["com.iPhand.SexQuotes","com.iPhand.LifeQuotes","com.iPhand.LoveQuotes","com.iPhand.BizQuotes","com.GOQO.ChineseBook","com.mingfai","com.iPhand.MotivQuotes","com.iPhand.Quotes","com.iceberg.Jokes","com.mingfaiEn","com.poqop.estate","com.poqop.dolcevita","com.poqop.shangmeijia","com.poqop.DoubanGroup","com.poqop.Beauty100","com.iPhand.FirstAid"],"requires":"1.5 and up","size":"1.5M","version":"1.0.0","category":"LIFESTYLE","developer_name":"skyblue.huang","screenshots":0,"timestamp":1424945337,"description":"\u300a\u9177\u5934\u50cf\u300b\u53ef\u4ee5\u8ba9\u4f60\u968f\u5fc3\u6240\u6b32\u5730\u521b\u5efa\u4f60\u559c\u6b22\u7684\u5934\u50cf\uff0c\u53ef\u4ee5\u4fdd\u6301\u6210\u56fe\u7247\u6587\u4ef6\u505a\u5404\u79cd\u7f51\u7edc\u793e\u533a\u7684\u5934\u50cf\uff0c\u8fd8\u53ef\u4ee5\u8bbe\u7f6e\u4e3a\u8054\u7cfb\u4eba\u5934\u50cf\uff0cSo Cool!\u6b64\u7248\u672c\u4e3a\u300a\u9177\u79c0\u300b\u59ca\u59b9\u7248\uff01\u5982\u559c\u6b22\u5168\u8eab\u5f62\u8c61\u8bf7\u4e0b\u8f7d\u300a\u9177\u79c0\u300b\uff01","price":0,"badges":[],"recent_changes":[],"developer_id":"skyblue.huang","content":"High Maturity","app_name":"\u9177\u5934\u50cf","SCRAPER_VERSION":3,"current_rating":3.1071429253,"similar_apps":["com.Cute.Photo.Frames.Effects","com.Photo.Collage.Editor.Teens"]}
# {"app_id":"com.icebears","ratings":[36,5,4,1,9],"updated":"October 28, 2013","installs":"5,000 - 10,000","developer_other":["com.tnsportsradio","com.wkvl","com.redemptionchurch","com.knoxapps.kpc","com.shopfarragut"],"requires":"2.1 and up","size":"17M","version":"1.3","category":"SPORTS","developer_name":"Knox Apps","screenshots":5,"timestamp":1424945337,"description":"The Knoxville Ice Bears are proud to present their mobile app! Get in on all the fast pace hockey action with their feature packed app.This app has so much functionality it's crazy!Features:- Play 2 Fun Ice Bears Minigames- Chuck a Puck- Zamboni Pro- Participate in In-Game Promotions- Guess the Attendance- Polls- Report Problems at the Game- Box Scores- Stats- Standings- Player Bios- Event Schedules- News Articles- View Photos- Take Fan Photos and Share Them- Take Goofy Fun Photos and Doctor them with Ice Bears Props- Listen to the games LIVE on TN Sports Radio- Browse our You Tube Channel- Download fun WallPapers- Activate 8 different Noisemakers- Buy Tickets- Share on Facebook- Share on Twitter- And MUCH MUCH MORE....Check it out today!","price":0,"badges":[],"recent_changes":["-Updated to fix a bug that caused the app to crash as soon as it was launched.","-Updated app for 2013-2014 hockey season.","-Fixed issue with back button."],"developer_id":"Knox+Apps","content":"Everyone","app_name":"The Knoxville Ice Bears","SCRAPER_VERSION":3,"current_rating":4.0545454025,"similar_apps":["hockey.rus","com.usahockey.android.usahockey","com.nhl.gc1314.phi","com.cubencioapps.dinmos","com.cubencioapps.csk","hr.apps.n147067085","ru.scumgazeta.happy.nighthockeyleague","com.espn.espnfantasyhockey","com.appmakr.app134106","lokomotiv.android","com.mobile.shnarped","ru.sports.khl_dinamo_msk","com.mantu.ihm13","bitterradish.wp.gen.hockey","com.tribuna.by.zhlobin","hockeyradio.activities"]}
# {"app_id":"com.iceberg.axavr","ratings":[1,1,0,0,0],"updated":"September 5, 2014","installs":"10 - 50","developer_other":[],"requires":"2.3 and up","size":"155M","version":"6","category":"BUSINESS","developer_name":"Iceberg","screenshots":12,"timestamp":1424945337,"description":"D\u00e9couvrez l\u2019immeuble enti\u00e8rement r\u00e9nov\u00e9 du 24 DROUOT avec cette visite virtuelle en 3D temps r\u00e9el. Vous passerez d\u2019un \u00e9tage \u00e0 un autre et d\u00e9couvrirez le hall d\u2019accueil, l\u2019espace caf\u00e9t\u00e9ria, un \u00e9tage courant open-space et cloisonn\u00e9 ainsi que la mezzanine en haut de l\u2019immeuble.L\u2019agence de communication ICEBERG a con\u00e7u cette application pour pr\u00e9senter le nouveau programme tertiaire situ\u00e9 en plein c\u0153ur de Paris.Bonne visite !","price":0,"badges":[],"recent_changes":[],"developer_id":"Iceberg","content":"Everyone","app_name":"24 Drouot","SCRAPER_VERSION":3,"current_rating":4.5,"similar_apps":["fr.dvmobile.Think","air.UpWest","com.iceberg.NewTime"]}

# %% [markdown]
# #Initialize Parallel Processing

# %%
# Configured for: equity
if PARALLEL:
    ipython_parallel = Client()
    print("{} active computing engines".format(len(ipython_parallel.ids)))

    lbv = ipython_parallel.load_balanced_view()

    map = lambda f,itertable:lbv.map(f,itertable,\
    block =False,\
    ordered =False)

    @require('socket')
    def host(dummy):
        return socket.gethostname()

    nodes = list(lbv.map(host,ipython_parallel.ids))
    nodes = [int(x.split('equity')[1].split(".")[0]) for x in nodes]
    nodes = nodes

    print(sorted(list(Counter(nodes).items())))
# Out:
# 57 active computing engines
# [(2, 3), (5, 6), (6, 6), (8, 6), (10, 6), (11, 6), (12, 4), (17, 20)]

# %% [markdown]
# # DAILYRATINGS

# %%
@require(iter_json_gzip,gzip,datetime,re,csv)
def DAILYRATINGS(file_in,out_base,compress=1):
    headers = ['app_id','date','rating5','rating4','rating3','rating2','rating1']
    out_filename = out_base.format('DAILYRATINGS')
    unique_daily_rating = set()
    with gzip.open(out_filename,'wt',9) as out_file:
        csv_writer = csv.writer(out_file)
        csv_writer.writerow(headers)
        for json in iter_json_gzip(file_in):
            day = datetime.datetime.fromtimestamp(int(json['timestamp']))\
                                .strftime('%Y-%m-%d')
            rating = json.get('ratings',None)
            if rating:
                obs = (json['app_id'],day,tuple(rating),)
                if hash(obs) not in unique_daily_rating:
                    unique_daily_rating.add(hash(obs))
                    csv_writer.writerow([json['app_id'],day]+rating)
    return out_filename

# %%
df_debug = None
if DEBUG:
    df_debug = read_csv(DAILYRATINGS(RAW_FILE,OUT_BASE,COMPRESS_LEVEL),compression='gzip',header=0)
df_debug
# Out:
#                                                  app_id        date  rating5  \
# 0                                com.touchtype.swiftkey  2013-07-17   162422
# 1                   com.gameloft.android.ANMP.GloftDMHM  2013-07-17   291722
# 2                           com.ibm.events.android.usga  2013-07-17      420
# 3                                      com.dama.camera2  2013-07-17      152
# 4                           com.disney.scribblefree_goo  2013-07-17     1209
# 5                                 com.gau.go.launcherex  2013-07-17  1011807
# 6                              com.teslacoilsw.launcher  2013-07-17    59107
# 7                          com.levelup.beautifulwidgets  2013-07-17    53501
# 8           com.socialnmobile.dictdata.chinese.stardict  2013-07-17      481
# 9                               com.mdb.android.xiangqi  2013-07-17       40
# 10                                   io.avocado.android  2013-07-17     2067
# 11                                        flipboard.app  2013-07-17   153386
# 12                      com.mobincube.android.app_20866  2013-07-17        1
# 13                                         com.at.proxi  2013-07-17        4
# 14                      shopcoffeetable.com.coffeetable  2013-07-17        2
# 15                          com.mini.flowers.angryfatty  2013-07-17      323
# 16                            com.and.Wuthering_Heights  2013-07-17        0
# 17                                     com.loltv.layout  2013-07-17       15
# 18                         com.stopnplayapps.angryshark  2013-07-17        1
# 19                           say.hello.worldsnookernews  2013-07-17      237
# 20                                com.wolterskluwer.lsq  2013-07-17        0
# 21           com.themesfordroid.hunterthemegolauncherex  2013-07-17       11
# 22                          com.boxyz.androidteam.tsubo  2013-07-17       14
# 23                             twig.nguyen.d2_runewords  2013-07-17       77
# 24                                           com.Netter  2013-07-17       35
# 25                                 com.gunvald.bigpenis  2013-07-17       37
# 26                                     com.prapps.tokay  2013-07-17        6
# 27                 com.quickmare.typingkeyboard.neurope  2013-07-17        0
# 28                      Technicaljar.BluetoothAppBinder  2013-07-17        4
# 29               com.jiubang.goscreenlock.theme.lighter  2013-07-17     1021
# ...                                                 ...         ...      ...
# 971                  com.miresoftware.sexyamateurs2free  2013-07-17       58
# 972             Alfasoft.Widgets.PsychedelicAnalogClock  2013-07-17      131
# 973                            com.Kaneosmare.BoeingC17  2013-07-17        0
# 974                                     adit.weather.ta  2013-07-17        7
# 975             com.andbling.wallpaper.live.names.ernie  2013-07-17        0
# 976              com.coreapps.android.followme.fetc2013  2013-07-17        0
# 977                             com.crossfield.frowline  2013-07-17        4
# 978                com.mspinc.sexygirllivewallpaperLite  2013-07-17        6
# 979                    org.guesswork.nightstand.digital  2013-07-17       28
# 980                                de.wgsoft.scanmaster  2013-07-17       75
# 981                    com.appsshoppe.hairlosstreatment  2013-07-17        0
# 982                                      com.mobizel.ra  2013-07-17        2
# 983                          com.buildingfive.pgnhelper  2013-07-17        1
# 984                                    com.oxxo.tiendas  2013-07-17       34
# 985                                    org.prospekt0048  2013-07-17        0
# 986                               com.andrios.bodycards  2013-07-17       45
# 987                                    com.sportsoo.web  2013-07-17        0
# 988                                    org.prospekt0049  2013-07-17        0
# 989                                 za.co.McCarthy.Audi  2013-07-17        1
# 990                    com.enlight.santaschristmaselves  2013-07-17        3
# 991   com.gau.go.launcherex.theme.gowidget.taskmanag...  2013-07-17      154
# 992                                 com.gw2.legendaries  2013-07-17        6
# 993                              com.dontpanic.lpp.cyan  2013-07-17       41
# 994                 br.com.mobileninjas.pensamentododia  2013-07-17       70
# 995                         com.custom.lwp.BridgeLights  2013-07-17        0
# 996      com.uefa.football.champiansleague.europe.messi  2013-07-17       11
# 997                     com.gcsresearch.burkebiketrails  2013-07-17        2
# 998                                      com.Wallpaper2  2013-07-17       16
# 999                              pt.tmn.android.vamosla  2013-07-17        6
# 1000                      com.mymobilebookshelf.dracula  2013-07-17        0
#
#       rating4  rating3  rating2  rating1
# 0       33001     6799     2879     4429
# 1       45460    13064     4439    18714
# 2          97       65       46       87
# 3          49       23       10        9
# 4         219      178      139      713
# 5      233232    79681    22214    44348
# 6       11001     2450      764     1113
# 7       15796     5546     3248     6737
# 8         253      129       36       58
# 9          20        8        5       23
# 10        955      536      227      322
# 11      50762    10884     2876     5652
# 12          0        0        0        0
# 13          0        0        0        1
# 14          0        3        0       10
# 15         79       58       19       81
# 16          0        0        0        0
# 17          7        1        0        0
# 18          0        0        0        0
# 19        179      242       86      104
# 20          0        0        0        0
# 21          5        2        0        4
# 22         17        6        3        4
# 23         12        6        2       10
# 24         11       14        7        9
# 25          4        2        0        6
# 26          2        0        0        0
# 27          0        0        0        0
# 28          2        1        1        1
# 29        239      102       41       84
# ...       ...      ...      ...      ...
# 971        12       12        5       16
# 972        33       29       15       33
# 973         0        0        0        0
# 974         0        0        0        0
# 975         0        0        0        0
# 976         0        0        0        3
# 977         0        0        0        0
# 978         1        0        0        1
# 979        12        4        1        3
# 980         7       10        6       21
# 981         1        0        0        0
# 982         2        0        0        3
# 983         0        0        1        1
# 984        11        8        6       23
# 985         0        0        0        0
# 986        18        2        4        8
# 987         0        0        0        0
# 988         0        0        0        0
# 989         0        0        0        0
# 990         0        0        0        1
# 991        23       16        4       14
# 992         5        0        0        1
# 993         7        1        1        1
# 994        16       16        3       11
# 995         0        0        0        1
# 996         2        0        1        0
# 997         0        0        0        1
# 998         6        0        0        2
# 999         0        0        0        3
# 1000        0        0        0        0
#
# [1001 rows x 7 columns]

# %% [markdown]
# # WEEKLYRATINGS

# %%
@require(iter_json_gzip,gzip,datetime,re,csv)
def WEEKLYRATINGS(file_in,out_base,compress=1):
    headers = ['app_id','year','week','rating5','rating4','rating3','rating2','rating1']
    out_filename = out_base.format('WEEKLYRATINGS')
    unique_daily_rating = set()
    with gzip.open(out_filename,'wt',9) as out_file:
        csv_writer = csv.writer(out_file)
        csv_writer.writerow(headers)
        for json in iter_json_gzip(file_in):
            year,week = datetime.datetime.fromtimestamp(int(json['timestamp']))                                .isocalendar()[:2]
            rating = json.get('ratings',None)
            if rating:
                obs = (json['app_id'],year,week)
                if hash(obs) not in unique_daily_rating:
                    unique_daily_rating.add(hash(obs))
                    csv_writer.writerow([json['app_id'],year,week]+rating)
    return out_filename

# %%
df_debug = None
if DEBUG:
    df_debug = read_csv(WEEKLYRATINGS(RAW_FILE,OUT_BASE,COMPRESS_LEVEL),compression='gzip',header=0)
df_debug
# Out:
#                                                  app_id  year  week  rating5  \
# 0                                com.touchtype.swiftkey  2013    29   162422
# 1                   com.gameloft.android.ANMP.GloftDMHM  2013    29   291722
# 2                           com.ibm.events.android.usga  2013    29      420
# 3                                      com.dama.camera2  2013    29      152
# 4                           com.disney.scribblefree_goo  2013    29     1209
# 5                                 com.gau.go.launcherex  2013    29  1011807
# 6                              com.teslacoilsw.launcher  2013    29    59107
# 7                          com.levelup.beautifulwidgets  2013    29    53501
# 8           com.socialnmobile.dictdata.chinese.stardict  2013    29      481
# 9                               com.mdb.android.xiangqi  2013    29       40
# 10                                   io.avocado.android  2013    29     2067
# 11                                        flipboard.app  2013    29   153386
# 12                      com.mobincube.android.app_20866  2013    29        1
# 13                                         com.at.proxi  2013    29        4
# 14                      shopcoffeetable.com.coffeetable  2013    29        2
# 15                          com.mini.flowers.angryfatty  2013    29      323
# 16                            com.and.Wuthering_Heights  2013    29        0
# 17                                     com.loltv.layout  2013    29       15
# 18                         com.stopnplayapps.angryshark  2013    29        1
# 19                           say.hello.worldsnookernews  2013    29      237
# 20                                com.wolterskluwer.lsq  2013    29        0
# 21           com.themesfordroid.hunterthemegolauncherex  2013    29       11
# 22                          com.boxyz.androidteam.tsubo  2013    29       14
# 23                             twig.nguyen.d2_runewords  2013    29       77
# 24                                           com.Netter  2013    29       35
# 25                                 com.gunvald.bigpenis  2013    29       37
# 26                                     com.prapps.tokay  2013    29        6
# 27                 com.quickmare.typingkeyboard.neurope  2013    29        0
# 28                      Technicaljar.BluetoothAppBinder  2013    29        4
# 29               com.jiubang.goscreenlock.theme.lighter  2013    29     1021
# ...                                                 ...   ...   ...      ...
# 971                  com.miresoftware.sexyamateurs2free  2013    29       58
# 972             Alfasoft.Widgets.PsychedelicAnalogClock  2013    29      131
# 973                            com.Kaneosmare.BoeingC17  2013    29        0
# 974                                     adit.weather.ta  2013    29        7
# 975             com.andbling.wallpaper.live.names.ernie  2013    29        0
# 976              com.coreapps.android.followme.fetc2013  2013    29        0
# 977                             com.crossfield.frowline  2013    29        4
# 978                com.mspinc.sexygirllivewallpaperLite  2013    29        6
# 979                    org.guesswork.nightstand.digital  2013    29       28
# 980                                de.wgsoft.scanmaster  2013    29       75
# 981                    com.appsshoppe.hairlosstreatment  2013    29        0
# 982                                      com.mobizel.ra  2013    29        2
# 983                          com.buildingfive.pgnhelper  2013    29        1
# 984                                    com.oxxo.tiendas  2013    29       34
# 985                                    org.prospekt0048  2013    29        0
# 986                               com.andrios.bodycards  2013    29       45
# 987                                    com.sportsoo.web  2013    29        0
# 988                                    org.prospekt0049  2013    29        0
# 989                                 za.co.McCarthy.Audi  2013    29        1
# 990                    com.enlight.santaschristmaselves  2013    29        3
# 991   com.gau.go.launcherex.theme.gowidget.taskmanag...  2013    29      154
# 992                                 com.gw2.legendaries  2013    29        6
# 993                              com.dontpanic.lpp.cyan  2013    29       41
# 994                 br.com.mobileninjas.pensamentododia  2013    29       70
# 995                         com.custom.lwp.BridgeLights  2013    29        0
# 996      com.uefa.football.champiansleague.europe.messi  2013    29       11
# 997                     com.gcsresearch.burkebiketrails  2013    29        2
# 998                                      com.Wallpaper2  2013    29       16
# 999                              pt.tmn.android.vamosla  2013    29        6
# 1000                      com.mymobilebookshelf.dracula  2013    29        0
#
#       rating4  rating3  rating2  rating1
# 0       33001     6799     2879     4429
# 1       45460    13064     4439    18714
# 2          97       65       46       87
# 3          49       23       10        9
# 4         219      178      139      713
# 5      233232    79681    22214    44348
# 6       11001     2450      764     1113
# 7       15796     5546     3248     6737
# 8         253      129       36       58
# 9          20        8        5       23
# 10        955      536      227      322
# 11      50762    10884     2876     5652
# 12          0        0        0        0
# 13          0        0        0        1
# 14          0        3        0       10
# 15         79       58       19       81
# 16          0        0        0        0
# 17          7        1        0        0
# 18          0        0        0        0
# 19        179      242       86      104
# 20          0        0        0        0
# 21          5        2        0        4
# 22         17        6        3        4
# 23         12        6        2       10
# 24         11       14        7        9
# 25          4        2        0        6
# 26          2        0        0        0
# 27          0        0        0        0
# 28          2        1        1        1
# 29        239      102       41       84
# ...       ...      ...      ...      ...
# 971        12       12        5       16
# 972        33       29       15       33
# 973         0        0        0        0
# 974         0        0        0        0
# 975         0        0        0        0
# 976         0        0        0        3
# 977         0        0        0        0
# 978         1        0        0        1
# 979        12        4        1        3
# 980         7       10        6       21
# 981         1        0        0        0
# 982         2        0        0        3
# 983         0        0        1        1
# 984        11        8        6       23
# 985         0        0        0        0
# 986        18        2        4        8
# 987         0        0        0        0
# 988         0        0        0        0
# 989         0        0        0        0
# 990         0        0        0        1
# 991        23       16        4       14
# 992         5        0        0        1
# 993         7        1        1        1
# 994        16       16        3       11
# 995         0        0        0        1
# 996         2        0        1        0
# 997         0        0        0        1
# 998         6        0        0        2
# 999         0        0        0        3
# 1000        0        0        0        0
#
# [1001 rows x 8 columns]

# %% [markdown]
# # MONTHLYRATINGS

# %%
@require(iter_json_gzip,gzip,datetime,re,csv)
def MONTHLYRATINGS(file_in,out_base,compress=1):
    headers = ['app_id','year','month','rating5','rating4','rating3','rating2','rating1']
    out_filename = out_base.format('MONTHLYRATINGS')
    unique_daily_rating = set()
    with gzip.open(out_filename,'wt',9) as out_file:
        csv_writer = csv.writer(out_file)
        csv_writer.writerow(headers)
        for json in iter_json_gzip(file_in):
            dateobj = datetime.datetime.fromtimestamp(int(json['timestamp']))
            year,month = dateobj.year,dateobj.month
            rating = json.get('ratings',None)
            if rating:
                obs = (json['app_id'],year,month)
                if hash(obs) not in unique_daily_rating:
                    unique_daily_rating.add(hash(obs))
                    csv_writer.writerow([json['app_id'],year,month]+rating)
    return out_filename

# %%
df_debug = None
if DEBUG:
    df_debug = read_csv(MONTHLYRATINGS(RAW_FILE,OUT_BASE,COMPRESS_LEVEL),compression='gzip',header=0)
df_debug
# Out:
#                                                  app_id  year  month  rating5  \
# 0                                com.touchtype.swiftkey  2013      7   162422
# 1                   com.gameloft.android.ANMP.GloftDMHM  2013      7   291722
# 2                           com.ibm.events.android.usga  2013      7      420
# 3                                      com.dama.camera2  2013      7      152
# 4                           com.disney.scribblefree_goo  2013      7     1209
# 5                                 com.gau.go.launcherex  2013      7  1011807
# 6                              com.teslacoilsw.launcher  2013      7    59107
# 7                          com.levelup.beautifulwidgets  2013      7    53501
# 8           com.socialnmobile.dictdata.chinese.stardict  2013      7      481
# 9                               com.mdb.android.xiangqi  2013      7       40
# 10                                   io.avocado.android  2013      7     2067
# 11                                        flipboard.app  2013      7   153386
# 12                      com.mobincube.android.app_20866  2013      7        1
# 13                                         com.at.proxi  2013      7        4
# 14                      shopcoffeetable.com.coffeetable  2013      7        2
# 15                          com.mini.flowers.angryfatty  2013      7      323
# 16                            com.and.Wuthering_Heights  2013      7        0
# 17                                     com.loltv.layout  2013      7       15
# 18                         com.stopnplayapps.angryshark  2013      7        1
# 19                           say.hello.worldsnookernews  2013      7      237
# 20                                com.wolterskluwer.lsq  2013      7        0
# 21           com.themesfordroid.hunterthemegolauncherex  2013      7       11
# 22                          com.boxyz.androidteam.tsubo  2013      7       14
# 23                             twig.nguyen.d2_runewords  2013      7       77
# 24                                           com.Netter  2013      7       35
# 25                                 com.gunvald.bigpenis  2013      7       37
# 26                                     com.prapps.tokay  2013      7        6
# 27                 com.quickmare.typingkeyboard.neurope  2013      7        0
# 28                      Technicaljar.BluetoothAppBinder  2013      7        4
# 29               com.jiubang.goscreenlock.theme.lighter  2013      7     1021
# ...                                                 ...   ...    ...      ...
# 971                  com.miresoftware.sexyamateurs2free  2013      7       58
# 972             Alfasoft.Widgets.PsychedelicAnalogClock  2013      7      131
# 973                            com.Kaneosmare.BoeingC17  2013      7        0
# 974                                     adit.weather.ta  2013      7        7
# 975             com.andbling.wallpaper.live.names.ernie  2013      7        0
# 976              com.coreapps.android.followme.fetc2013  2013      7        0
# 977                             com.crossfield.frowline  2013      7        4
# 978                com.mspinc.sexygirllivewallpaperLite  2013      7        6
# 979                    org.guesswork.nightstand.digital  2013      7       28
# 980                                de.wgsoft.scanmaster  2013      7       75
# 981                    com.appsshoppe.hairlosstreatment  2013      7        0
# 982                                      com.mobizel.ra  2013      7        2
# 983                          com.buildingfive.pgnhelper  2013      7        1
# 984                                    com.oxxo.tiendas  2013      7       34
# 985                                    org.prospekt0048  2013      7        0
# 986                               com.andrios.bodycards  2013      7       45
# 987                                    com.sportsoo.web  2013      7        0
# 988                                    org.prospekt0049  2013      7        0
# 989                                 za.co.McCarthy.Audi  2013      7        1
# 990                    com.enlight.santaschristmaselves  2013      7        3
# 991   com.gau.go.launcherex.theme.gowidget.taskmanag...  2013      7      154
# 992                                 com.gw2.legendaries  2013      7        6
# 993                              com.dontpanic.lpp.cyan  2013      7       41
# 994                 br.com.mobileninjas.pensamentododia  2013      7       70
# 995                         com.custom.lwp.BridgeLights  2013      7        0
# 996      com.uefa.football.champiansleague.europe.messi  2013      7       11
# 997                     com.gcsresearch.burkebiketrails  2013      7        2
# 998                                      com.Wallpaper2  2013      7       16
# 999                              pt.tmn.android.vamosla  2013      7        6
# 1000                      com.mymobilebookshelf.dracula  2013      7        0
#
#       rating4  rating3  rating2  rating1
# 0       33001     6799     2879     4429
# 1       45460    13064     4439    18714
# 2          97       65       46       87
# 3          49       23       10        9
# 4         219      178      139      713
# 5      233232    79681    22214    44348
# 6       11001     2450      764     1113
# 7       15796     5546     3248     6737
# 8         253      129       36       58
# 9          20        8        5       23
# 10        955      536      227      322
# 11      50762    10884     2876     5652
# 12          0        0        0        0
# 13          0        0        0        1
# 14          0        3        0       10
# 15         79       58       19       81
# 16          0        0        0        0
# 17          7        1        0        0
# 18          0        0        0        0
# 19        179      242       86      104
# 20          0        0        0        0
# 21          5        2        0        4
# 22         17        6        3        4
# 23         12        6        2       10
# 24         11       14        7        9
# 25          4        2        0        6
# 26          2        0        0        0
# 27          0        0        0        0
# 28          2        1        1        1
# 29        239      102       41       84
# ...       ...      ...      ...      ...
# 971        12       12        5       16
# 972        33       29       15       33
# 973         0        0        0        0
# 974         0        0        0        0
# 975         0        0        0        0
# 976         0        0        0        3
# 977         0        0        0        0
# 978         1        0        0        1
# 979        12        4        1        3
# 980         7       10        6       21
# 981         1        0        0        0
# 982         2        0        0        3
# 983         0        0        1        1
# 984        11        8        6       23
# 985         0        0        0        0
# 986        18        2        4        8
# 987         0        0        0        0
# 988         0        0        0        0
# 989         0        0        0        0
# 990         0        0        0        1
# 991        23       16        4       14
# 992         5        0        0        1
# 993         7        1        1        1
# 994        16       16        3       11
# 995         0        0        0        1
# 996         2        0        1        0
# 997         0        0        0        1
# 998         6        0        0        2
# 999         0        0        0        3
# 1000        0        0        0        0
#
# [1001 rows x 8 columns]

# %% [markdown]
# # NEWWEBSITE

# %%
@require(iter_json_gzip,gzip,datetime,re,csv)
def NEWWEBSITE(file_in,out_base,compress=1):
    headers = ['app_id','date','url']
    out_filename = out_base.format('NEWWEBSITE')
    running = {}
    with gzip.open(out_filename,'wt',compress) as out_file:
        csv_writer = csv.writer(out_file)
        csv_writer.writerow(headers)
        http = re.compile(r"(http://)|(https://)")
        www = re.compile(r"^www\.")
        ending = re.compile(r"\.(a-z)(.*?)^")
        bad = re.compile(r"\.[a-z]+(.*?)$")
        for json in iter_json_gzip(file_in):
            website = json.get('website','')
            if isinstance(website,str):
                website = http.sub('',website).lower()
                website = www.sub('',website)
                website = website.split(r"/")[0]
                bad_str = bad.findall(website)
                if bad_str:
                    website = website.replace(bad_str[0],'')
                if running.get(json['app_id'],'')!=website and len(website)>0:
                    running[json['app_id']] = website
                    day = datetime.datetime.\
                    fromtimestamp(int(json['timestamp']))\
                            .strftime('%Y-%m-%d').strip()
                    obs = (json['app_id'],day,website)
                    csv_writer.writerow(obs)
    return out_filename

# %%
df_debug = None
if DEBUG:
    df_debug = read_csv(NEWWEBSITE(RAW_FILE,OUT_BASE,COMPRESS_LEVEL),compression='gzip',header=0)
df_debug
# Out:
#                                                 app_id        date  \
# 0                               com.touchtype.swiftkey  2013-07-17
# 1                  com.gameloft.android.ANMP.GloftDMHM  2013-07-17
# 2                          com.ibm.events.android.usga  2013-07-17
# 3                                     com.dama.camera2  2013-07-17
# 4                          com.disney.scribblefree_goo  2013-07-17
# 5                                com.gau.go.launcherex  2013-07-17
# 6                             com.teslacoilsw.launcher  2013-07-17
# 7                         com.levelup.beautifulwidgets  2013-07-17
# 8          com.socialnmobile.dictdata.chinese.stardict  2013-07-17
# 9                              com.mdb.android.xiangqi  2013-07-17
# 10                                  io.avocado.android  2013-07-17
# 11                                       flipboard.app  2013-07-17
# 12                     com.mobincube.android.app_20866  2013-07-17
# 13                                        com.at.proxi  2013-07-17
# 14                     shopcoffeetable.com.coffeetable  2013-07-17
# 15                           com.and.Wuthering_Heights  2013-07-17
# 16                        com.stopnplayapps.angryshark  2013-07-17
# 17                          say.hello.worldsnookernews  2013-07-17
# 18                               com.wolterskluwer.lsq  2013-07-17
# 19          com.themesfordroid.hunterthemegolauncherex  2013-07-17
# 20                         com.boxyz.androidteam.tsubo  2013-07-17
# 21                            twig.nguyen.d2_runewords  2013-07-17
# 22                                          com.Netter  2013-07-17
# 23                com.quickmare.typingkeyboard.neurope  2013-07-17
# 24                     Technicaljar.BluetoothAppBinder  2013-07-17
# 25                           com.digibooks4all.tritium  2013-07-17
# 26                                      com.playerx.hh  2013-07-17
# 27                    com.buddysreadandspelllitegoogle  2013-07-17
# 28                           com.papoon.sixteencandles  2013-07-17
# 29                          com.mythology.legends.quiz  2013-07-17
# ..                                                 ...         ...
# 736                                         com.sencha  2013-07-17
# 737                        com.jb.gosms.theme.cutebows  2013-07-17
# 738                       org.grassland.safari_sd_lite  2013-07-17
# 739                         nu.vegeby.android.FartKoll  2013-07-17
# 740                 com.miresoftware.sexyamateurs2free  2013-07-17
# 741            Alfasoft.Widgets.PsychedelicAnalogClock  2013-07-17
# 742                                    adit.weather.ta  2013-07-17
# 743            com.andbling.wallpaper.live.names.ernie  2013-07-17
# 744             com.coreapps.android.followme.fetc2013  2013-07-17
# 745               com.mspinc.sexygirllivewallpaperLite  2013-07-17
# 746                   org.guesswork.nightstand.digital  2013-07-17
# 747                               de.wgsoft.scanmaster  2013-07-17
# 748                   com.appsshoppe.hairlosstreatment  2013-07-17
# 749                                     com.mobizel.ra  2013-07-17
# 750                         com.buildingfive.pgnhelper  2013-07-17
# 751                                   com.oxxo.tiendas  2013-07-17
# 752                                   org.prospekt0048  2013-07-17
# 753                              com.andrios.bodycards  2013-07-17
# 754                                   com.sportsoo.web  2013-07-17
# 755                                   org.prospekt0049  2013-07-17
# 756                                za.co.McCarthy.Audi  2013-07-17
# 757  com.gau.go.launcherex.theme.gowidget.taskmanag...  2013-07-17
# 758                             com.dontpanic.lpp.cyan  2013-07-17
# 759                br.com.mobileninjas.pensamentododia  2013-07-17
# 760                        com.custom.lwp.BridgeLights  2013-07-17
# 761     com.uefa.football.champiansleague.europe.messi  2013-07-17
# 762                    com.gcsresearch.burkebiketrails  2013-07-17
# 763                                     com.Wallpaper2  2013-07-17
# 764                             pt.tmn.android.vamosla  2013-07-17
# 765                      com.mymobilebookshelf.dracula  2013-07-17
#
#                                    url
# 0                         swiftkey.net
# 1                         gameloft.com
# 2                             usga.org
# 3                         jfdplabs.com
# 4                            m.support
# 5              golauncher.goforandroid
# 6                     novalauncher.com
# 7                support.levelupstudio
# 8                    socialnmobile.com
# 9                mdbsoftwares.blogspot
# 10                          avocado.io
# 11                       flipboard.com
# 12                  stagebandsouth.com
# 13                    abovethought.com
# 14                 shopcoffeetable.com
# 15                     movielangapp.co
# 16                   stopnplayapps.com
# 17   kid992sayhellowavegoodbye.appspot
# 18                              wkf.fr
# 19                        facebook.com
# 20                            mtubo.jp
# 21              twigstechtips.blogspot
# 22                  elsevier-masson.fr
# 23                       quickmare.com
# 24                    technicaljar.com
# 25                  tritiumdigital.com
# 26                           games.zed
# 27              thesteampunkstudio.com
# 28                       cafepress.com
# 29                maksimapps.wordpress
# ..                                 ...
# 736                       dowgroup.com
# 737              scscreations.blogspot
# 738                       facebook.com
# 739                        blog.vegeby
# 740                   miresoftware.com
# 741                      alfredone.com
# 742                   mobilogstudio.co
# 743                       andbling.com
# 744                      core-apps.com
# 745                        mspinc.mobi
# 746                       sites.google
# 747                          wgsoft.de
# 748                     appsshoppe.com
# 749                        mobizel.com
# 750                   buildingfive.net
# 751                           oxxo.com
# 752                         litgid.com
# 753                    andriosapps.com
# 754                       sportsoo.com
# 755                         litgid.com
# 756               bidvestautomotive.co
# 757            golauncher.goforandroid
# 758                          forum.xda
# 759                   mobileninjas.com
# 760           manumandroidapp.blogspot
# 761                       facebook.com
# 762                   gcs-research.com
# 763                       sites.google
# 764                         vamosla.pt
# 765              mymobilebookshelf.com
#
# [766 rows x 3 columns]

# %% [markdown]
# # NEWPRIVACYDOMAIN

# %%
@require(iter_json_gzip,gzip,datetime,re,csv)
def NEWPRIVACYDOMAIN(file_in,out_base,compress=1):
    headers = ['app_id','date','url']
    out_filename = out_base.format('NEWPRIVACYDOMAIN')
    running = {}
    with gzip.open(out_filename,'wt',compress) as out_file:
        csv_writer = csv.writer(out_file)
        csv_writer.writerow(headers)
        http = re.compile(r"(http://)|(https://)")
        www = re.compile(r"^www\.")
        ending = re.compile(r"\.(a-z)(.*?)^")
        bad = re.compile(r"\.[a-z]+(.*?)$")
        for json in iter_json_gzip(file_in):
            website = json.get('privacy_policy','')
            if isinstance(website,str):
                website = http.sub('',website).lower()
                website = www.sub('',website)
                website = website.split(r"/")[0]
                bad_str = bad.findall(website)
                if bad_str:
                    website = website.replace(bad_str[0],'')
                if running.get(json['app_id'],'')!=website and len(website)>0:
                    running[json['app_id']] = website
                    day = datetime.datetime.\
                    fromtimestamp(int(json['timestamp']))\
                            .strftime('%Y-%m-%d').strip()
                    obs = (json['app_id'],day,website)
                    csv_writer.writerow(obs)
    return out_filename

# %%
df_debug = None
if DEBUG:
    df_debug = read_csv(NEWPRIVACYDOMAIN(RAW_FILE,OUT_BASE,COMPRESS_LEVEL),compression='gzip',header=0)
df_debug
# Out:
#                                                 app_id        date  \
# 0                               com.touchtype.swiftkey  2013-07-17
# 1                  com.gameloft.android.ANMP.GloftDMHM  2013-07-17
# 2                          com.disney.scribblefree_goo  2013-07-17
# 3                                com.gau.go.launcherex  2013-07-17
# 4                         com.levelup.beautifulwidgets  2013-07-17
# 5                                   io.avocado.android  2013-07-17
# 6                                        flipboard.app  2013-07-17
# 7    com.faadooengineers.electricalmeasurementinstu...  2013-07-17
# 8    com.theofficialsimsmagazine.theofficialsimsmag...  2013-07-17
# 9                                com.flyingword.LLHCen  2013-07-17
# 10                             jp.stack.android.ko104a  2013-07-17
# 11                                           com.voval  2013-07-17
# 12                  com.enyetech.radio.coca_cola.fm_hn  2013-07-17
# 13                                   com.stiga.mirmult  2013-07-17
# 14                                com.link.mayormaster  2013-07-17
# 15                              com.clickfree.unlocker  2013-07-17
# 16                             de.rodenberg.doorfinder  2013-07-17
# 17                            com.wBrazilartsandcrafts  2013-07-17
# 18                               com.smallapps.creevey  2013-07-17
# 19                                      ebaytips.ebook  2013-07-17
# 20      appinventor.ai_thanakornpapan.Special_Delivery  2013-07-17
# 21                  com.ptowngames.puzzles.butterflies  2013-07-17
# 22                          com.sancronringtones.carsb  2013-07-17
# 23   com.utopiandroid.brionicthemes.gosmsprothemes....  2013-07-17
# 24   com.spreedinc.providers.californianewspaperpar...  2013-07-17
# 25                             com.shanghaifakemarket2  2013-07-17
# 26                           com.dreamstep.wYuYanjiWeb  2013-07-17
# 27                              com.getgrillsimple.app  2013-07-17
# 28                       air.com.prolog.ESCand5X000.en  2013-07-17
# 29                            com.jiubang.goscreenlock  2013-07-17
# ..                                                 ...         ...
# 75                           com.echoditto.thankanurse  2013-07-17
# 76                                     de.slub.catalog  2013-07-17
# 77                         com.machealth.Yourdiagnosis  2013-07-17
# 78                              com.pushpay.android.pp  2013-07-17
# 79            com.wordpress.chislonchow.legacylauncher  2013-07-17
# 80                         lam.justbecause.tripchecker  2013-07-17
# 81                       com.appsbar.KennedyEFCU248382  2013-07-17
# 82                       fr.prokaryo.cubeLWP.FR.simple  2013-07-17
# 83                                    de.chip.appguide  2013-07-17
# 84                           com.idreamwork.itexplorer  2013-07-17
# 85                              lcdsoundsystem.jukebox  2013-07-17
# 86             com.lestudios.livewallpaper.lovelyparis  2013-07-17
# 87              com.coverpro.awesome.template.sitellas  2013-07-17
# 88                             com.lightsource.android  2013-07-17
# 89                      com.blackvibes.mralexanderstar  2013-07-17
# 90                                        com.chatkast  2013-07-17
# 91                       com.brennanmoymedia.fakeabell  2013-07-17
# 92                             com.rwe.it.sk.smarthome  2013-07-17
# 93                        com.nebulabytes.taptapfaster  2013-07-17
# 94                         com.magnolialabs.textnomore  2013-07-17
# 95                                       com.brodacall  2013-07-17
# 96                        kz.crystalspring.pit_stop_kz  2013-07-17
# 97                             tuition.into.a.business  2013-07-17
# 98                           com.hattedskull.piratescj  2013-07-17
# 99                           fr.aetys.imagier.color.fr  2013-07-17
# 100                          com.app_badgebuddy.layout  2013-07-17
# 101                            org.grexen.findmecoffee  2013-07-17
# 102                             com.supportland.client  2013-07-17
# 103                        com.jb.gosms.theme.cutebows  2013-07-17
# 104               com.mspinc.sexygirllivewallpaperLite  2013-07-17
#
#                           url
# 0                swiftkey.net
# 1                gameloft.com
# 2            corporate.disney
# 3            goforandroid.com
# 4           levelupstudio.com
# 5                  avocado.io
# 6               flipboard.com
# 7         faadooengineers.com
# 8      thesimsofficialmag.com
# 9              lucalashes.com
# 10          kirakiraheart.com
# 11              skysoftvn.com
# 12              coca-cola.com
# 13               kinohall.net
# 14       checkin-reminder.net
# 15              clickfree.com
# 16               rodenberg.ag
# 17    brazilartsandcrafts.com
# 18             small-apps.com
# 19   coolestgadgetsonline.net
# 20         ebook.astoremarket
# 21                docs.google
# 22       sancronringtones.com
# 23           utopiandroid.com
# 24            thereporter.com
# 25       shanghaishopping.org
# 26            alertinform.com
# 27         getgrillsimple.com
# 28                 speakit.tv
# 29           goforandroid.com
# ..                        ...
# 75           friendanurse.org
# 76            slub-dresden.de
# 77          yourdiagnosis.com
# 78                pushpay.com
# 79      chislonchow.wordpress
# 80       android.lamcreations
# 81          kennedyvaefcu.org
# 82               sites.google
# 83                    chip.de
# 84             idreamwork.net
# 85              word2link.com
# 86             mylestudio.com
# 87          privacychoice.org
# 88        salemwebnetwork.com
# 89             blackvibes.com
# 90               chatkast.com
# 91        brennanmoymedia.com
# 92          onlinehelp-sh.com
# 93               sites.google
# 94             textnomore.com
# 95              brodacall.com
# 96                homeplus.kz
# 97               app-buzz.com
# 98             hattedskull.hu
# 99                   aetys.fr
# 100         operationslob.com
# 101          findmecoffee.com
# 102           supportland.com
# 103     scscreations.blogspot
# 104               mspinc.mobi
#
# [105 rows x 3 columns]

# %% [markdown]
# # NEWSIMILAR5

# %%
@require(iter_json_gzip,gzip,datetime,re,csv)
def NEWSIMILAR5(file_in,out_base,compress=1,number_similar = 5):
    headers = ['app_id','date']+ ['related{}'.format(x) \
                                  for x in range(1,number_similar+1)]
    out_filename = out_base.format('NEWSIMILAR{}'.format(number_similar))
    running = {}
    with gzip.open(out_filename,'wt',9) as out_file:
        csv_writer = csv.writer(out_file)
        csv_writer.writerow(headers)
        for json in iter_json_gzip(file_in):
            related = json.get('similar_apps',[])
            if related:
                related = sorted(map(str, related[:number_similar]))
                joined = ",".join(related)
                if running.get(json['app_id'],'')!=joined:
                    running[json['app_id']] = joined
                    day = datetime.datetime.\
                    fromtimestamp(int(json['timestamp']))\
                            .strftime('%Y-%m-%d').strip()
                    csv_writer.writerow([json['app_id'],day]+ related)
    return out_filename

# %%
df_debug = None
if DEBUG:
    df_debug = read_csv(NEWSIMILAR5(RAW_FILE,OUT_BASE,COMPRESS_LEVEL),compression='gzip',header=0)
df_debug
# Out:
#                                                 app_id        date  \
# 0                               com.touchtype.swiftkey  2013-07-17
# 1                  com.gameloft.android.ANMP.GloftDMHM  2013-07-17
# 2                          com.ibm.events.android.usga  2013-07-17
# 3                                     com.dama.camera2  2013-07-17
# 4                          com.disney.scribblefree_goo  2013-07-17
# 5                                com.gau.go.launcherex  2013-07-17
# 6                             com.teslacoilsw.launcher  2013-07-17
# 7                         com.levelup.beautifulwidgets  2013-07-17
# 8          com.socialnmobile.dictdata.chinese.stardict  2013-07-17
# 9                              com.mdb.android.xiangqi  2013-07-17
# 10                                  io.avocado.android  2013-07-17
# 11                                       flipboard.app  2013-07-17
# 12                     com.mobincube.android.app_20866  2013-07-17
# 13                                        com.at.proxi  2013-07-17
# 14                     shopcoffeetable.com.coffeetable  2013-07-17
# 15                         com.mini.flowers.angryfatty  2013-07-17
# 16                           com.and.Wuthering_Heights  2013-07-17
# 17                                    com.loltv.layout  2013-07-17
# 18                        com.stopnplayapps.angryshark  2013-07-17
# 19                          say.hello.worldsnookernews  2013-07-17
# 20                               com.wolterskluwer.lsq  2013-07-17
# 21          com.themesfordroid.hunterthemegolauncherex  2013-07-17
# 22                         com.boxyz.androidteam.tsubo  2013-07-17
# 23                            twig.nguyen.d2_runewords  2013-07-17
# 24                                          com.Netter  2013-07-17
# 25                                com.gunvald.bigpenis  2013-07-17
# 26                                    com.prapps.tokay  2013-07-17
# 27                com.quickmare.typingkeyboard.neurope  2013-07-17
# 28                     Technicaljar.BluetoothAppBinder  2013-07-17
# 29              com.jiubang.goscreenlock.theme.lighter  2013-07-17
# ..                                                 ...         ...
# 969                 com.miresoftware.sexyamateurs2free  2013-07-17
# 970            Alfasoft.Widgets.PsychedelicAnalogClock  2013-07-17
# 971                           com.Kaneosmare.BoeingC17  2013-07-17
# 972                                    adit.weather.ta  2013-07-17
# 973            com.andbling.wallpaper.live.names.ernie  2013-07-17
# 974             com.coreapps.android.followme.fetc2013  2013-07-17
# 975                            com.crossfield.frowline  2013-07-17
# 976               com.mspinc.sexygirllivewallpaperLite  2013-07-17
# 977                   org.guesswork.nightstand.digital  2013-07-17
# 978                               de.wgsoft.scanmaster  2013-07-17
# 979                   com.appsshoppe.hairlosstreatment  2013-07-17
# 980                                     com.mobizel.ra  2013-07-17
# 981                         com.buildingfive.pgnhelper  2013-07-17
# 982                                   com.oxxo.tiendas  2013-07-17
# 983                                   org.prospekt0048  2013-07-17
# 984                              com.andrios.bodycards  2013-07-17
# 985                                   com.sportsoo.web  2013-07-17
# 986                                   org.prospekt0049  2013-07-17
# 987                                za.co.McCarthy.Audi  2013-07-17
# 988                   com.enlight.santaschristmaselves  2013-07-17
# 989  com.gau.go.launcherex.theme.gowidget.taskmanag...  2013-07-17
# 990                                com.gw2.legendaries  2013-07-17
# 991                             com.dontpanic.lpp.cyan  2013-07-17
# 992                br.com.mobileninjas.pensamentododia  2013-07-17
# 993                        com.custom.lwp.BridgeLights  2013-07-17
# 994     com.uefa.football.champiansleague.europe.messi  2013-07-17
# 995                    com.gcsresearch.burkebiketrails  2013-07-17
# 996                                     com.Wallpaper2  2013-07-17
# 997                             pt.tmn.android.vamosla  2013-07-17
# 998                      com.mymobilebookshelf.dracula  2013-07-17
#
#                                         related1  \
# 0                             com.aitype.android
# 1        com.blockdot.universal.truffulaShuffula
# 2                com.advancedmobile.android.ghin
# 3                            com.magix.camera_mx
# 4                    com.drawtube.net.angrybirds
# 5              com.BahagHariArts.BlueNeonGoTheme
# 6                           com.anddoes.launcher
# 7                              cloudtv.hdwidgets
# 8      com.akdevelopment.dict.enchinesetrad.free
# 9             air.com.longo.Xiangqi.android.free
# 10                              com.badoo.mobile
# 11             com.google.android.apps.magazines
# 12                            com.audioaddict.jr
# 13                           com.facebook.katana
# 14                           com.bestbuy.android
# 15                             com.aceviral.agrr
# 16                          com.howtolisten.main
# 17       com.CreativeDK.LeagueofLegendsChampions
# 18                 com.fgol.HungrySharkEvolution
# 19      com.a62563803550827198bd5ee4a.a68089272a
# 20                                      com.keek
# 21     com.golocker.theme.template.pinkbutterfly
# 22                          com.alt12.pinkpadpro
# 23               com.centralbytes.forgottentales
# 24       com.thepandasteam.criteresdiagnostiques
# 25                com.aura.ringtones.auraanimals
# 26                       com.ninegag.android.app
# 27                     com.beansoft.keyboardplus
# 28                               com.bwx.bequick
# 29          com.gau.go.launcherex.theme.Cosmic.E
# ..                                           ...
# 969                      com.acrossair.tvguideuk
# 970             com.adw.clock_ice_cream_sandwich
# 971                        com.SkyLiveWallpapers
# 972                           com.adcoms.Weather
# 973                        com.joko.lightgridpro
# 974                  com.ergonlabs.SabbathSchool
# 975                        com.bitmango.flowline
# 976             com.mspinc.sexygirllivewallpaper
# 977                                   com.dc.mhp
# 978                        Scantech.CarGaugeLite
# 979              com.fitnesskeeper.runkeeper.pro
# 980                  com.ghostpattern.gwcalendar
# 981                    chessbase.android.chessdb
# 982                                      and.p2l
# 983                      com.appflute.love.poems
# 984                            com.exercises.pro
# 985                        com.espn.score_center
# 986                               com.dictionary
# 987                              com.autoscout24
# 988                  com.appsilicious.wallpapers
# 989                    com.artemzin.android.love
# 990             com.ligresoftware.gw2puzzleguide
# 991                 com.dustinb.theme.cyancobalt
# 992      appinventor.ai_leandroavila.ChicoXavier
# 993                        com.joko.lightgridpro
# 994                            com.afl.ucom.view
# 995                      com.esri.android.client
# 996  com.certificomobile.virginmarylivewallpaper
# 997                           com.td.prisa.los40
# 998                    com.content.books.dracula
#
#                                               related2  \
# 0                                 com.aitype.android.p
# 1                           com.disney.TempleRunOz.goo
# 2                            com.goldsteintech.android
# 3                          com.neaststudios.procapture
# 4                   com.flexsolution.scratchguess.logo
# 5                                 com.anddoes.launcher
# 6                            com.gau.go.launcherex.key
# 7                             com.anddoes.fancywidgets
# 8                   com.akdevelopment.dict.enthai.free
# 9                        com.DreamFactory.ChineseChess
# 10                    com.handmark.tweetcaster.premium
# 11                      com.ideashower.readitlater.pro
# 12                          com.massimobiolcati.irealb
# 13                                            com.keek
# 14                                  com.ibotta.android
# 15                           com.aceviral.angrygranrun
# 16                             com.nozisim.checkkorean
# 17                             com.buchland.lolmemento
# 18                                  com.fgol.sharkfree
# 19                            com.protrade.sportacular
# 20                              com.orange.orangeetmoi
# 21              com.xllusion.livewallpaper.horrornight
# 22                          com.runtastic.android.pro2
# 23                        com.dreamstudio.epicdefense2
# 24                                                 NaN
# 25             com.kauf.soundboard.baum.FartSoundBoard
# 26                       com.outfit7.talkingangelafree
# 27                         com.dasur.language.est.pack
# 28                                  com.dianxinos.dxbs
# 29            com.jiubang.goscreenlock.theme.cardboard
# ..                                                 ...
# 969                              com.hottrix.imilkfree
# 970  com.andbling.wallpaper.live.clock.analog.cool....
# 971                     com.appelves.gun.wallpapers.hd
# 972                        com.ilmeteo.android.ilmeteo
# 973                              com.joko.paperlandpro
# 974          com.overdrive.mobile.android.mediaconsole
# 975                        com.bitmango.flowlinebranch
# 976             com.mspinc.sexygirlsbeachlivewallpaper
# 977                              com.joko.lightgridpro
# 978                               Scantech.CarGaugePro
# 979                                  com.fitnow.loseit
# 980                                   com.sec.spp.push
# 981                                com.kalab.pgnviewer
# 982                          com.doodleapp.zy.easynote
# 983                      com.droidworld.asagradabiblia
# 984                               com.northpark.situps
# 985                           com.handmark.sportcaster
# 986                            com.embiq.osfm_historia
# 987                                           com.waze
# 988                            com.dancingsquirrel.elf
# 989         com.gau.go.launcherex.gowidget.taskmanager
# 990                      com.suredigit.gw2.tradingpost
# 991                 com.jb.gokeyboard.theme.siriCyangk
# 992                        com.bobmarley.sistemafrases
# 993               com.marieluke.stonecuttersnight.free
# 994                  com.blueskyapps.worldcupcountdown
# 995                                     com.gcs.mapsVT
# 996            com.flyingfox.supercube_virginmary_free
# 997                           de.burgerking.kingfinder
# 998                     com.gp.dracen.AOTJVEEDGEZCKFLT
#
#                                              related3  \
# 0                com.google.android.inputmethod.latin
# 1                            com.eamobile.life_row_wf
# 2                       com.ibm.events.android.usopen
# 3                                 com.oss.goodcamera2
# 4                       com.hitcents.stickmanepicfree
# 5       com.gau.go.launcherex.theme.defaultthemethree
# 6                                com.gtp.nextlauncher
# 7                   com.anddoes.fancywidgets.unlocker
# 8    com.bravolol.bravolang.englishchinesecdictionary
# 9                                          com.cchess
# 10                                com.yuplee.birthday
# 11                             com.instapaper.android
# 12                                  com.maxxt.pcradio
# 13                               com.syncme.syncmeapp
# 14                                          com.slice
# 15                          com.funbox.game.angrypoke
# 16                  kr.cocone.android.listening.kr.en
# 17                                       com.gzero.tv
# 18                                com.fgol.sharkfree2
# 19                                  fiverings.snooker
# 20                         de.web.mobile.android.mail
# 21                              org.adwfreak.launcher
# 22                         com.tmsoft.whitenoise.full
# 23                              com.joblo.d2runewords
# 24                                                NaN
# 25                     com.outfit7.tomlovesangelafree
# 26                     com.outfit7.tomlovesangelafree
# 27                         com.vision.android.estonia
# 28                        com.latedroid.juicedefender
# 29        com.jiubang.goscreenlock.theme.interstellar
# ..                                                ...
# 969                                      com.kii.safe
# 970                         com.jiubang.lwp.moonstone
# 971                             com.srsdev.wallpapers
# 972                               com.macropinch.swan
# 973                               com.joko.photilepro
# 974                                   com.youdao.dict
# 975                           com.chuslab.VariousFlow
# 976                com.mspinc.sexygirlslivewallpapers
# 977                                com.pvy.batterybar
# 978                                 Scantech.Terminal
# 979                     com.popularapp.periodcalendar
# 980                    de.sandnersoft.Arbeitskalender
# 981                            com.kalab.pgnviewerpro
# 982                                   com.kebab.Llama
# 983                    com.dynamicg.timerecording.pro
# 984               com.tinymission.dailyabworkoutfree1
# 985                  com.ojground.worldjscore.android
# 986                        com.merriamwebster.premium
# 987                             de.mobile.android.app
# 988                         com.dancingsquirrel.giant
# 989              com.gau.go.launcherex.theme.BearLove
# 990                               hoovercj.gw2craftdb
# 991                com.jb.gosms.pctheme.siricyangosms
# 992                   com.outfit7.tomslovelettersfree
# 993                   com.marieluke.tsiangmaroad.free
# 994                             com.mappd.footballcup
# 995                              com.promt.pmtappfree
# 996         com.gannicus.android.tablet.wallpapersbay
# 997                             de.fastline.kinoradar
# 998                com.panaceasupplies.android.reader
#
#                                               related4  \
# 0                                 com.nuance.swype.dtc
# 1                                     com.nekki.vector
# 2                        com.myleaderboard.GolfChannel
# 3                                   com.superphotofull
# 4                      com.zynga.draw2.googleplay.free
# 5                             com.jiubang.goscreenlock
# 6                              com.mobint.hololauncher
# 7                    net.hubalek.android.makeyourclock
# 8                                          com.dict.ec
# 9                                com.tosmart.chessroad
# 10                                       org.antivirus
# 11                                   com.verge.android
# 12                                 com.pandora.android
# 13                                    mobi.bcam.mobile
# 14                                com.thorntons.finder
# 15                              com.junerking.birdjump
# 16                       kr.cocone.android.robot.ko.en
# 17                                     com.imdb.mobile
# 18                                 com.fgol.sharkfree3
# 19                    mobi.sportstap.android.sportstap
# 20                               jp.naver.line.android
# 21            theme.go.launcherex.theme.pink.butterfly
# 22                                     com.tsubomaster
# 23                     com.littlekillerz.legendsarcana
# 24                                                 NaN
# 25               com.pxlapps.app.android.soundeffects3
# 26                        com.zombodroid.MemeGenerator
# 27                        net.cdeguet.smartkeyboardpro
# 28       com.socialnmobile.dictapps.notepad.color.note
# 29           com.jiubang.goscreenlock.theme.one.getjar
# ..                                                 ...
# 969                      com.maxmpz.audioplayer.unlock
# 970                             com.mjdev.analog_clock
# 971                         com.submad.summercity.free
# 972            com.yahoo.mobile.client.android.weather
# 973                                  com.popbox.flurry
# 974                                      org.lds.ldssa
# 975                  com.pilotfishmediainc.flowconnect
# 976                      com.mspinc.sexygirlswallpaper
# 977  jp.main.kurousa.android.livewallpaper.DeviceIn...
# 978                                   org.prowl.torque
# 979                com.runtastic.android.pedometer.pro
# 980                              jp.co.johospace.jorte
# 981                                     com.zen.chess1
# 982                                   com.lexa.fakegps
# 983                                      flipboard.app
# 984                  com.tinymission.dailyworkoutsfree
# 985                                      com.scores365
# 986                                  com.tecarta.bible
# 987                                   org.prowl.torque
# 988                       com.outfit7.talkingsantafree
# 989  com.gau.go.launcherex.theme.appwidget.taskmana...
# 990                   org.kaptkaos.gw2.fieldguide.free
# 991                           com.rrr.theme.CyanbreadX
# 992                               pt.lumberapps.frases
# 993                                fishnoodle.snowfall
# 994                                de.fcbayern.android
# 995                             me.scan.android.client
# 996                        com.sunshineapps.virginmary
# 997                              de.filmstarts.android
# 998                       com.redbrickks.horrorstories
#
#                                      related5
# 0                      com.nuance.swype.trial
# 1                                  me.pou.app
# 2                            com.swingbyswing
# 3    com.zeronoiseapps.secretvideorecorderpro
# 4                   quess.song.music.pop.quiz
# 5           com.wed.go.launcherex.theme.plate
# 6                       org.adwfreak.launcher
# 7                           org.zooper.zwfree
# 8                     com.pleco.chinesesystem
# 9                  com.xidea.ChineseDarkChess
# 10                           org.mots.haxsync
# 11                               flipboard.cn
# 12                           de.radio.android
# 13                 net.eworldui.videouploader
# 14                             fr.snapp.fidme
# 15             com.runningrico.alienvszombies
# 16                net.daum.android.dictionary
# 17                               com.tvnu.app
# 18                     com.hyperkani.sliceice
# 19           say.hello.worldsnookernewsadfree
# 20                    pl.moniusoft.ispeedtest
# 21        themes.go.launcherex.theme.darkstar
# 22           digifit.virtuagym.client.android
# 23                games.laylio.mightydungeons
# 24                                        NaN
# 25                        com.smartanuj.jokes
# 26                             de.tvspielfilm
# 27           org.pocketworkstation.pckeyboard
# 28                       org.kman.WifiManager
# 29            com.yukka.livewallpaper.lighter
# ..                                        ...
# 969                     com.photomontagerfull
# 970         com.the7art.flowerparadewallpaper
# 971                         net.zedge.android
# 972                          yong.weather.pro
# 973                        opotech.image3Dlwp
# 974                          org.lds.ldstools
# 975                          slide.flowFrenzy
# 976              com.mspinc.sexygirlwallpaper
# 977   net.hubalek.android.gaugebattwidget.pro
# 978                      org.prowl.torquefree
# 979                com.runtastic.android.pro2
# 980                          mikado.bizcalpro
# 981                 uk.co.aifactory.chessfree
# 982                    com.punsoftware.backup
# 983                             org.lds.ldssa
# 984                   comgowithmyflow.workout
# 985                             pl.sport.live
# 986                 com.wolfram.android.alpha
# 987                   p46.GPSTracking.Android
# 988                              com.peel.app
# 989         com.rechild.advancedtaskkillerpro
# 990          sirpali.gw2.tradepost.calculator
# 991               com.sonny.theme.sublimecyan
# 992                               sms.prontas
# 993         mma.wallpaper.nativamericans.lite
# 994                           de.motain.iliga
# 995    uk.co.autotrader.androidconsumersearch
# 996                         net.zedge.android
# 997               pt.ptinovacao.rma.meomobile
# 998                    com.wargomedia.dracula
#
# [999 rows x 7 columns]

# %% [markdown]
# # NEWSIMILAR10

# %%
@require(NEWSIMILAR5)
def NEWSIMILAR10(RAW_FILE,OUT_BASE,COMPRESS_LEVEL):
    return NEWSIMILAR5(RAW_FILE,OUT_BASE,COMPRESS_LEVEL,10)

# %%
df_debug = None
if DEBUG:
    df_debug = read_csv(NEWSIMILAR10(RAW_FILE,OUT_BASE,COMPRESS_LEVEL),compression='gzip',header=0)
df_debug
# Out:
#                                                 app_id        date  \
# 0                               com.touchtype.swiftkey  2013-07-17
# 1                  com.gameloft.android.ANMP.GloftDMHM  2013-07-17
# 2                          com.ibm.events.android.usga  2013-07-17
# 3                                     com.dama.camera2  2013-07-17
# 4                          com.disney.scribblefree_goo  2013-07-17
# 5                                com.gau.go.launcherex  2013-07-17
# 6                             com.teslacoilsw.launcher  2013-07-17
# 7                         com.levelup.beautifulwidgets  2013-07-17
# 8          com.socialnmobile.dictdata.chinese.stardict  2013-07-17
# 9                              com.mdb.android.xiangqi  2013-07-17
# 10                                  io.avocado.android  2013-07-17
# 11                                       flipboard.app  2013-07-17
# 12                     com.mobincube.android.app_20866  2013-07-17
# 13                                        com.at.proxi  2013-07-17
# 14                     shopcoffeetable.com.coffeetable  2013-07-17
# 15                         com.mini.flowers.angryfatty  2013-07-17
# 16                           com.and.Wuthering_Heights  2013-07-17
# 17                                    com.loltv.layout  2013-07-17
# 18                        com.stopnplayapps.angryshark  2013-07-17
# 19                          say.hello.worldsnookernews  2013-07-17
# 20                               com.wolterskluwer.lsq  2013-07-17
# 21          com.themesfordroid.hunterthemegolauncherex  2013-07-17
# 22                         com.boxyz.androidteam.tsubo  2013-07-17
# 23                            twig.nguyen.d2_runewords  2013-07-17
# 24                                          com.Netter  2013-07-17
# 25                                com.gunvald.bigpenis  2013-07-17
# 26                                    com.prapps.tokay  2013-07-17
# 27                com.quickmare.typingkeyboard.neurope  2013-07-17
# 28                     Technicaljar.BluetoothAppBinder  2013-07-17
# 29              com.jiubang.goscreenlock.theme.lighter  2013-07-17
# ..                                                 ...         ...
# 969                 com.miresoftware.sexyamateurs2free  2013-07-17
# 970            Alfasoft.Widgets.PsychedelicAnalogClock  2013-07-17
# 971                           com.Kaneosmare.BoeingC17  2013-07-17
# 972                                    adit.weather.ta  2013-07-17
# 973            com.andbling.wallpaper.live.names.ernie  2013-07-17
# 974             com.coreapps.android.followme.fetc2013  2013-07-17
# 975                            com.crossfield.frowline  2013-07-17
# 976               com.mspinc.sexygirllivewallpaperLite  2013-07-17
# 977                   org.guesswork.nightstand.digital  2013-07-17
# 978                               de.wgsoft.scanmaster  2013-07-17
# 979                   com.appsshoppe.hairlosstreatment  2013-07-17
# 980                                     com.mobizel.ra  2013-07-17
# 981                         com.buildingfive.pgnhelper  2013-07-17
# 982                                   com.oxxo.tiendas  2013-07-17
# 983                                   org.prospekt0048  2013-07-17
# 984                              com.andrios.bodycards  2013-07-17
# 985                                   com.sportsoo.web  2013-07-17
# 986                                   org.prospekt0049  2013-07-17
# 987                                za.co.McCarthy.Audi  2013-07-17
# 988                   com.enlight.santaschristmaselves  2013-07-17
# 989  com.gau.go.launcherex.theme.gowidget.taskmanag...  2013-07-17
# 990                                com.gw2.legendaries  2013-07-17
# 991                             com.dontpanic.lpp.cyan  2013-07-17
# 992                br.com.mobileninjas.pensamentododia  2013-07-17
# 993                        com.custom.lwp.BridgeLights  2013-07-17
# 994     com.uefa.football.champiansleague.europe.messi  2013-07-17
# 995                    com.gcsresearch.burkebiketrails  2013-07-17
# 996                                     com.Wallpaper2  2013-07-17
# 997                             pt.tmn.android.vamosla  2013-07-17
# 998                      com.mymobilebookshelf.dracula  2013-07-17
#
#                                         related1  \
# 0                             com.aitype.android
# 1        com.blockdot.universal.truffulaShuffula
# 2                                  air.WatchESPN
# 3                         com.almalence.hdr_plus
# 4                       com.drawcoolman.net.cars
# 5              com.BahagHariArts.BlueNeonGoTheme
# 6                           com.anddoes.launcher
# 7                    cloudtv.hdthemes.colourform
# 8     com.akdevelopment.dict.enchinesesimpl.free
# 9             air.com.longo.Xiangqi.android.free
# 10                              com.badoo.mobile
# 11                                      com.Time
# 12                       com.afinc.musicparadise
# 13                          com.discovercircle10
# 14                           com.bestbuy.android
# 15                             com.aceviral.agrr
# 16                   air.net.daum.kids.kidsbasic
# 17       com.CreativeDK.LeagueofLegendsChampions
# 18                 com.fgol.HungrySharkEvolution
# 19      com.a62563803550827198bd5ee4a.a68089272a
# 20                                      com.keek
# 21          com.gau.go.launcherex.theme.mystical
# 22                          com.alt12.pinkpadpro
# 23               com.centralbytes.forgottentales
# 24       com.thepandasteam.criteresdiagnostiques
# 25                                com.alek.smile
# 26                           com.andrwq.recorder
# 27                          com.aitype.android.p
# 28                               com.bwx.bequick
# 29          com.gau.go.launcherex.theme.Cosmic.E
# ..                                           ...
# 969                      com.acrossair.tvguideuk
# 970             com.adw.clock_ice_cream_sandwich
# 971                        com.SkyLiveWallpapers
# 972                           com.adcoms.Weather
# 973       com.gau.go.launcherex.theme.droidglass
# 974                   com.androidtrainer.survive
# 975                        com.bigduckgames.flow
# 976                                      com.he2
# 977                                   com.dc.mhp
# 978           OCTech.Mobile.Applications.OBDLink
# 979              com.fitnesskeeper.runkeeper.pro
# 980                  com.TouchSpots.CallTimerPro
# 981                    chessbase.android.chessdb
# 982                                      and.p2l
# 983                  com.aitype.android.tablet.p
# 984                            com.exercises.pro
# 985                            com.bskyb.fbscore
# 986               com.abbyy.mobile.lingvo.market
# 987                    com.aaa.android.discounts
# 988                  com.appsilicious.wallpapers
# 989                    com.artemzin.android.love
# 990                 com.charrbucks.gw2.countdown
# 991                            cloudtv.hdwidgets
# 992      appinventor.ai_leandroavila.ChicoXavier
# 993   com.jetblacksoftware.xmastreewallpaperpaid
# 994                            com.afl.ucom.view
# 995                      com.esri.android.client
# 996  com.certificomobile.virginmarylivewallpaper
# 997                      com.appturbo.appturboSE
# 998       au.com.tinmangames.sl1.vampire.android
#
#                                               related2  \
# 0                                 com.aitype.android.p
# 1                           com.disney.TempleRunOz.goo
# 2                      com.advancedmobile.android.ghin
# 3                                com.kth.PuddingCamera
# 4                            com.drawmonsters.net.dogs
# 5                                 com.anddoes.launcher
# 6                     com.chrislacy.actionlauncher.pro
# 7                                    cloudtv.hdwidgets
# 8            com.akdevelopment.dict.enchinesetrad.free
# 9                                       chschess.chess
# 10                            com.handmark.tweetcaster
# 11                                    com.devhd.feedly
# 12                                  com.audioaddict.jr
# 13                                 com.facebook.katana
# 14                           com.birbeck.starbuckscard
# 15                           com.aceviral.angrygranrun
# 16                                com.howtolisten.main
# 17                                     com.K19media.tv
# 18                                 com.fgol.grabatron1
# 19                                com.cricbuzz.android
# 20                           com.leparisien.leparisien
# 21           com.golocker.theme.template.pinkbutterfly
# 22                    com.ensight.android.soundmassage
# 23                        com.dreamstudio.epicdefense2
# 24                                                 NaN
# 25                              com.ani.apps.jokes.sms
# 26                                com.apps.bodyboardsb
# 27                           com.beansoft.keyboardplus
# 28                                     com.bwx.quicker
# 29                            com.jiubang.goscreenlock
# ..                                                 ...
# 969              com.garettrogers.android.bigbrother12
# 970  com.andbling.wallpaper.live.clock.analog.cool....
# 971          com.androidwasabi.livewallpaper.dandelion
# 972                              com.aws.android.elite
# 973                               com.gtp.nextlauncher
# 974                    com.ani.apps.idioms.and.phrases
# 975                       com.bigduckgames.flowbridges
# 976                               com.iconnect.app.pts
# 977                            com.dkeesto.digitalflux
# 978                              Scantech.CarGaugeLite
# 979                                  com.fitnow.loseit
# 980                               com.aitype.android.p
# 981                    com.epekware.wordhelpforfriends
# 982                                          com.anydo
# 983                            com.appflute.love.poems
# 984                               com.northpark.situps
# 985                               com.cricbuzz.android
# 986                                     com.dictionary
# 987                            com.appturbo.appturboUK
# 988                            com.dancingsquirrel.elf
# 989         com.gau.go.launcherex.gowidget.taskmanager
# 990                         com.combustion.dragontimer
# 991                  com.anddoes.fancywidgets.unlocker
# 992                            com.appturbo.appturboMX
# 993                              com.joko.lightgridpro
# 994                       com.appshen.frameworks.blade
# 995                          com.esri.arcgis.collector
# 996            com.flyingfox.supercube_virginmary_free
# 997                             com.greatclips.android
# 998                          com.content.books.dracula
#
#                                        related3  \
# 0                     com.beansoft.keyboardplus
# 1                      com.eamobile.life_row_wf
# 2                       com.dogmac.SportsCenter
# 3                           com.magix.camera_mx
# 4                   com.drawtube.net.angrybirds
# 5                       com.campmobile.launcher
# 6                com.czarnomorski.theme.dcikonz
# 7                      com.anddoes.fancywidgets
# 8            com.akdevelopment.dict.enthai.free
# 9                 com.DreamFactory.ChineseChess
# 10             com.handmark.tweetcaster.premium
# 11                                   com.eterno
# 12                          com.audioaddict.sky
# 13                            com.facebook.orca
# 14                 com.birbeck.starbuckscardpro
# 15           com.crescentmoongames.redline_rush
# 16                   com.lguplus.videoeducation
# 17                         com.activision.elite
# 18                               com.fgol.shark
# 19                 com.fasterthanmonkeys.iscore
# 20             com.mylife.android.MyLifeRelease
# 21                com.jb.gosms.theme.aPonyTheme
# 22           com.fourtechnologies.mynetdiary.ad
# 23             com.dreamstudio.epicdefense2paid
# 24                                          NaN
# 25               com.aura.ringtones.auraanimals
# 26                          com.foncannoninc.wc
# 27                  com.dasur.language.est.pack
# 28                           com.dianxinos.dxbs
# 29          com.jiubang.goscreenlock.theme.Halo
# ..                                          ...
# 969                       com.hottrix.imilkfree
# 970                   com.jiubang.lwp.moonstone
# 971              com.appelves.gun.wallpapers.hd
# 972                         com.gismeteo.client
# 973  com.jetblacksoftware.xmastreewallpaperpaid
# 974                 com.ergonlabs.SabbathSchool
# 975                       com.bitmango.flowline
# 976            com.mspinc.sexygirllivewallpaper
# 977                       com.joko.lightgridpro
# 978                        Scantech.CarGaugePro
# 979          com.fourtechnologies.mynetdiary.ad
# 980                          com.gary.NoTePases
# 981                    com.google.android.chess
# 982                   com.doodleapp.zy.easynote
# 983               com.droidworld.asagradabiblia
# 984                            com.rittr.situps
# 985                       com.espn.score_center
# 986                     com.embiq.osfm_historia
# 987                             com.autoscout24
# 988                   com.dancingsquirrel.giant
# 989        com.gau.go.launcherex.theme.BearLove
# 990                com.domino.gw2.dressing.room
# 991                com.dustinb.theme.cyancobalt
# 992                 com.bobmarley.sistemafrases
# 993                   com.live.wallpaper.autumn
# 994           com.blueskyapps.worldcupcountdown
# 995                              com.gcs.mapsVT
# 996   com.gannicus.android.tablet.wallpapersbay
# 997      com.spodtronic.radio.energydeutschland
# 998             com.drawinghand.net.monsterhigh
#
#                                               related4  \
# 0                            com.dasur.slideit.vt.lite
# 1                  com.gameloft.android.ANMP.GloftLVMK
# 2                            com.goldsteintech.android
# 3                          com.neaststudios.procapture
# 4                         com.ecapycsw.onetouchdrawing
# 5                  com.gau.go.launcherex.theme.WP7Blue
# 6                            com.gau.go.launcherex.key
# 7                    com.anddoes.fancywidgets.unlocker
# 8     com.bravolol.bravolang.englishchinesecdictionary
# 9                              com.aichess.googlechess
# 10                            com.hootsuite.droid.full
# 11                    com.google.android.apps.currents
# 12                              com.aupeo.AupeoNextGen
# 13                          com.giannz.photodownloader
# 14                                     com.hsn.android
# 15                           com.funbox.game.angrypoke
# 16                      com.nhn.android.phrasebookplus
# 17                                    com.blizzard.wow
# 18                                     com.fgol.shark2
# 19                             com.fivemobile.thescore
# 20                              com.orange.orangeetmoi
# 21                 com.jiubang.goscreenlock.theme.dark
# 22              com.hivebrain.andrewjohnson.weightloss
# 23                         com.javaground.danteinferno
# 24                                                 NaN
# 25                                    com.cramzy.jokes
# 26                                        com.kii.safe
# 27                                   com.dasur.slideit
# 28               com.geekyouup.android.widgets.battery
# 29            com.jiubang.goscreenlock.theme.cardboard
# ..                                                 ...
# 969                               com.invacore.damnlol
# 970                             com.mjdev.analog_clock
# 971          com.gannicus.android.tablet.wallpapersbay
# 972                        com.ilmeteo.android.ilmeteo
# 973                              com.joko.lightgridpro
# 974                            com.heku.readingtrainer
# 975                        com.bitmango.flowlinebranch
# 976             com.mspinc.sexygirlsbeachlivewallpaper
# 977                                 com.pvy.batterybar
# 978                                  Scantech.Terminal
# 979                      com.popularapp.periodcalendar
# 980                        com.ghostpattern.gwcalendar
# 981                                com.kalab.pgnviewer
# 982                          com.guidedways.android2do
# 983                     com.droidworld.lasagradabiblia
# 984                              com.runtastic.android
# 985                            com.fivemobile.thescore
# 986                                 com.merriamwebster
# 987                        com.eclipsim.gpstoolbox.pro
# 988                         com.google.android.youtube
# 989  com.gau.go.launcherex.theme.appwidget.taskmana...
# 990                         com.guildwarstemple.timers
# 991                   com.fede.launcherproplusunlocker
# 992                         com.gdacarv.app.amorporsms
# 993               com.marieluke.stonecuttersnight.free
# 994                     com.jalvasco.football.worldcup
# 995                               com.promt.pmtappfree
# 996                              com.srsdev.wallpapers
# 997                                 com.td.prisa.los40
# 998                       com.drawmonsters.net.zombies
#
#                                           related5  \
# 0                     com.fiberthemax.OpQ2keyboard
# 1                             com.imangi.templerun
# 2                                 com.golflogix.ui
# 3                              com.oss.goodcamera2
# 4               com.flexsolution.scratchguess.logo
# 5    com.gau.go.launcherex.theme.defaultthemethree
# 6                             com.gtp.nextlauncher
# 7                     com.custom.lwp.LBeautifulSea
# 8                                      com.dict.ec
# 9                 com.alonsoruibal.chessdroid.lite
# 10                          com.opera.mini.android
# 11               com.google.android.apps.magazines
# 12                                    com.e8tracks
# 13                                        com.keek
# 14                              com.ibotta.android
# 15            com.imperialgamestudio.turbogrannies
# 16                         com.nozisim.checkkorean
# 17                         com.buchland.lolmemento
# 18                                 com.fgol.shark3
# 19                               com.july.cricinfo
# 20                      de.web.mobile.android.mail
# 21           com.packofthemes.gosmsprothemephoenix
# 22             com.runtastic.android.heartrate.pro
# 23                           com.joblo.d2runewords
# 24                                             NaN
# 25                    com.drawtube.net.wildanimals
# 26                         com.ninegag.android.app
# 27                            com.nuance.swype.dtc
# 28                     com.latedroid.juicedefender
# 29             com.jiubang.goscreenlock.theme.dark
# ..                                             ...
# 969                                   com.kii.safe
# 970                                   com.rtsw.mcw
# 971         com.gau.go.launcherex.theme.droidglass
# 972                com.ilmeteo.android.ilmeteoplus
# 973                          com.joko.paperlandpro
# 974      com.overdrive.mobile.android.mediaconsole
# 975                    com.bitmango.flowlinebridge
# 976             com.mspinc.sexygirlslivewallpapers
# 977                               com.softspb.time
# 978                        com.ScanMyOpelLite.Main
# 979            com.runtastic.android.pedometer.pro
# 980                    com.google.android.calendar
# 981                         com.kalab.pgnviewerpro
# 982                           com.ideal.backbundle
# 983                 com.dynamicg.timerecording.pro
# 984              com.skyhealth.fitnessbuddyandroid
# 985                       com.handmark.sportcaster
# 986                     com.merriamwebster.premium
# 987                      com.goldsteintech.android
# 988                 com.incredibleapp.wallpapershd
# 989                 com.gau.go.launcherex.theme.cb
# 990               com.ligresoftware.gw2puzzleguide
# 991             com.jb.gokeyboard.theme.siriCyangk
# 992                            com.jcvsoft.smsamor
# 993                com.marieluke.tsiangmaroad.free
# 994                       com.lilait.oba.crronaldo
# 995                           com.promt.pmtappsale
# 996                    com.sunshineapps.virginmary
# 997                            com.td.prisa.maxima
# 998                 com.gp.dracen.AOTJVEEDGEZCKFLT
#
#                                               related6  \
# 0                 com.google.android.inputmethod.latin
# 1                                com.imangi.templerun2
# 2                        com.ibm.events.android.usopen
# 3                                   com.superphotofull
# 4                        com.hitcents.stickmanepicfree
# 5                             com.jiubang.goscreenlock
# 6                              com.mobint.hololauncher
# 7                                 jmbc.timeWidget.lite
# 8                                       com.dictionary
# 9                                           com.cchess
# 10                              com.spartancoders.gtok
# 11                      com.ideashower.readitlater.pro
# 12                            com.google.android.music
# 13                              com.spartancoders.gtok
# 14                            com.ocado.mobile.android
# 15           com.imperialgamestudio.turbogrannies_lite
# 16                         com.wonshinhyo.VocaRoidLite
# 17                                        com.gzero.tv
# 18                                  com.fgol.sharkfree
# 19                          com.mobilefootie.fotmobpro
# 20                           info.mkplan.lineCuteStamp
# 21             com.themesfordroid.leopardthemegolocker
# 22                 com.runtastic.android.pedometer.pro
# 23                     com.littlekillerz.legendsarcana
# 24                                                 NaN
# 25             com.kauf.soundboard.baum.FartSoundBoard
# 26                       com.outfit7.talkingangelafree
# 27                  com.nvdevelopment.dict.etrumt.free
# 28       com.socialnmobile.dictapps.notepad.color.note
# 29         com.jiubang.goscreenlock.theme.interstellar
# ..                                                 ...
# 969                                  com.livetv.russia
# 970                            com.stylish.live.clocks
# 971                          com.launchertheme.kxnt.ui
# 972                                com.macropinch.swan
# 973                                com.joko.photilepro
# 974                            com.pleco.chinesesystem
# 975                            com.chuslab.VariousFlow
# 976                      com.mspinc.sexygirlswallpaper
# 977                              com.tomanyz.lockWatch
# 978                                com.apdroid.tabtalk
# 979                         com.runtastic.android.pro2
# 980                                   com.sec.spp.push
# 981                      com.optimesoftware.chess.free
# 982                                    com.kebab.Llama
# 983            com.greenleaf.android.translator.enru.c
# 984              com.skyhealth.fitnessbuddyandroidfree
# 985                   com.ojground.worldjscore.android
# 986                                    com.tecarta.amp
# 987                                           com.waze
# 988                       com.outfit7.talkingsantafree
# 989                  com.gau.go.launcherex.theme.cblue
# 990                      com.suredigit.gw2.tradingpost
# 991                 com.jb.gosms.pctheme.siricyangosms
# 992                              com.kukinet.encourage
# 993               com.maxelus.freshleaveslivewallpaper
# 994                               com.lilait.oba.messi
# 995                                     com.smsBlocker
# 996                                fishnoodle.aquarium
# 997                           de.burgerking.kingfinder
# 998  com.nadstech.alicesadventuresinwonderland.AOTT...
#
#                                               related7  \
# 0                                    com.jb.gokeyboard
# 1                                     com.nekki.vector
# 2                        com.myleaderboard.GolfChannel
# 3             com.zeronoiseapps.secretvideorecorderpro
# 4                                   com.omgpop.dstfree
# 5                                      com.spb.shell3d
# 6                           com.mobint.hololauncher.hd
# 7                   jp.co.vibe.weatherskylivewallpaper
# 8                         com.dreamob.android.encndict
# 9                             com.google.android.chess
# 10                                        com.twidroid
# 11                              com.instapaper.android
# 12                          com.massimobiolcati.irealb
# 13                                com.syncme.syncmeapp
# 14                                           com.slice
# 15                              com.junerking.birdjump
# 16                   kr.cocone.android.listening.kr.en
# 17                                     com.imdb.mobile
# 18                                 com.fgol.sharkfree2
# 19                            com.protrade.sportacular
# 20                               jp.naver.line.android
# 21              com.xllusion.livewallpaper.horrornight
# 22                          com.runtastic.android.pro2
# 23                  com.topfreegames.bikeracefreeworld
# 24                                                 NaN
# 25                      com.outfit7.tomlovesangelafree
# 26                      com.outfit7.tomlovesangelafree
# 27                     com.sedevelop.dict.eneston.free
# 28                         imoblife.memorybooster.full
# 29           com.jiubang.goscreenlock.theme.one.getjar
# ..                                                 ...
# 969                      com.maxmpz.audioplayer.unlock
# 970                  com.the7art.flowerparadewallpaper
# 971                              com.srsdev.wallpapers
# 972                           com.wetter.androidclient
# 973                       com.paranoid.preferences.pro
# 974                             com.touchtype.swiftkey
# 975                       com.currynurt.yetanotherflow
# 976                       com.mspinc.sexygirlwallpaper
# 977   jp.main.kurousa.android.livewallpaper.DeviceInfo
# 978                                com.prizmos.carista
# 979                                         com.strava
# 980                          com.studiokuma.callfilter
# 981                               com.pereira.analysis
# 982                                   com.lexa.fakegps
# 983                     com.sedevelop.dict.enrufl.free
# 984                com.tinymission.dailyabworkoutfree1
# 985                           com.protrade.sportacular
# 986                                  com.tecarta.bible
# 987                              de.mobile.android.app
# 988                                       com.peel.app
# 989  com.gau.go.launcherex.theme.gowidget.halloween...
# 990                                hoovercj.gw2craftdb
# 991                       com.levelup.beautifulwidgets
# 992                    com.outfit7.tomslovelettersfree
# 993                             com.whatsapp.wallpaper
# 994                              com.mappd.footballcup
# 995  com.unitedinternet.portal.android.onlinestorag...
# 996                                 fishnoodle.koipond
# 997                              de.fastline.kinoradar
# 998         com.nadstech.bramstoker.AOTTZEVCYYCATREXIN
#
#                                               related8  \
# 0                                 com.nuance.swype.dtc
# 1                             com.noodlecake.happyjump
# 2                             com.shotzoom.golfshotgps
# 3                          jp.naver.linecamera.android
# 4                       com.openmygame.games.kr.client
# 5                             com.teslacoilsw.launcher
# 6                                        kov.theme.ics
# 7                    net.hubalek.android.makeyourclock
# 8                           com.embermitre.hanping.app
# 9                                com.tosmart.chessroad
# 10                                 com.yuplee.birthday
# 11                                   com.verge.android
# 12                                   com.maxxt.pcradio
# 13                                com.tektrify.iloader
# 14                              com.surfwax.couponsapp
# 15                                  com.noodlecake.ssg
# 16                       kr.cocone.android.robot.ko.en
# 17                                        com.peel.app
# 18                                 com.fgol.sharkfree3
# 19                                   fiverings.snooker
# 20                             jp.quan_inc.stickershop
# 21                               org.adwfreak.launcher
# 22                          com.tmsoft.whitenoise.full
# 23                      de.mobilebits.soulcraftdefault
# 24                                                 NaN
# 25               com.pxlapps.app.android.soundeffects3
# 26                             com.smartanuj.hideitpro
# 27                          com.vision.android.estonia
# 28                           mobi.infolife.uninstaller
# 29                  com.jiubang.goscreenlock.theme.ray
# ..                                                 ...
# 969                              com.photomontagerfull
# 970                             kuba.livewall.geoclock
# 971                         com.submad.summercity.free
# 972            com.yahoo.mobile.client.android.weather
# 973                                  com.popbox.flurry
# 974                                    com.youdao.dict
# 975                     com.gold_stone_studio.flow8013
# 976                       com.rhythmnewmedia.android.e
# 977  jp.main.kurousa.android.livewallpaper.DeviceIn...
# 978                                   org.prowl.torque
# 979                         com.tmsoft.whitenoise.full
# 980                     de.sandnersoft.Arbeitskalender
# 981                                     com.zen.chess1
# 982                                  com.octabode.dcfd
# 983                                      flipboard.app
# 984                  com.tinymission.dailyworkoutsfree
# 985                                      com.scores365
# 986                                   com.tecarta.nasb
# 987                                   org.prowl.torque
# 988                       com.sdgtl.mediahub.tmo.vplus
# 989                              com.jbapps.contactpro
# 990                   org.kaptkaos.gw2.fieldguide.free
# 991                           com.rrr.theme.CyanbreadX
# 992                      es.intelectiva.imgfrasesamor2
# 993                                 fishnoodle.koipond
# 994                                de.fcbayern.android
# 995                     com.vistechprojects.planimeter
# 996                            fishnoodle.koipond_free
# 997                              de.filmstarts.android
# 998                 com.panaceasupplies.android.reader
#
#                                        related9  \
# 0                        com.nuance.swype.trial
# 1    com.retrodreamer.IceCreamJump.android.free
# 2                              com.swingbyswing
# 3              uk.co.neilandtheresa.NewVignette
# 4               com.zynga.draw2.googleplay.free
# 5             com.wed.go.launcherex.theme.plate
# 6                              org.adw.launcher
# 7                             org.zooper.zwfree
# 8                       com.pleco.chinesesystem
# 9                          com.vndynapp.cotuong
# 10                                org.antivirus
# 11              com.zinio.mobile.android.reader
# 12                          com.pandora.android
# 13                             mobi.bcam.mobile
# 14                         com.thorntons.finder
# 15               com.runningrico.alienvszombies
# 16                  net.daum.android.dictionary
# 17                                 com.tvnu.app
# 18          com.gameloft.android.ANMP.GloftSRHM
# 19             mobi.sportstap.android.sportstap
# 20                   nfadev.sn.immnavigatorlite
# 21     theme.go.launcherex.theme.pink.butterfly
# 22                              com.tsubomaster
# 23             free.littlekillerz.legendsarcana
# 24                                          NaN
# 25                           com.sis.funnyjokes
# 26                 com.zombodroid.MemeGenerator
# 27                 net.cdeguet.smartkeyboardpro
# 28                          org.gpo.greenpower2
# 29          com.tracio.apps.magic.touch.lighter
# ..                                          ...
# 969                 com.theronrogers.vaultyfree
# 970               nl.jsource.retroclock.android
# 971                             kov.theme.stark
# 972                     ru.yandex.weatherplugin
# 973                com.teragon.skyatdawnlw.lite
# 974                               org.lds.ldssa
# 975           com.pilotfishmediainc.flowconnect
# 976                                com.thechive
# 977     net.hubalek.android.gaugebattwidget.pro
# 978                        org.prowl.torquefree
# 979                   com.ultimate.points.diary
# 980                       jp.co.johospace.jorte
# 981                            org.scid.android
# 982                      com.punsoftware.backup
# 983                               org.lds.ldssa
# 984                     comgowithmyflow.workout
# 985                               com.thuuz.gtv
# 986                             com.tecarta.nlt
# 987                     p46.GPSTracking.Android
# 988                              com.sketchbook
# 989         com.rechild.advancedtaskkillerfroyo
# 990             org.kaptkaos.gw2.fieldguide.pro
# 991                 com.sonny.theme.sublimecyan
# 992                        pt.lumberapps.frases
# 993                         fishnoodle.snowfall
# 994                             de.motain.iliga
# 995                      me.scan.android.client
# 996                           net.zedge.android
# 997                   de.krankikom.uci_kinowelt
# 998                com.redbrickks.horrorstories
#
#                                     related10
# 0         com.thaicomcenter.android.tswipepro
# 1                                  me.pou.app
# 2                              com.v1.v1golf2
# 3        uk.co.neilandtheresa.VignetteNewDemo
# 4                   quess.song.music.pop.quiz
# 5                            org.adw.launcher
# 6                       org.adwfreak.launcher
# 7           sk.michalec.SimpleDigiClockWidget
# 8     socialnmobile.dictdata.bible.dictionary
# 9                  com.xidea.ChineseDarkChess
# 10                           org.mots.haxsync
# 11                               flipboard.cn
# 12                           de.radio.android
# 13                 net.eworldui.videouploader
# 14                             fr.snapp.fidme
# 15                       com.zagmoid.carrom3d
# 16             net.pororo.pororosongphonefree
# 17                             de.tvspielfilm
# 18                     com.hyperkani.sliceice
# 19           say.hello.worldsnookernewsadfree
# 20                    pl.moniusoft.ispeedtest
# 21        themes.go.launcherex.theme.darkstar
# 22           digifit.virtuagym.client.android
# 23                games.laylio.mightydungeons
# 24                                        NaN
# 25                        com.smartanuj.jokes
# 26                             de.tvspielfilm
# 27           org.pocketworkstation.pckeyboard
# 28                       org.kman.WifiManager
# 29            com.yukka.livewallpaper.lighter
# ..                                        ...
# 969              com.zombodroid.MemeGenerator
# 970         sk.michalec.SimpleDigiClockWidget
# 971                         net.zedge.android
# 972                          yong.weather.pro
# 973                        opotech.image3Dlwp
# 974                          org.lds.ldstools
# 975                          slide.flowFrenzy
# 976             kr.co.mokey.mokeywallpaper_v3
# 977     net.hubalek.android.makeyourclock.pro
# 978                      org.prowl.torquescan
# 979                  name.file.wwplusfastfood
# 980                          mikado.bizcalpro
# 981                 uk.co.aifactory.chessfree
# 982              org.ajeje.locationspooferpro
# 983                                    org.m5
# 984                                je.fit.pro
# 985                             pl.sport.live
# 986                 com.wolfram.android.alpha
# 987                  uk.co.nickfines.RealCalc
# 988                    com.textsfromlastnight
# 989         com.rechild.advancedtaskkillerpro
# 990          sirpali.gw2.tradepost.calculator
# 991             fr.clockwidget.lpclassicsense
# 992                               sms.prontas
# 993         mma.wallpaper.nativamericans.lite
# 994                            es.lfp.gi.main
# 995    uk.co.autotrader.androidconsumersearch
# 996  pterry.android.bibleverses.livewallpaper
# 997               pt.ptinovacao.rma.meomobile
# 998                    com.wargomedia.dracula
#
# [999 rows x 12 columns]

# %% [markdown]
# # NEWSIMILAR15

# %%
@require(NEWSIMILAR5)
def NEWSIMILAR15(RAW_FILE,OUT_BASE,COMPRESS_LEVEL):
    return NEWSIMILAR5(RAW_FILE,OUT_BASE,COMPRESS_LEVEL,15)

# %%
df_debug = None
if DEBUG:
    df_debug = read_csv(NEWSIMILAR15(RAW_FILE,OUT_BASE,COMPRESS_LEVEL),compression='gzip',header=0)
df_debug
# Out:
#                                                 app_id        date  \
# 0                               com.touchtype.swiftkey  2013-07-17
# 1                  com.gameloft.android.ANMP.GloftDMHM  2013-07-17
# 2                          com.ibm.events.android.usga  2013-07-17
# 3                                     com.dama.camera2  2013-07-17
# 4                          com.disney.scribblefree_goo  2013-07-17
# 5                                com.gau.go.launcherex  2013-07-17
# 6                             com.teslacoilsw.launcher  2013-07-17
# 7                         com.levelup.beautifulwidgets  2013-07-17
# 8          com.socialnmobile.dictdata.chinese.stardict  2013-07-17
# 9                              com.mdb.android.xiangqi  2013-07-17
# 10                                  io.avocado.android  2013-07-17
# 11                                       flipboard.app  2013-07-17
# 12                     com.mobincube.android.app_20866  2013-07-17
# 13                                        com.at.proxi  2013-07-17
# 14                     shopcoffeetable.com.coffeetable  2013-07-17
# 15                         com.mini.flowers.angryfatty  2013-07-17
# 16                           com.and.Wuthering_Heights  2013-07-17
# 17                                    com.loltv.layout  2013-07-17
# 18                        com.stopnplayapps.angryshark  2013-07-17
# 19                          say.hello.worldsnookernews  2013-07-17
# 20                               com.wolterskluwer.lsq  2013-07-17
# 21          com.themesfordroid.hunterthemegolauncherex  2013-07-17
# 22                         com.boxyz.androidteam.tsubo  2013-07-17
# 23                            twig.nguyen.d2_runewords  2013-07-17
# 24                                          com.Netter  2013-07-17
# 25                                com.gunvald.bigpenis  2013-07-17
# 26                                    com.prapps.tokay  2013-07-17
# 27                com.quickmare.typingkeyboard.neurope  2013-07-17
# 28                     Technicaljar.BluetoothAppBinder  2013-07-17
# 29              com.jiubang.goscreenlock.theme.lighter  2013-07-17
# ..                                                 ...         ...
# 969                 com.miresoftware.sexyamateurs2free  2013-07-17
# 970            Alfasoft.Widgets.PsychedelicAnalogClock  2013-07-17
# 971                           com.Kaneosmare.BoeingC17  2013-07-17
# 972                                    adit.weather.ta  2013-07-17
# 973            com.andbling.wallpaper.live.names.ernie  2013-07-17
# 974             com.coreapps.android.followme.fetc2013  2013-07-17
# 975                            com.crossfield.frowline  2013-07-17
# 976               com.mspinc.sexygirllivewallpaperLite  2013-07-17
# 977                   org.guesswork.nightstand.digital  2013-07-17
# 978                               de.wgsoft.scanmaster  2013-07-17
# 979                   com.appsshoppe.hairlosstreatment  2013-07-17
# 980                                     com.mobizel.ra  2013-07-17
# 981                         com.buildingfive.pgnhelper  2013-07-17
# 982                                   com.oxxo.tiendas  2013-07-17
# 983                                   org.prospekt0048  2013-07-17
# 984                              com.andrios.bodycards  2013-07-17
# 985                                   com.sportsoo.web  2013-07-17
# 986                                   org.prospekt0049  2013-07-17
# 987                                za.co.McCarthy.Audi  2013-07-17
# 988                   com.enlight.santaschristmaselves  2013-07-17
# 989  com.gau.go.launcherex.theme.gowidget.taskmanag...  2013-07-17
# 990                                com.gw2.legendaries  2013-07-17
# 991                             com.dontpanic.lpp.cyan  2013-07-17
# 992                br.com.mobileninjas.pensamentododia  2013-07-17
# 993                        com.custom.lwp.BridgeLights  2013-07-17
# 994     com.uefa.football.champiansleague.europe.messi  2013-07-17
# 995                    com.gcsresearch.burkebiketrails  2013-07-17
# 996                                     com.Wallpaper2  2013-07-17
# 997                             pt.tmn.android.vamosla  2013-07-17
# 998                      com.mymobilebookshelf.dracula  2013-07-17
#
#                                        related1  \
# 0                            com.aitype.android
# 1       com.blockdot.universal.truffulaShuffula
# 2                                 air.WatchESPN
# 3                        com.almalence.hdr_plus
# 4                      com.drawcoolman.net.cars
# 5             com.BahagHariArts.BlueNeonGoTheme
# 6                             cloudtv.hdwidgets
# 7                   cloudtv.hdthemes.colourform
# 8    com.akdevelopment.dict.enchinesesimpl.free
# 9            air.com.longo.Xiangqi.android.free
# 10                          com.apdroid.tabtalk
# 11                                   bn.ereader
# 12                      com.afinc.musicparadise
# 13         com.ani.apps.texts.facebook.statuses
# 14                        com.bellyflop.android
# 15                            com.aceviral.agrr
# 16                  air.net.daum.kids.kidsbasic
# 17      com.CreativeDK.LeagueofLegendsChampions
# 18                com.fgol.HungrySharkEvolution
# 19     com.a62563803550827198bd5ee4a.a68089272a
# 20                    com.ellevsoft.socialframe
# 21            com.BahagHariArts.BlueNeonGoTheme
# 22                         com.alt12.pinkpadpro
# 23              com.ArtInGames.AirAttackHDPart2
# 24      com.thepandasteam.criteresdiagnostiques
# 25                               com.alek.smile
# 26                               com.alek.smile
# 27                           com.aitype.android
# 28                              com.bwx.bequick
# 29         com.gau.go.launcherex.theme.Cosmic.E
# ..                                          ...
# 969                     com.acrossair.tvguideuk
# 970            com.adw.clock_ice_cream_sandwich
# 971                       com.SkyLiveWallpapers
# 972  au.com.weatherzone.android.weatherzoneplus
# 973      com.gau.go.launcherex.theme.droidglass
# 974                  com.androidtrainer.survive
# 975                       com.bigduckgames.flow
# 976                     com.acrossair.tvguideuk
# 977                            com.anifree.rain
# 978          OCTech.Mobile.Applications.OBDLink
# 979                  com.ellisapps.wwrestaurant
# 980                 com.TouchSpots.CallTimerPro
# 981                   ccc.chess.gui.chessforall
# 982                                     and.p2l
# 983                  com.aitype.android.lang.ar
# 984                           com.exercises.pro
# 985                                 atpwta.live
# 986              com.abbyy.mobile.lingvo.market
# 987                   com.aaa.android.discounts
# 988                 com.appsilicious.wallpapers
# 989                                   com.anydo
# 990                   com.aaa.android.discounts
# 991                           cloudtv.hdwidgets
# 992     appinventor.ai_leandroavila.ChicoXavier
# 993  com.jetblacksoftware.xmastreewallpaperpaid
# 994                        bic.ronaldo.cronaldo
# 995                     com.esri.android.client
# 996                              com.androidesk
# 997              br.com.rommel.detectormentiras
# 998      au.com.tinmangames.sl1.vampire.android
#
#                                               related2  \
# 0                                 com.aitype.android.p
# 1                                 com.byril.battleship
# 2                      com.advancedmobile.android.ghin
# 3                    com.flavionet.android.camera.lite
# 4                            com.drawmonsters.net.dogs
# 5                         com.SolarSpark.DotLockerLite
# 6                                 com.anddoes.launcher
# 7                                    cloudtv.hdwidgets
# 8            com.akdevelopment.dict.enchinesetrad.free
# 9                                       chschess.chess
# 10                                    com.badoo.mobile
# 11                                            com.Time
# 12                                  com.audioaddict.jr
# 13                                com.discovercircle10
# 14                                 com.bestbuy.android
# 15                           com.aceviral.angrygranrun
# 16                                com.howtolisten.main
# 17                                     com.K19media.tv
# 18                                 com.fgol.grabatron1
# 19                         com.activaweb.matchendirect
# 20                                            com.keek
# 21                com.gau.go.launcherex.theme.halskull
# 22                            com.ammobile.acupressure
# 23                     com.bestcoolfungames.antsmasher
# 24                                                 NaN
# 25                              com.ani.apps.jokes.sms
# 26                                 com.andrwq.recorder
# 27                                com.aitype.android.p
# 28                                     com.bwx.quicker
# 29                    com.gau.go.launcherex.theme.Dark
# ..                                                 ...
# 969                                   com.audio.police
# 970  com.andbling.wallpaper.live.clock.analog.cool....
# 971          com.androidwasabi.livewallpaper.dandelion
# 972                       com.accuweather.paid.android
# 973                               com.gtp.nextlauncher
# 974                    com.ani.apps.idioms.and.phrases
# 975                       com.bigduckgames.flowbridges
# 976                        com.dailymotion.dailymotion
# 977                          com.apalon.pimpyourscreen
# 978                              Scantech.CarGaugeLite
# 979                    com.fitnesskeeper.runkeeper.pro
# 980                               com.aitype.android.p
# 981                          chessbase.android.chessdb
# 982                                          com.anydo
# 983                        com.aitype.android.tablet.p
# 984                       com.gowithmyflow.workoutfull
# 985                                  com.bskyb.fbscore
# 986               com.andrewshu.android.redditdonation
# 987                           com.amazon.mShop.android
# 988                            com.dancingsquirrel.elf
# 989                          com.artemzin.android.love
# 990                       com.charrbucks.gw2.countdown
# 991                           com.anddoes.fancywidgets
# 992             com.appeducativo.mensagensdosespiritos
# 993                              com.joko.lightgridpro
# 994                                  com.afl.ucom.view
# 995                          com.esri.arcgis.collector
# 996          com.androidwasabi.livewallpaper.dandelion
# 997                             com.airunapps.animales
# 998                          com.content.books.dracula
#
#                                         related3  \
# 0                      com.aitype.android.tablet
# 1                     com.disney.TempleRunOz.goo
# 2                            com.bskyb.sportnews
# 3                          com.kth.PuddingCamera
# 4                   com.drawmonsters.net.zombies
# 5                           com.anddoes.launcher
# 6                        com.campmobile.launcher
# 7                       com.anddoes.fancywidgets
# 8             com.akdevelopment.dict.enthai.free
# 9                         cn.voilet.chinesechess
# 10                                     com.co_mm
# 11                              com.devhd.feedly
# 12                           com.audioaddict.sky
# 13                           com.facebook.katana
# 14                     com.birbeck.starbuckscard
# 15            com.crescentmoongames.redline_rush
# 16                    com.lguplus.videoeducation
# 17                          com.activision.elite
# 18                                com.fgol.shark
# 19                          com.cricbuzz.android
# 20                     com.leparisien.leparisien
# 21          com.gau.go.launcherex.theme.mystical
# 22                    com.aslibra.familyDoctorTW
# 23               com.centralbytes.forgottentales
# 24                                           NaN
# 25                     com.anjokes.apps.jokes.de
# 26                          com.apps.bodyboardsb
# 27                   com.aitype.android.tablet.p
# 28                            com.dianxinos.dxbs
# 29         com.gau.go.launcherex.theme.Z.Lighter
# ..                                           ...
# 969                    com.dancingsquirrel.giant
# 970                 com.idtech.widgets.blueclock
# 971       com.androidwasabi.livewallpaper.s4leaf
# 972                           com.adcoms.Weather
# 973   com.jetblacksoftware.xmastreewallpaperpaid
# 974                                 com.duolingo
# 975                        com.bitmango.flowline
# 976                                      com.he2
# 977                   com.commind.bubbles.donate
# 978                         Scantech.CarGaugePro
# 979                            com.fitnow.loseit
# 980                         com.cozi.androidfree
# 981              com.epekware.wordhelpforfriends
# 982                    com.doodleapp.zy.easynote
# 983                      com.appflute.love.poems
# 984                 com.manatlan.apps.sevenminfw
# 985                          com.bskyb.sportnews
# 986                               com.dictionary
# 987                      com.appturbo.appturboCA
# 988                    com.dancingsquirrel.giant
# 989   com.gau.go.launcherex.gowidget.taskmanager
# 990                   com.combustion.dragontimer
# 991            com.anddoes.fancywidgets.unlocker
# 992                      com.appturbo.appturboBR
# 993                    com.live.wallpaper.autumn
# 994                 com.appshen.frameworks.blade
# 995                               com.gcs.mapsVT
# 996  com.certificomobile.virginmarylivewallpaper
# 997                      com.appturbo.appturboSE
# 998              com.drawinghand.net.monsterhigh
#
#                                              related4  \
# 0                           com.beansoft.keyboardplus
# 1                           com.ea.game.simpsons4_row
# 2                             com.dogmac.SportsCenter
# 3                                 com.magix.camera_mx
# 4                         com.drawtube.net.angrybirds
# 5                             com.campmobile.launcher
# 6                    com.chrislacy.actionlauncher.pro
# 7                   com.anddoes.fancywidgets.unlocker
# 8    com.bravolol.bravolang.englishchinesecdictionary
# 9                       com.DreamFactory.ChineseChess
# 10                           com.handmark.tweetcaster
# 11                                         com.eterno
# 12                             com.aupeo.AupeoNextGen
# 13                                  com.facebook.orca
# 14                       com.birbeck.starbuckscardpro
# 15                                 com.droidhen.duck2
# 16                         com.nhn.android.phrasebook
# 17                            com.allocine.androidapp
# 18                                    com.fgol.shark2
# 19                              com.espn.score_center
# 20                             com.linternaute.cartes
# 21          com.golocker.theme.template.pinkbutterfly
# 22                   com.ensight.android.soundmassage
# 23                                   com.dotemu.rtype
# 24                                                NaN
# 25                     com.aura.ringtones.auraanimals
# 26               com.cricket.shima.handset.android.v1
# 27                  com.android.inputmethod.norwegian
# 28                            com.dianxinos.dxbs.paid
# 29                           com.jiubang.goscreenlock
# ..                                                ...
# 969             com.garettrogers.android.bigbrother12
# 970                       com.idtech.widgets.redclock
# 971           com.androidwasabi.livewallpaper.xperiaz
# 972                                   com.aws.android
# 973                             com.joko.lightgridpro
# 974                       com.ergonlabs.SabbathSchool
# 975                       com.bitmango.flowlinebranch
# 976                              com.iconnect.app.pts
# 977                                        com.dc.mhp
# 978                                 Scantech.Terminal
# 979                com.fourtechnologies.mynetdiary.ad
# 980                                com.gary.NoTePases
# 981                          com.google.android.chess
# 982                         com.guidedways.android2do
# 983                     com.droidworld.asagradabiblia
# 984                                   com.maxcapacity
# 985                              com.cricbuzz.android
# 986                           com.embiq.osfm_historia
# 987                           com.appturbo.appturboUK
# 988                        com.google.android.youtube
# 989              com.gau.go.launcherex.theme.BearLove
# 990                               com.dccomics.comics
# 991                      com.dustinb.theme.cyancobalt
# 992                           com.appturbo.appturboES
# 993              com.marieluke.stonecuttersnight.free
# 994                 com.blueskyapps.worldcupcountdown
# 995                            com.greatclips.android
# 996           com.flyingfox.supercube_virginmary_free
# 997                            com.greatclips.android
# 998                      com.drawmonsters.net.zombies
#
#                                               related5  \
# 0                              com.cootek.smartinputv5
# 1                             com.eamobile.life_row_wf
# 2                              com.fivemobile.thescore
# 3                          com.neaststudios.procapture
# 4                         com.ecapycsw.onetouchdrawing
# 5                            com.gau.go.launcherex.key
# 6                       com.czarnomorski.theme.dcikonz
# 7                         com.custom.lwp.LBeautifulSea
# 8                                          com.dict.ec
# 9                              com.aichess.googlechess
# 10                    com.handmark.tweetcaster.premium
# 11                    com.google.android.apps.currents
# 12                                        com.e8tracks
# 13                          com.giannz.photodownloader
# 14                                     com.hsn.android
# 15                              com.eig.carsandgunsvip
# 16                      com.nhn.android.phrasebookplus
# 17                                    com.blizzard.wow
# 18                                     com.fgol.shark3
# 19                        com.fasterthanmonkeys.iscore
# 20                          com.mobilnet.decor.gp.line
# 21                       com.jb.gosms.theme.aPonyTheme
# 22                  com.fourtechnologies.mynetdiary.ad
# 23                        com.dreamstudio.epicdefense2
# 24                                                 NaN
# 25                                    com.cramzy.jokes
# 26                                 com.foncannoninc.wc
# 27                           com.beansoft.keyboardplus
# 28               com.geekyouup.android.widgets.battery
# 29                 com.jiubang.goscreenlock.theme.Halo
# ..                                                 ...
# 969                              com.hottrix.imilkfree
# 970                          com.jiubang.lwp.moonstone
# 971                     com.appelves.gun.wallpapers.hd
# 972                              com.aws.android.elite
# 973                              com.joko.paperlandpro
# 974                            com.heku.readingtrainer
# 975                        com.bitmango.flowlinebridge
# 976                     com.incredibleapp.wallpapershd
# 977                            com.dkeesto.digitalflux
# 978                                com.ScanMyOpel.Main
# 979                              com.mapmyrun.android2
# 980                        com.ghostpattern.gwcalendar
# 981                                com.kalab.pgnviewer
# 982                        com.handyapps.tasksntodos10
# 983                     com.droidworld.lasagradabiblia
# 984                               com.northpark.situps
# 985                              com.espn.score_center
# 986                                    com.gyc.ace.kjv
# 987                                    com.autoscout24
# 988                     com.incredibleapp.wallpapershd
# 989  com.gau.go.launcherex.theme.appwidget.taskmana...
# 990                       com.domino.gw2.dressing.room
# 991                   com.fede.launcherproplusunlocker
# 992                            com.appturbo.appturboMX
# 993                    com.marieluke.tsiangmaroad.free
# 994                            com.fivemobile.thescore
# 995                              com.h3r3t1c.onnandbup
# 996          com.gannicus.android.tablet.wallpapersbay
# 997                           com.ityis.mobile.recetas
# 998                     com.gp.dracen.AOTJVEEDGEZCKFLT
#
#                                               related6  \
# 0                                    com.dasur.slideit
# 1                  com.gameloft.android.ANMP.GloftLVMK
# 2                            com.goldsteintech.android
# 3                              com.nhn.android.ncamera
# 4                   com.flexsolution.scratchguess.logo
# 5                  com.gau.go.launcherex.theme.WP7Blue
# 6                               com.dlto.atom.launcher
# 7                                 com.gtp.nextlauncher
# 8                                       com.dictionary
# 9                     com.alonsoruibal.chessdroid.lite
# 10                            com.hootsuite.droid.full
# 11                   com.google.android.apps.magazines
# 12                            com.google.android.music
# 13             com.handmark.friendcaster.plugin.aviary
# 14                                  com.ibotta.android
# 15                                   com.eig.papercars
# 16                             com.nozisim.checkkorean
# 17                             com.buchland.lolmemento
# 18                                  com.fgol.sharkfree
# 19                             com.fivemobile.thescore
# 20                    com.mylife.android.MyLifeRelease
# 21                         com.jb.gosms.theme.darkstar
# 22              com.hivebrain.andrewjohnson.weightloss
# 23                    com.dreamstudio.epicdefense2paid
# 24                                                 NaN
# 25                        com.drawtube.net.wildanimals
# 26                        com.fsp.android.phonetracker
# 27                         com.dasur.language.est.pack
# 28                                  com.jappka.bataria
# 29              com.jiubang.goscreenlock.theme.Monster
# ..                                                 ...
# 969                               com.invacore.damnlol
# 970       com.mehmetkoc.clockandroidalpha.androidalpha
# 971          com.gannicus.android.tablet.wallpapersbay
# 972                                com.gismeteo.client
# 973                                com.joko.photilepro
# 974  com.mobisystems.msdict.embedded.wireless.oxfor...
# 975                              com.bonfiremedia.dots
# 976                              com.momo.yuka.sexyleg
# 977                              com.joko.lightgridpro
# 978                            com.ScanMyOpelLite.Main
# 979                      com.popularapp.periodcalendar
# 980                               com.good.android.gfe
# 981                             com.kalab.pgnviewerpro
# 982                               com.ideal.backbundle
# 983                     com.dynamicg.timerecording.pro
# 984                                   com.rittr.situps
# 985                            com.fivemobile.thescore
# 986                                 com.merriamwebster
# 987                             com.chartcross.gpstest
# 988                        com.outfit7.talkingnewsfree
# 989                     com.gau.go.launcherex.theme.cb
# 990                         com.guildwarstemple.timers
# 991             com.gau.go.launcherex.theme.droidglass
# 992                        com.bobmarley.sistemafrases
# 993               com.maxelus.freshleaveslivewallpaper
# 994                     com.jalvasco.football.worldcup
# 995                               com.promt.pmtappfree
# 996                              com.srsdev.wallpapers
# 997             com.spodtronic.radio.energydeutschland
# 998    com.nadstech.achristmascarol.AOTTYFDXIPBAMSXMIV
#
#                                               related7  \
# 0                            com.dasur.slideit.vt.lite
# 1                                 com.imangi.templerun
# 2                                     com.golflogix.ui
# 3                                  com.oss.goodcamera2
# 4                            com.hitcents.stickmanepic
# 5        com.gau.go.launcherex.theme.defaultthemethree
# 6                                com.gau.go.launcherex
# 7                                com.joko.paperlandpro
# 8                         com.dreamob.android.encndict
# 9                                           com.cchess
# 10                              com.opera.mini.android
# 11                            com.handmark.mpp.gateway
# 12                          com.live365.mobile.android
# 13                            com.hootsuite.droid.full
# 14                       com.lafourchette.lafourchette
# 15                           com.funbox.game.angrypoke
# 16                         com.wonshinhyo.VocaRoidLite
# 17                            com.directv.dvrscheduler
# 18                                 com.fgol.sharkfree2
# 19                                   com.july.cricinfo
# 20                              com.orange.orangeetmoi
# 21                 com.jiubang.goscreenlock.theme.dark
# 22                 com.runtastic.android.heartrate.pro
# 23                         com.javaground.danteinferno
# 24                                                 NaN
# 25             com.kauf.soundboard.baum.FartSoundBoard
# 26                                        com.kii.safe
# 27                                   com.dasur.slideit
# 28           com.jasoncalhoun.android.systeminfowidget
# 29            com.jiubang.goscreenlock.theme.cardboard
# ..                                                 ...
# 969                                       com.kii.safe
# 970                             com.mjdev.analog_clock
# 971             com.gau.go.launcherex.theme.droidglass
# 972                        com.handmark.expressweather
# 973                       com.paranoid.preferences.pro
# 974          com.overdrive.mobile.android.mediaconsole
# 975                            com.chuslab.VariousFlow
# 976                   com.mspinc.sexygirllivewallpaper
# 977                          com.lithium.livewallpaper
# 978                              com.android_rsap.rsap
# 979                              com.runtastic.android
# 980                        com.google.android.calendar
# 981                      com.optimesoftware.chess.free
# 982                               com.jordyland.aesmap
# 983            com.greenleaf.android.translator.enru.c
# 984                              com.runtastic.android
# 985                     com.gotv.nflgamecenter.us.lite
# 986                         com.merriamwebster.premium
# 987                        com.eclipsim.gpstoolbox.pro
# 988                       com.outfit7.talkingsantafree
# 989                  com.gau.go.launcherex.theme.cblue
# 990                           com.lemondoo.placemyface
# 991                      com.jb.gokeyboard.theme.black
# 992                         com.gdacarv.app.amorporsms
# 993                             com.whatsapp.wallpaper
# 994                           com.lilait.oba.crronaldo
# 995                               com.promt.pmtappsale
# 996                        com.sunshineapps.virginmary
# 997                                 com.td.prisa.los40
# 998  com.nadstech.alicesadventuresinwonderland.AOTT...
#
#                                               related8  \
# 0                         com.fiberthemax.OpQ2keyboard
# 1                                com.imangi.templerun2
# 2                       com.ibm.events.android.masters
# 3                                         com.oss.mcam
# 4                        com.hitcents.stickmanepicfree
# 5                             com.jiubang.goscreenlock
# 6                            com.gau.go.launcherex.key
# 7                           com.tomanyz.lockWatchLight
# 8                           com.embermitre.hanping.app
# 9                            com.game.chinesechessfree
# 10                            com.plantpurple.emojidom
# 11                          com.huffingtonpost.android
# 12                          com.massimobiolcati.irealb
# 13                                            com.keek
# 14                            com.ocado.mobile.android
# 15                              com.geemzo.microracing
# 16                         kr.co.WaterbearSoft.muttagi
# 17                                        com.gzero.tv
# 18                                 com.fgol.sharkfree3
# 19                          com.mobilefootie.fotmobpro
# 20                          de.web.mobile.android.mail
# 21               com.packofthemes.gosmsprothemephoenix
# 22                 com.runtastic.android.pedometer.pro
# 23                               com.joblo.d2runewords
# 24                                                 NaN
# 25                               com.km.house.elephant
# 26                            com.megabytebomb.dowcipy
# 27                                   com.jb.gokeyboard
# 28                         com.latedroid.juicedefender
# 29                com.jiubang.goscreenlock.theme.color
# ..                                                 ...
# 969                                  com.livetv.russia
# 970                               com.painless.glclock
# 971                       com.jb.gokeyboard.theme.pink
# 972                        com.ilmeteo.android.ilmeteo
# 973                                  com.popbox.flurry
# 974                            com.pleco.chinesesystem
# 975                       com.currynurt.yetanotherflow
# 976             com.mspinc.sexygirlsbeachlivewallpaper
# 977                                 com.pvy.batterybar
# 978                                com.apdroid.tabtalk
# 979                com.runtastic.android.pedometer.pro
# 980                                   com.sec.spp.push
# 981                               com.pereira.analysis
# 982                                    com.kebab.Llama
# 983                             com.mikersmicros.fm_li
# 984                com.runtastic.android.pedometer.pro
# 985                           com.handmark.sportcaster
# 986                         com.standardworks.activity
# 987                             com.gami.agecalculator
# 988                 com.outfit7.talkingsantagingerfree
# 989  com.gau.go.launcherex.theme.gowidget.halloween...
# 990                   com.ligresoftware.gw2puzzleguide
# 991                 com.jb.gokeyboard.theme.siriCyangk
# 992                                com.jcvsoft.smsamor
# 993                                fishnoodle.aquarium
# 994                               com.lilait.oba.messi
# 995                                com.sileria.alsalah
# 996                                fishnoodle.aquarium
# 997                                com.td.prisa.maxima
# 998         com.nadstech.bramstoker.AOTTZEVCYYCATREXIN
#
#                                              related9  \
# 0                com.google.android.inputmethod.latin
# 1                 com.ludia.familyfeudandfriends.free
# 2                       com.ibm.events.android.usopen
# 3                                  com.superphotofull
# 4                                  com.omgpop.dstfree
# 5                             com.mobint.hololauncher
# 6                                com.gtp.nextlauncher
# 7                          fishnoodle.silhouette_free
# 8                     com.embermitre.hanping.app.lite
# 9                            com.google.android.chess
# 10                             com.spartancoders.gtok
# 11                     com.ideashower.readitlater.pro
# 12                             com.maxmpz.audioplayer
# 13                                        com.seesmic
# 14                           com.redaBenh.SosCocktail
# 15               com.imperialgamestudio.turbogrannies
# 16                  kr.cocone.android.listening.kr.en
# 17                                    com.imdb.mobile
# 18                          com.fridayapps.sharksmack
# 19                            com.mobilefootie.wc2010
# 20                          info.mkplan.lineCuteStamp
# 21               com.ratana.jazzcat.mysticalskullfree
# 22                         com.runtastic.android.pro2
# 23                    com.littlekillerz.legendsarcana
# 24                                                NaN
# 25                     com.outfit7.tomlovesangelafree
# 26                            com.ninegag.android.app
# 27                               com.nuance.swype.dtc
# 28                 com.metago.astro.network.bluetooth
# 29                com.jiubang.goscreenlock.theme.dark
# ..                                                ...
# 969                     com.maxmpz.audioplayer.unlock
# 970                                      com.rtsw.mcw
# 971                         com.launchertheme.kxnt.ui
# 972                   com.ilmeteo.android.ilmeteoplus
# 973                             com.srsdev.wallpapers
# 974                  com.storytoys.Farm123.GooglePlay
# 975                             com.free.flow.circuit
# 976                com.mspinc.sexygirlslivewallpapers
# 977                                  com.softspb.time
# 978                         com.mxtech.videoplayer.ad
# 979                        com.runtastic.android.pro2
# 980                         com.studiokuma.callfilter
# 981                        com.realvnc.viewer.android
# 982                                  com.lexa.fakegps
# 983                        com.mobizfun.holyquranlite
# 984                 com.skyhealth.fitnessbuddyandroid
# 985                         com.mobitv.client.nfl2010
# 986                                   com.tecarta.amp
# 987                         com.goldsteintech.android
# 988                                      com.peel.app
# 989   com.gau.go.launcherex.theme.gowidget.pinkwidget
# 990                      com.panasonic.pavc.viera.nrc
# 991                com.jb.gosms.pctheme.siricyangosms
# 992                             com.kukinet.encourage
# 993                                fishnoodle.koipond
# 994                                     com.livescore
# 995                                    com.smsBlocker
# 996                          fishnoodle.aquarium_free
# 997                          de.burgerking.kingfinder
# 998  com.nadstech.davidcopperfield.AOTUSDJMYXFANKTWIQ
#
#                                              related10  \
# 0                                    com.jb.gokeyboard
# 1                                     com.nekki.vector
# 2                           com.mobilefootie.fotmobpro
# 3                          com.wheadon.photoenhancepro
# 4                       com.openmygame.games.kr.client
# 5                                      com.spb.shell3d
# 6                              com.mobint.hololauncher
# 7                                 jmbc.timeWidget.lite
# 8                          com.movinapp.dict.enzh.free
# 9                 com.jns.game.socialchinesechess.free
# 10                                com.syncme.syncmeapp
# 11                              com.instapaper.android
# 12                                   com.maxxt.pcradio
# 13                              com.spartancoders.gtok
# 14                       com.retailconvergence.ruelala
# 15           com.imperialgamestudio.turbogrannies_lite
# 16                       kr.cocone.android.robot.ko.en
# 17                            com.microsoft.smartglass
# 18                 com.gameloft.android.ANMP.GloftFDHM
# 19                            com.protrade.sportacular
# 20                               jp.naver.line.android
# 21             com.themesfordroid.leopardthemegolocker
# 22                     com.runtastic.android.situp.pro
# 23         com.square_enix.android_googleplay.FFIII_GP
# 24                                                 NaN
# 25               com.pxlapps.app.android.soundeffects3
# 26                       com.outfit7.talkingangelafree
# 27                  com.nvdevelopment.dict.etrumt.free
# 28       com.socialnmobile.dictapps.notepad.color.note
# 29         com.jiubang.goscreenlock.theme.interstellar
# ..                                                 ...
# 969                          com.mobo.video.player.pro
# 970                            com.stylish.live.clocks
# 971                          com.live.wallpaper.autumn
# 972                       com.lachainemeteo.androidapp
# 973                                 com.ss.launcher.to
# 974                             com.touchtype.swiftkey
# 975                     com.gold_stone_studio.flow8013
# 976                      com.mspinc.sexygirlswallpaper
# 977                              com.tomanyz.lockWatch
# 978                         com.mxtech.videoplayer.pro
# 979        com.sportstracklive.android.ui.activity.pro
# 980                de.foobarsoft.calendareventreminder
# 981                                     com.zen.chess1
# 982                             com.lexa.fakegpsdonate
# 983                     com.sedevelop.dict.enrufl.free
# 984              com.skyhealth.fitnessbuddyandroidfree
# 985                   com.ojground.worldjscore.android
# 986                                  com.tecarta.bible
# 987                       com.visionobjects.calculator
# 988                                 com.picsart.studio
# 989                     com.jb.mms.theme.valentinelove
# 990                      com.suredigit.gw2.tradingpost
# 991                       com.levelup.beautifulwidgets
# 992                    com.outfit7.tomslovelettersfree
# 993                            fishnoodle.koipond_free
# 994                              com.mappd.footballcup
# 995  com.unitedinternet.portal.android.onlinestorag...
# 996                                    fishnoodle.fire
# 997                              de.fastline.kinoradar
# 998  com.nadstech.elretratodedoriangray.AOTULDITFZS...
#
#                                        related11  \
# 0                           com.nuance.swype.dtc
# 1                       com.noodlecake.happyjump
# 2                  com.myleaderboard.GolfChannel
# 3       com.zeronoiseapps.secretvideorecorderpro
# 4                          com.scoompa.dstassist
# 5                       com.teslacoilsw.launcher
# 6                     com.mobint.hololauncher.hd
# 7             jp.co.vibe.weatherskylivewallpaper
# 8                        com.pleco.chinesesystem
# 9                         com.mobirix.chess.wgmf
# 10                                  com.twidroid
# 11                     com.usatoday.android.news
# 12                           com.pandora.android
# 13                          com.syncme.syncmeapp
# 14                                     com.slice
# 15                        com.junerking.birdjump
# 16                   net.daum.android.dictionary
# 17                               com.orange.owtv
# 18           com.gameloft.android.ANMP.GloftSRHM
# 19                              com.swingbyswing
# 20                  jp.quan_inc.drawsticker.main
# 21        com.xllusion.livewallpaper.horrornight
# 22              com.runtastic.android.squats.pro
# 23            com.topfreegames.bikeracefreeworld
# 24                                           NaN
# 25                            com.sis.adultjokes
# 26                com.outfit7.tomlovesangelafree
# 27               com.sedevelop.dict.eneston.free
# 28                   imoblife.memorybooster.full
# 29     com.jiubang.goscreenlock.theme.one.getjar
# ..                                           ...
# 969                        com.photomontagerfull
# 970            com.the7art.flowerparadewallpaper
# 971              com.maxelus.colorslivewallpaper
# 972                          com.macropinch.swan
# 973                 com.teragon.skyatdawnlw.lite
# 974           com.touchtype.swiftkey.tablet.full
# 975            com.pilotfishmediainc.flowconnect
# 976                 com.mspinc.sexygirlwallpaper
# 977                              jmbc.timeWidget
# 978                          com.prizmos.carista
# 979                                   com.strava
# 980               de.sandnersoft.Arbeitskalender
# 981                           com.zetty.wordtalk
# 982                  com.michaels.michaelsstores
# 983                            com.taptu.streams
# 984          com.tinymission.dailyabworkoutfree1
# 985                     com.protrade.sportacular
# 986                              com.tecarta.msg
# 987                                     com.waze
# 988                         com.samsung.mediahub
# 989                        com.jbapps.contactpro
# 990                          hoovercj.gw2craftdb
# 991                     com.rrr.theme.CyanbreadX
# 992            com.workpail.inkpad.notepad.notes
# 993                        fishnoodle.night_city
# 994                   com.mobilefootie.fotmobpro
# 995               com.vistechprojects.planimeter
# 996                           fishnoodle.koipond
# 997                        de.filmstarts.android
# 998  com.nadstech.olivertwist.AOTUYEHUNCWCFZMSTO
#
#                                             related12  \
# 0                              com.nuance.swype.trial
# 1          com.retrodreamer.IceCreamJump.android.free
# 2                            com.protrade.sportacular
# 3                         jp.naver.linecamera.android
# 4                            com.timeplusq.drawnguess
# 5                   com.wed.go.launcherex.theme.plate
# 6                                     com.photox.jbhd
# 7                   net.hubalek.android.makeyourclock
# 8                       fr.nghs.android.dictionnaires
# 9                               com.tosmart.chessroad
# 10                                com.yuplee.birthday
# 11                                  com.verge.android
# 12                                           com.vevo
# 13                               com.tektrify.iloader
# 14                             com.surfwax.couponsapp
# 15                                 com.noodlecake.ssg
# 16                         net.pororo.pororoflashcard
# 17                                       com.peel.app
# 18                             com.hyperkani.sliceice
# 19    com.yahoo.mobile.client.android.fantasyfootball
# 20                    jp.quan_inc.lovesticker.android
# 21                        go.sms.pro.theme.pink.zebra
# 22                         com.tmsoft.whitenoise.full
# 23                     de.mobilebits.soulcraftdefault
# 24                                                NaN
# 25                                 com.sis.funnyjokes
# 26                            com.smartanuj.hideitpro
# 27                         com.vision.android.estonia
# 28                          mobi.infolife.uninstaller
# 29                 com.jiubang.goscreenlock.theme.ray
# ..                                                ...
# 969                                com.sphinx.lolpics
# 970                              jmbc.timeWidget.lite
# 971                             com.srsdev.wallpapers
# 972                          com.wetter.androidclient
# 973                               fishnoodle.jumpgate
# 974                         com.usatoday.android.news
# 975                           com.tiltangames.flowmax
# 976                      com.rhythmnewmedia.android.e
# 977  jp.main.kurousa.android.livewallpaper.DeviceInfo
# 978           de.softxperience.android.noteeverything
# 979                        com.tmsoft.whitenoise.full
# 980                             jp.co.johospace.jorte
# 981                             info.ghteam.kidsgames
# 982                                 com.octabode.dcfd
# 983                                     flipboard.app
# 984                com.tinymission.dailyabworkoutpaid
# 985                                     com.scores365
# 986                                  com.tecarta.nasb
# 987                             de.mobile.android.app
# 988                      com.sdgtl.mediahub.tmo.vplus
# 989              com.jiubang.goscreenlock.theme.cyrix
# 990                 org.gnejs.app.swtor.companion.pro
# 991                       com.sonny.theme.sublimecyan
# 992                             de.mobile.android.app
# 993                             fishnoodle.silhouette
# 994                                com.sabakat.vubooo
# 995                         de.einsundeins.smartdrive
# 996                           fishnoodle.koipond_free
# 997                         de.krankikom.uci_kinowelt
# 998                com.panaceasupplies.android.reader
#
#                                              related13  \
# 0                  com.thaicomcenter.android.tswipepro
# 1                                           me.pou.app
# 2                             com.shotzoom.golfshotgps
# 3                     uk.co.neilandtheresa.NewVignette
# 4                      com.zynga.draw2.googleplay.free
# 5                                     org.adw.launcher
# 6                                        kov.theme.ics
# 7                        nl.jsource.retroclock.android
# 8                                livio.pack.lang.en_US
# 9                                 com.vndynapp.cotuong
# 10                          de.web.mobile.android.mail
# 11                     com.zinio.mobile.android.reader
# 12                                    de.radio.android
# 13                                    mobi.bcam.mobile
# 14                                com.thorntons.finder
# 15                      com.runningrico.alienvszombies
# 16                      net.pororo.pororosongphonefree
# 17                          com.slingmedia.slingPlayer
# 18                     com.incrementalsoft.greedymouse
# 19                                   fiverings.snooker
# 20                             jp.quan_inc.stickershop
# 21                               org.adwfreak.launcher
# 22                                     com.tsubomaster
# 23                    free.littlekillerz.legendsarcana
# 24                                                 NaN
# 25                                 com.smartanuj.jokes
# 26                        com.zombodroid.MemeGenerator
# 27                            inputmethod.latin.ported
# 28                                 org.gpo.greenpower2
# 29           com.jiubang.goscreenlock.theme.santaclaus
# ..                                                 ...
# 969                        com.theronrogers.vaultyfree
# 970                             kuba.livewall.geoclock
# 971                         com.submad.summercity.free
# 972            com.yahoo.mobile.client.android.weather
# 973                              fishnoodle.storm_free
# 974                                    com.youdao.dict
# 975                                      jp.gungho.pad
# 976                                       com.thechive
# 977  jp.main.kurousa.android.livewallpaper.DeviceIn...
# 978                                   org.prowl.torque
# 979                          com.ultimate.points.diary
# 980                                   mikado.bizcalpro
# 981                                   org.scid.android
# 982                             com.punsoftware.backup
# 983                                      org.lds.ldssa
# 984                  com.tinymission.dailyworkoutsfree
# 985                                      com.thuuz.gtv
# 986                                    com.tecarta.nlt
# 987                                   org.prowl.torque
# 988                                     com.sketchbook
# 989                com.rechild.advancedtaskkillerfroyo
# 990                   org.kaptkaos.gw2.fieldguide.free
# 991                  com.wed.go.launcherex.theme.plate
# 992                      es.intelectiva.imgfrasesamor2
# 993                                fishnoodle.snowfall
# 994                                de.fcbayern.android
# 995                                  javalc6.thesaurus
# 996                                   kov.theme.tersus
# 997                             de.radio.android.prime
# 998                       com.redbrickks.horrorstories
#
#                                     related14  \
# 0           inputmethod.latin.perfectkeyboard
# 1                          no.dirtybit.funrun
# 2                            com.swingbyswing
# 3        uk.co.neilandtheresa.VignetteNewDemo
# 4                   quess.song.music.pop.quiz
# 5                       org.adwfreak.launcher
# 6                            org.adw.launcher
# 7                           org.zooper.zwfree
# 8     socialnmobile.dictdata.bible.dictionary
# 9                  com.xidea.ChineseDarkChess
# 10                              org.antivirus
# 11                               flipboard.cn
# 12                               hr.podlanica
# 13                 net.eworldui.videouploader
# 14                                fr.fnac.com
# 15              com.sillycube.android.Rushing
# 16                 net.sokum.englishstudycast
# 17                               com.tvnu.app
# 18              com.rovio.amazingalex.premium
# 19           mobi.sportstap.android.sportstap
# 20                 nfadev.sn.immnavigatorlite
# 21   theme.go.launcherex.theme.pink.butterfly
# 22           digifit.virtuagym.client.android
# 23                games.laylio.mightydungeons
# 24                                        NaN
# 25                       jokes.santabanta.com
# 26                             de.tvspielfilm
# 27               net.cdeguet.smartkeyboardpro
# 28                   org.kman.BluetoothWidget
# 29        com.tracio.apps.magic.touch.lighter
# ..                                        ...
# 969              com.zombodroid.MemeGenerator
# 970             nl.jsource.retroclock.android
# 971                           kov.theme.stark
# 972                   ru.yandex.weatherplugin
# 973                    me.everything.launcher
# 974                             org.lds.ldssa
# 975                           jp.naver.SJLGPP
# 976             kr.co.mokey.mokeywallpaper_v3
# 977   net.hubalek.android.gaugebattwidget.pro
# 978                      org.prowl.torquefree
# 979                     com.wsl.CardioTrainer
# 980                    org.koxx.pure_calendar
# 981            uk.co.aifactory.backgammonfree
# 982        com.wunderkinder.wunderlistandroid
# 983                                    org.m5
# 984                   comgowithmyflow.workout
# 985                      com.yahoo.cricket.ui
# 986                 com.wolfram.android.alpha
# 987                   p46.GPSTracking.Android
# 988                    com.textsfromlastnight
# 989         com.rechild.advancedtaskkillerpro
# 990           org.kaptkaos.gw2.fieldguide.pro
# 991             fr.clockwidget.lpclassicsense
# 992                      pt.lumberapps.frases
# 993                          fishnoodle.storm
# 994                           de.motain.iliga
# 995                    me.scan.android.client
# 996                         net.zedge.android
# 997               pt.ptinovacao.rma.meomobile
# 998                     com.ulabs.thegioisach
#
#                                       related15
# 0               net.cdeguet.smartkeyboardpro.ko
# 1                          org.orangenose.games
# 2                                com.v1.v1golf2
# 3                     vStudio.Android.Camera360
# 4                       tipitap.coloring.phones
# 5      theme.go.launcherex.theme.pink.butterfly
# 6                         org.adwfreak.launcher
# 7             sk.michalec.SimpleDigiClockWidget
# 8      socialnmobile.dictdata.english.irregular
# 9               com.zingmagic.chinesechessvfree
# 10                             org.mots.haxsync
# 11                 jp.co.yahoo.android.yjwidget
# 12                           mediau_full.player
# 13            net.eworldui.videouploader.adfree
# 14                               fr.snapp.fidme
# 15                         com.zagmoid.carrom3d
# 16                               start.FoodTime
# 17                               de.tvspielfilm
# 18   com.rovio.angrybirdsstarwarshd.premium.iap
# 19             say.hello.worldsnookernewsadfree
# 20                      pl.moniusoft.ispeedtest
# 21          themes.go.launcherex.theme.darkstar
# 22                        ipnossoft.rma.premium
# 23                     pl.idreams.CanKnockdown3
# 24                                          NaN
# 25                   talking.toy.funny.elephant
# 26                        yuku.mp3recorder.full
# 27             org.pocketworkstation.pckeyboard
# 28                         org.kman.WifiManager
# 29              com.yukka.livewallpaper.lighter
# ..                                          ...
# 969                       yuku.mp3recorder.full
# 970           sk.michalec.SimpleDigiClockWidget
# 971                           net.zedge.android
# 972                            yong.weather.pro
# 973                          opotech.image3Dlwp
# 974                            org.lds.ldstools
# 975                            slide.flowFrenzy
# 976                                 mobi.ifunny
# 977       net.hubalek.android.makeyourclock.pro
# 978                        org.prowl.torquescan
# 979                    name.file.wwplusfastfood
# 980                 org.koxx.pure_grid_calendar
# 981                   uk.co.aifactory.chessfree
# 982                org.ajeje.locationspooferpro
# 983                             sa.edu.ksu.Ayat
# 984                                  je.fit.pro
# 985                               pl.sport.live
# 986         com.wordwebsoftware.android.wordweb
# 987                    uk.co.nickfines.RealCalc
# 988                   vStudio.Android.Camera360
# 989                    de.dbware.circlelauncher
# 990            sirpali.gw2.tradepost.calculator
# 991               nl.jsource.retroclock.android
# 992                                 sms.prontas
# 993           mma.wallpaper.nativamericans.lite
# 994                              es.lfp.gi.main
# 995      uk.co.autotrader.androidconsumersearch
# 996    pterry.android.bibleverses.livewallpaper
# 997                       se.mtg.freetv.nova_bg
# 998                      com.wargomedia.dracula
#
# [999 rows x 17 columns]

# %% [markdown]
# # NEWDEVELOPER

# %%
@require(iter_json_gzip,gzip,datetime,re,csv)
def NEWDEVELOPER(file_in,out_base,compress=1):
    headers = ['app_id','date','dev_id']
    out_filename = out_base.format('NEWDEVELOPER')
    running = {}
    with gzip.open(out_filename,'wt',compress) as out_file:
        csv_writer = csv.writer(out_file)
        csv_writer.writerow(headers)
        for json in iter_json_gzip(file_in):
            developer = json.get('developer_id','')
            if isinstance(developer,str):
                developer = developer.strip()
                if running.get(json['app_id'],'')!=developer and len(developer)>0:
                    running[json['app_id']] = developer
                    day = datetime.datetime.fromtimestamp(int(json['timestamp']))\
                            .strftime('%Y-%m-%d')
                    obs = (json['app_id'],day,developer)
                    csv_writer.writerow(obs) 
    return out_filename

# %%
df_debug = None
if DEBUG:
    df_debug = read_csv(NEWDEVELOPER(RAW_FILE,OUT_BASE,COMPRESS_LEVEL),compression='gzip',header=0)
df_debug
# Out:
#                                                  app_id        date  \
# 0                                com.touchtype.swiftkey  2013-07-17
# 1                   com.gameloft.android.ANMP.GloftDMHM  2013-07-17
# 2                           com.ibm.events.android.usga  2013-07-17
# 3                                      com.dama.camera2  2013-07-17
# 4                           com.disney.scribblefree_goo  2013-07-17
# 5                                 com.gau.go.launcherex  2013-07-17
# 6                              com.teslacoilsw.launcher  2013-07-17
# 7                          com.levelup.beautifulwidgets  2013-07-17
# 8           com.socialnmobile.dictdata.chinese.stardict  2013-07-17
# 9                               com.mdb.android.xiangqi  2013-07-17
# 10                                   io.avocado.android  2013-07-17
# 11                                        flipboard.app  2013-07-17
# 12                      com.mobincube.android.app_20866  2013-07-17
# 13                                         com.at.proxi  2013-07-17
# 14                      shopcoffeetable.com.coffeetable  2013-07-17
# 15                          com.mini.flowers.angryfatty  2013-07-17
# 16                            com.and.Wuthering_Heights  2013-07-17
# 17                                     com.loltv.layout  2013-07-17
# 18                         com.stopnplayapps.angryshark  2013-07-17
# 19                           say.hello.worldsnookernews  2013-07-17
# 20                                com.wolterskluwer.lsq  2013-07-17
# 21           com.themesfordroid.hunterthemegolauncherex  2013-07-17
# 22                          com.boxyz.androidteam.tsubo  2013-07-17
# 23                             twig.nguyen.d2_runewords  2013-07-17
# 24                                           com.Netter  2013-07-17
# 25                                 com.gunvald.bigpenis  2013-07-17
# 26                                     com.prapps.tokay  2013-07-17
# 27                 com.quickmare.typingkeyboard.neurope  2013-07-17
# 28                      Technicaljar.BluetoothAppBinder  2013-07-17
# 29               com.jiubang.goscreenlock.theme.lighter  2013-07-17
# ...                                                 ...         ...
# 971                  com.miresoftware.sexyamateurs2free  2013-07-17
# 972             Alfasoft.Widgets.PsychedelicAnalogClock  2013-07-17
# 973                            com.Kaneosmare.BoeingC17  2013-07-17
# 974                                     adit.weather.ta  2013-07-17
# 975             com.andbling.wallpaper.live.names.ernie  2013-07-17
# 976              com.coreapps.android.followme.fetc2013  2013-07-17
# 977                             com.crossfield.frowline  2013-07-17
# 978                com.mspinc.sexygirllivewallpaperLite  2013-07-17
# 979                    org.guesswork.nightstand.digital  2013-07-17
# 980                                de.wgsoft.scanmaster  2013-07-17
# 981                    com.appsshoppe.hairlosstreatment  2013-07-17
# 982                                      com.mobizel.ra  2013-07-17
# 983                          com.buildingfive.pgnhelper  2013-07-17
# 984                                    com.oxxo.tiendas  2013-07-17
# 985                                    org.prospekt0048  2013-07-17
# 986                               com.andrios.bodycards  2013-07-17
# 987                                    com.sportsoo.web  2013-07-17
# 988                                    org.prospekt0049  2013-07-17
# 989                                 za.co.McCarthy.Audi  2013-07-17
# 990                    com.enlight.santaschristmaselves  2013-07-17
# 991   com.gau.go.launcherex.theme.gowidget.taskmanag...  2013-07-17
# 992                                 com.gw2.legendaries  2013-07-17
# 993                              com.dontpanic.lpp.cyan  2013-07-17
# 994                 br.com.mobileninjas.pensamentododia  2013-07-17
# 995                         com.custom.lwp.BridgeLights  2013-07-17
# 996      com.uefa.football.champiansleague.europe.messi  2013-07-17
# 997                     com.gcsresearch.burkebiketrails  2013-07-17
# 998                                      com.Wallpaper2  2013-07-17
# 999                              pt.tmn.android.vamosla  2013-07-17
# 1000                      com.mymobilebookshelf.dracula  2013-07-17
#
#                                     dev_id
# 0                                 SwiftKey
# 1                                 Gameloft
# 2     United+States+Golf+Association,+USGA
# 3                                JFDP+Labs
# 4                                   Disney
# 5                     GO+Launcher+Dev+Team
# 6                       TeslaCoil+Software
# 7                           LevelUp+Studio
# 8                                    Notes
# 9                            MDB+Softwares
# 10                  Avocado+Software,+Inc.
# 11                               Flipboard
# 12                                   Husic
# 13                            AboveThought
# 14                       Real+Valuable+LLC
# 15                            Mini+Flowers
# 16                               KijuI%26T
# 17                               Darr2cool
# 18                      Stop+'N'+Play+Apps
# 19                     sayhellowavegoodbye
# 20                   Wolters+Kluwer+France
# 21                        Themes+For+Droid
# 22                              Boxyz,inc.
# 23                             Twig+Nguyen
# 24                     Elsevier+Masson+SAS
# 25                          Mikkel+Gunvald
# 26                      PrApps+Development
# 27                       Quickmare+Studios
# 28                        Technicaljar.com
# 29                                  ZT.art
# ...                                    ...
# 971                          MiRE+Software
# 972                               Alfasoft
# 973                             kaneosmare
# 974                         MobiLog+Studio
# 975                                 Eelooz
# 976                              Core-apps
# 977                       Cross+Field+Inc.
# 978                               MSP+Inc.
# 979                      Digital+Guesswork
# 980                              WGSoft.de
# 981                               Infoapps
# 982                                Mobizel
# 983                          Building+Five
# 984                  Cadena+Comercial+OXXO
# 985                       Publishing+House
# 986                                Andrios
# 987                               Verbolsa
# 988                       Publishing+House
# 989                          CBR+Marketing
# 990                Kids+Christmas+Coloring
# 991                         GO+Launcher+EX
# 992                                 Ishtan
# 993                             Dont+Panic
# 994                          Mobile+Ninjas
# 995                              manum+app
# 996                                ASO+Lab
# 997                           GCS+Research
# 998                              SIGHTSOFT
# 999              PT+Comunica%C3%A7%C3%B5es
# 1000                     MyMobileBookshelf
#
# [1001 rows x 3 columns]

# %% [markdown]
# # NEWDEVELOPERNAME

# %%
@require(iter_json_gzip,gzip,datetime,re,csv)
def NEWDEVELOPERNAME(file_in,out_base,compress=1):
    headers = ['app_id','date','dev_name']
    out_filename = out_base.format('NEWDEVELOPERNAME')
    running = {}
    with gzip.open(out_filename,'wt',compress) as out_file:
        csv_writer = csv.writer(out_file)
        csv_writer.writerow(headers)
        for json in iter_json_gzip(file_in):
            developer = json.get('developer_name','')
            if isinstance(developer,str):
                developer = developer.strip()
                if running.get(json['app_id'],'')!=developer and len(developer)>0:
                    running[json['app_id']] = developer
                    day = datetime.datetime.fromtimestamp(int(json['timestamp']))\
                            .strftime('%Y-%m-%d')
                    obs = (json['app_id'],day,developer)
                    csv_writer.writerow(obs) 
    return out_filename

# %%
df_debug = None
if DEBUG:
    df_debug = read_csv(NEWDEVELOPERNAME(RAW_FILE,OUT_BASE,COMPRESS_LEVEL),compression='gzip',header=0)
df_debug
# Out:
#                                                  app_id        date  \
# 0                                com.touchtype.swiftkey  2013-07-17
# 1                   com.gameloft.android.ANMP.GloftDMHM  2013-07-17
# 2                           com.ibm.events.android.usga  2013-07-17
# 3                                      com.dama.camera2  2013-07-17
# 4                           com.disney.scribblefree_goo  2013-07-17
# 5                                 com.gau.go.launcherex  2013-07-17
# 6                              com.teslacoilsw.launcher  2013-07-17
# 7                          com.levelup.beautifulwidgets  2013-07-17
# 8           com.socialnmobile.dictdata.chinese.stardict  2013-07-17
# 9                               com.mdb.android.xiangqi  2013-07-17
# 10                                   io.avocado.android  2013-07-17
# 11                                        flipboard.app  2013-07-17
# 12                      com.mobincube.android.app_20866  2013-07-17
# 13                                         com.at.proxi  2013-07-17
# 14                      shopcoffeetable.com.coffeetable  2013-07-17
# 15                          com.mini.flowers.angryfatty  2013-07-17
# 16                            com.and.Wuthering_Heights  2013-07-17
# 17                                     com.loltv.layout  2013-07-17
# 18                         com.stopnplayapps.angryshark  2013-07-17
# 19                           say.hello.worldsnookernews  2013-07-17
# 20                                com.wolterskluwer.lsq  2013-07-17
# 21           com.themesfordroid.hunterthemegolauncherex  2013-07-17
# 22                          com.boxyz.androidteam.tsubo  2013-07-17
# 23                             twig.nguyen.d2_runewords  2013-07-17
# 24                                           com.Netter  2013-07-17
# 25                                 com.gunvald.bigpenis  2013-07-17
# 26                                     com.prapps.tokay  2013-07-17
# 27                 com.quickmare.typingkeyboard.neurope  2013-07-17
# 28                      Technicaljar.BluetoothAppBinder  2013-07-17
# 29               com.jiubang.goscreenlock.theme.lighter  2013-07-17
# ...                                                 ...         ...
# 971                  com.miresoftware.sexyamateurs2free  2013-07-17
# 972             Alfasoft.Widgets.PsychedelicAnalogClock  2013-07-17
# 973                            com.Kaneosmare.BoeingC17  2013-07-17
# 974                                     adit.weather.ta  2013-07-17
# 975             com.andbling.wallpaper.live.names.ernie  2013-07-17
# 976              com.coreapps.android.followme.fetc2013  2013-07-17
# 977                             com.crossfield.frowline  2013-07-17
# 978                com.mspinc.sexygirllivewallpaperLite  2013-07-17
# 979                    org.guesswork.nightstand.digital  2013-07-17
# 980                                de.wgsoft.scanmaster  2013-07-17
# 981                    com.appsshoppe.hairlosstreatment  2013-07-17
# 982                                      com.mobizel.ra  2013-07-17
# 983                          com.buildingfive.pgnhelper  2013-07-17
# 984                                    com.oxxo.tiendas  2013-07-17
# 985                                    org.prospekt0048  2013-07-17
# 986                               com.andrios.bodycards  2013-07-17
# 987                                    com.sportsoo.web  2013-07-17
# 988                                    org.prospekt0049  2013-07-17
# 989                                 za.co.McCarthy.Audi  2013-07-17
# 990                    com.enlight.santaschristmaselves  2013-07-17
# 991   com.gau.go.launcherex.theme.gowidget.taskmanag...  2013-07-17
# 992                                 com.gw2.legendaries  2013-07-17
# 993                              com.dontpanic.lpp.cyan  2013-07-17
# 994                 br.com.mobileninjas.pensamentododia  2013-07-17
# 995                         com.custom.lwp.BridgeLights  2013-07-17
# 996      com.uefa.football.champiansleague.europe.messi  2013-07-17
# 997                     com.gcsresearch.burkebiketrails  2013-07-17
# 998                                      com.Wallpaper2  2013-07-17
# 999                              pt.tmn.android.vamosla  2013-07-17
# 1000                      com.mymobilebookshelf.dracula  2013-07-17
#
#                                   dev_name
# 0                                 SwiftKey
# 1                                 Gameloft
# 2     United States Golf Association, USGA
# 3                                JFDP Labs
# 4                                   Disney
# 5                     GO Launcher Dev Team
# 6                       TeslaCoil Software
# 7                           LevelUp Studio
# 8                                    Notes
# 9                            MDB Softwares
# 10                  Avocado Software, Inc.
# 11                               Flipboard
# 12                                   Husic
# 13                            AboveThought
# 14                       Real Valuable LLC
# 15                            Mini Flowers
# 16                                 KijuI&T
# 17                               Darr2cool
# 18                      Stop 'N' Play Apps
# 19                     sayhellowavegoodbye
# 20                   Wolters Kluwer France
# 21                        Themes For Droid
# 22                              Boxyz,inc.
# 23                             Twig Nguyen
# 24                     Elsevier Masson SAS
# 25                          Mikkel Gunvald
# 26                      PrApps Development
# 27                       Quickmare Studios
# 28                        Technicaljar.com
# 29                                  ZT.art
# ...                                    ...
# 971                          MiRE Software
# 972                               Alfasoft
# 973                             kaneosmare
# 974                         MobiLog Studio
# 975                                 Eelooz
# 976                              Core-apps
# 977                       Cross Field Inc.
# 978                               MSP Inc.
# 979                      Digital Guesswork
# 980                              WGSoft.de
# 981                               Infoapps
# 982                                Mobizel
# 983                          Building Five
# 984                  Cadena Comercial OXXO
# 985                       Publishing House
# 986                                Andrios
# 987                               Verbolsa
# 988                       Publishing House
# 989                          CBR Marketing
# 990                Kids Christmas Coloring
# 991                         GO Launcher EX
# 992                                 Ishtan
# 993                             Dont Panic
# 994                          Mobile Ninjas
# 995                              manum app
# 996                                ASO Lab
# 997                           GCS Research
# 998                              SIGHTSOFT
# 999                        PT Comunicações
# 1000                     MyMobileBookshelf
#
# [1001 rows x 3 columns]

# %% [markdown]
# # NEWCATEGORY

# %%
@require(iter_json_gzip,gzip,datetime,re,csv)
def NEWCATEGORY(file_in,out_base,compress=1):
    headers = ['app_id','date','category']
    out_filename = out_base.format('NEWCATEGORY')
    running = {}
    with gzip.open(out_filename,'wt',compress) as out_file:
        csv_writer = csv.writer(out_file)
        csv_writer.writerow(headers)
        for json in iter_json_gzip(file_in):
            category = json.get('category','')
            if isinstance(category,str):
                category = category.strip().upper()
                if running.get(json['app_id'],'')!=category and len(category)>0:
                    running[json['app_id']] = category
                    day = datetime.datetime.fromtimestamp(int(json['timestamp']))\
                            .strftime('%Y-%m-%d')
                    obs = (json['app_id'],day,category)
                    csv_writer.writerow(obs)
    return out_filename

# %%
df_debug = None
if DEBUG:
    df_debug = read_csv(NEWCATEGORY(RAW_FILE,OUT_BASE,COMPRESS_LEVEL),compression='gzip',header=0)
df_debug
# Out:
#                                                  app_id        date  \
# 0                                com.touchtype.swiftkey  2013-07-17
# 1                   com.gameloft.android.ANMP.GloftDMHM  2013-07-17
# 2                           com.ibm.events.android.usga  2013-07-17
# 3                                      com.dama.camera2  2013-07-17
# 4                           com.disney.scribblefree_goo  2013-07-17
# 5                                 com.gau.go.launcherex  2013-07-17
# 6                              com.teslacoilsw.launcher  2013-07-17
# 7                          com.levelup.beautifulwidgets  2013-07-17
# 8           com.socialnmobile.dictdata.chinese.stardict  2013-07-17
# 9                               com.mdb.android.xiangqi  2013-07-17
# 10                                   io.avocado.android  2013-07-17
# 11                                        flipboard.app  2013-07-17
# 12                      com.mobincube.android.app_20866  2013-07-17
# 13                                         com.at.proxi  2013-07-17
# 14                      shopcoffeetable.com.coffeetable  2013-07-17
# 15                          com.mini.flowers.angryfatty  2013-07-17
# 16                            com.and.Wuthering_Heights  2013-07-17
# 17                                     com.loltv.layout  2013-07-17
# 18                         com.stopnplayapps.angryshark  2013-07-17
# 19                           say.hello.worldsnookernews  2013-07-17
# 20                                com.wolterskluwer.lsq  2013-07-17
# 21           com.themesfordroid.hunterthemegolauncherex  2013-07-17
# 22                          com.boxyz.androidteam.tsubo  2013-07-17
# 23                             twig.nguyen.d2_runewords  2013-07-17
# 24                                           com.Netter  2013-07-17
# 25                                 com.gunvald.bigpenis  2013-07-17
# 26                                     com.prapps.tokay  2013-07-17
# 27                 com.quickmare.typingkeyboard.neurope  2013-07-17
# 28                      Technicaljar.BluetoothAppBinder  2013-07-17
# 29               com.jiubang.goscreenlock.theme.lighter  2013-07-17
# ...                                                 ...         ...
# 971                  com.miresoftware.sexyamateurs2free  2013-07-17
# 972             Alfasoft.Widgets.PsychedelicAnalogClock  2013-07-17
# 973                            com.Kaneosmare.BoeingC17  2013-07-17
# 974                                     adit.weather.ta  2013-07-17
# 975             com.andbling.wallpaper.live.names.ernie  2013-07-17
# 976              com.coreapps.android.followme.fetc2013  2013-07-17
# 977                             com.crossfield.frowline  2013-07-17
# 978                com.mspinc.sexygirllivewallpaperLite  2013-07-17
# 979                    org.guesswork.nightstand.digital  2013-07-17
# 980                                de.wgsoft.scanmaster  2013-07-17
# 981                    com.appsshoppe.hairlosstreatment  2013-07-17
# 982                                      com.mobizel.ra  2013-07-17
# 983                          com.buildingfive.pgnhelper  2013-07-17
# 984                                    com.oxxo.tiendas  2013-07-17
# 985                                    org.prospekt0048  2013-07-17
# 986                               com.andrios.bodycards  2013-07-17
# 987                                    com.sportsoo.web  2013-07-17
# 988                                    org.prospekt0049  2013-07-17
# 989                                 za.co.McCarthy.Audi  2013-07-17
# 990                    com.enlight.santaschristmaselves  2013-07-17
# 991   com.gau.go.launcherex.theme.gowidget.taskmanag...  2013-07-17
# 992                                 com.gw2.legendaries  2013-07-17
# 993                              com.dontpanic.lpp.cyan  2013-07-17
# 994                 br.com.mobileninjas.pensamentododia  2013-07-17
# 995                         com.custom.lwp.BridgeLights  2013-07-17
# 996      com.uefa.football.champiansleague.europe.messi  2013-07-17
# 997                     com.gcsresearch.burkebiketrails  2013-07-17
# 998                                      com.Wallpaper2  2013-07-17
# 999                              pt.tmn.android.vamosla  2013-07-17
# 1000                      com.mymobilebookshelf.dracula  2013-07-17
#
#                  category
# 0            PRODUCTIVITY
# 1                  CASUAL
# 2                  SPORTS
# 3             PHOTOGRAPHY
# 4                   BRAIN
# 5         PERSONALIZATION
# 6         PERSONALIZATION
# 7         PERSONALIZATION
# 8     BOOKS_AND_REFERENCE
# 9                   BRAIN
# 10                 SOCIAL
# 11     NEWS_AND_MAGAZINES
# 12        MUSIC_AND_AUDIO
# 13                 SOCIAL
# 14               SHOPPING
# 15                 RACING
# 16              EDUCATION
# 17          ENTERTAINMENT
# 18                 ARCADE
# 19                 SPORTS
# 20                 SOCIAL
# 21        PERSONALIZATION
# 22     HEALTH_AND_FITNESS
# 23                 ARCADE
# 24                MEDICAL
# 25          ENTERTAINMENT
# 26          ENTERTAINMENT
# 27           PRODUCTIVITY
# 28           PRODUCTIVITY
# 29        PERSONALIZATION
# ...                   ...
# 971         ENTERTAINMENT
# 972       PERSONALIZATION
# 973       PERSONALIZATION
# 974               WEATHER
# 975       PERSONALIZATION
# 976   BOOKS_AND_REFERENCE
# 977                 BRAIN
# 978         ENTERTAINMENT
# 979       PERSONALIZATION
# 980         COMMUNICATION
# 981    HEALTH_AND_FITNESS
# 982              BUSINESS
# 983             EDUCATION
# 984                 TOOLS
# 985   BOOKS_AND_REFERENCE
# 986    HEALTH_AND_FITNESS
# 987                SPORTS
# 988   BOOKS_AND_REFERENCE
# 989             LIFESTYLE
# 990         ENTERTAINMENT
# 991          PRODUCTIVITY
# 992         ENTERTAINMENT
# 993       PERSONALIZATION
# 994             LIFESTYLE
# 995       PERSONALIZATION
# 996                SPORTS
# 997                 TOOLS
# 998       PERSONALIZATION
# 999         ENTERTAINMENT
# 1000  BOOKS_AND_REFERENCE
#
# [1001 rows x 3 columns]

# %% [markdown]
# # NEWPRICE

# %%
@require(iter_json_gzip,gzip,datetime,re,csv)
def NEWPRICE(file_in,out_base,compress=1):
    headers = ['app_id','date','price']
    out_filename = out_base.format('NEWPRICE')
    running = {}
    with gzip.open(out_filename,'wt',compress) as out_file:
        csv_writer = csv.writer(out_file)
        csv_writer.writerow(headers)
        for json in iter_json_gzip(file_in):
            price = str(json.get('price',''))
            if price =='0.00':
                price = '0'
            if running.get(json['app_id'],'')!=price and price != '.' and len(price)>0:
                running[json['app_id']] = price
                day = datetime.datetime.fromtimestamp(int(json['timestamp']))\
                        .strftime('%Y-%m-%d')
                obs = (json['app_id'],day,price)
                csv_writer.writerow(obs)
    return out_filename

# %%
df_debug = None
if DEBUG:
    df_debug = read_csv(NEWPRICE(RAW_FILE,OUT_BASE,COMPRESS_LEVEL),compression='gzip',header=0)
df_debug
# Out:
#                                                  app_id        date  price
# 0                                com.touchtype.swiftkey  2013-07-17   3.99
# 1                   com.gameloft.android.ANMP.GloftDMHM  2013-07-17   0.00
# 2                           com.ibm.events.android.usga  2013-07-17   0.00
# 3                                      com.dama.camera2  2013-07-17   2.99
# 4                           com.disney.scribblefree_goo  2013-07-17   0.00
# 5                                 com.gau.go.launcherex  2013-07-17   0.00
# 6                              com.teslacoilsw.launcher  2013-07-17   0.00
# 7                          com.levelup.beautifulwidgets  2013-07-17   2.59
# 8           com.socialnmobile.dictdata.chinese.stardict  2013-07-17   0.00
# 9                               com.mdb.android.xiangqi  2013-07-17   0.00
# 10                                   io.avocado.android  2013-07-17   0.00
# 11                                        flipboard.app  2013-07-17   0.00
# 12                      com.mobincube.android.app_20866  2013-07-17   0.00
# 13                                         com.at.proxi  2013-07-17   0.00
# 14                      shopcoffeetable.com.coffeetable  2013-07-17   0.00
# 15                          com.mini.flowers.angryfatty  2013-07-17   0.00
# 16                            com.and.Wuthering_Heights  2013-07-17   7.97
# 17                                     com.loltv.layout  2013-07-17   0.00
# 18                         com.stopnplayapps.angryshark  2013-07-17   0.00
# 19                           say.hello.worldsnookernews  2013-07-17   0.00
# 20                                com.wolterskluwer.lsq  2013-07-17   0.00
# 21           com.themesfordroid.hunterthemegolauncherex  2013-07-17   0.00
# 22                          com.boxyz.androidteam.tsubo  2013-07-17   4.75
# 23                             twig.nguyen.d2_runewords  2013-07-17   0.00
# 24                                           com.Netter  2013-07-17   0.00
# 25                                 com.gunvald.bigpenis  2013-07-17   0.00
# 26                                     com.prapps.tokay  2013-07-17   0.00
# 27                 com.quickmare.typingkeyboard.neurope  2013-07-17   0.00
# 28                      Technicaljar.BluetoothAppBinder  2013-07-17   0.00
# 29               com.jiubang.goscreenlock.theme.lighter  2013-07-17   0.00
# ...                                                 ...         ...    ...
# 971                  com.miresoftware.sexyamateurs2free  2013-07-17   0.00
# 972             Alfasoft.Widgets.PsychedelicAnalogClock  2013-07-17   0.00
# 973                            com.Kaneosmare.BoeingC17  2013-07-17   0.00
# 974                                     adit.weather.ta  2013-07-17   0.00
# 975             com.andbling.wallpaper.live.names.ernie  2013-07-17   0.99
# 976              com.coreapps.android.followme.fetc2013  2013-07-17   0.00
# 977                             com.crossfield.frowline  2013-07-17   0.00
# 978                com.mspinc.sexygirllivewallpaperLite  2013-07-17   0.00
# 979                    org.guesswork.nightstand.digital  2013-07-17   1.20
# 980                                de.wgsoft.scanmaster  2013-07-17   0.00
# 981                    com.appsshoppe.hairlosstreatment  2013-07-17   0.00
# 982                                      com.mobizel.ra  2013-07-17   0.00
# 983                          com.buildingfive.pgnhelper  2013-07-17   0.00
# 984                                    com.oxxo.tiendas  2013-07-17   0.00
# 985                                    org.prospekt0048  2013-07-17   0.99
# 986                               com.andrios.bodycards  2013-07-17   0.00
# 987                                    com.sportsoo.web  2013-07-17   0.00
# 988                                    org.prospekt0049  2013-07-17   0.99
# 989                                 za.co.McCarthy.Audi  2013-07-17   0.00
# 990                    com.enlight.santaschristmaselves  2013-07-17   0.00
# 991   com.gau.go.launcherex.theme.gowidget.taskmanag...  2013-07-17   0.00
# 992                                 com.gw2.legendaries  2013-07-17   0.00
# 993                              com.dontpanic.lpp.cyan  2013-07-17   0.00
# 994                 br.com.mobileninjas.pensamentododia  2013-07-17   0.00
# 995                         com.custom.lwp.BridgeLights  2013-07-17   0.00
# 996      com.uefa.football.champiansleague.europe.messi  2013-07-17   0.00
# 997                     com.gcsresearch.burkebiketrails  2013-07-17   0.00
# 998                                      com.Wallpaper2  2013-07-17   0.00
# 999                              pt.tmn.android.vamosla  2013-07-17   0.00
# 1000                      com.mymobilebookshelf.dracula  2013-07-17   2.99
#
# [1001 rows x 3 columns]

# %% [markdown]
# # NEWVERSION

# %%
@require(iter_json_gzip,gzip,datetime,re,csv)
def NEWVERSION(file_in,out_base,compress=1):
    headers = ['app_id','date','version']
    out_filename = out_base.format('NEWVERSION')
    with gzip.open(out_filename,'wt',compress,) as out_file:
        csv_writer = csv.writer(out_file)
        csv_writer.writerow(headers)
        running = {}
        nowhite = re.compile(r"\s+")
        for json in iter_json_gzip(file_in):
            version = json.get('version','')
            if isinstance(version,str):
                version = version.strip()
                if len(version)>0:
                    version = version.replace('Varies with device','varies')
                    version = nowhite.sub('',version).lower()
                    if running.get(json['app_id'],'')!=version and len(version)>0:
                        running[json['app_id']] = version
                        day = datetime.datetime.fromtimestamp(int(json['timestamp']))\
                                .strftime('%Y-%m-%d')
                        obs = (json['app_id'],day,version)
                        csv_writer.writerow(obs)
    return out_filename

# %%
df_debug = None
if DEBUG:
    df_debug = read_csv(NEWVERSION(RAW_FILE,OUT_BASE,COMPRESS_LEVEL),compression='gzip',header=0)
df_debug
# Out:
#                                                  app_id        date version
# 0                                com.touchtype.swiftkey  2013-07-17  varies
# 1                   com.gameloft.android.ANMP.GloftDMHM  2013-07-17   1.0.0
# 2                           com.ibm.events.android.usga  2013-07-17     2.2
# 3                                      com.dama.camera2  2013-07-17   1.0.6
# 4                           com.disney.scribblefree_goo  2013-07-17   1.0.2
# 5                                 com.gau.go.launcherex  2013-07-17  varies
# 6                              com.teslacoilsw.launcher  2013-07-17   2.1.1
# 7                          com.levelup.beautifulwidgets  2013-07-17   5.3.1
# 8           com.socialnmobile.dictdata.chinese.stardict  2013-07-17   1.0.4
# 9                               com.mdb.android.xiangqi  2013-07-17  2.6.12
# 10                                   io.avocado.android  2013-07-17     1.8
# 11                                        flipboard.app  2013-07-17  varies
# 12                      com.mobincube.android.app_20866  2013-07-17       6
# 13                                         com.at.proxi  2013-07-17    beta
# 14                      shopcoffeetable.com.coffeetable  2013-07-17    1.01
# 15                          com.mini.flowers.angryfatty  2013-07-17     2.6
# 16                            com.and.Wuthering_Heights  2013-07-17     1.0
# 17                                     com.loltv.layout  2013-07-17     1.1
# 18                         com.stopnplayapps.angryshark  2013-07-17     2.0
# 19                           say.hello.worldsnookernews  2013-07-17    24.0
# 20                                com.wolterskluwer.lsq  2013-07-17     1.0
# 21           com.themesfordroid.hunterthemegolauncherex  2013-07-17     1.0
# 22                          com.boxyz.androidteam.tsubo  2013-07-17   1.2.8
# 23                             twig.nguyen.d2_runewords  2013-07-17     1.5
# 24                                           com.Netter  2013-07-17   1.0.1
# 25                                 com.gunvald.bigpenis  2013-07-17     2.2
# 26                                     com.prapps.tokay  2013-07-17     1.6
# 27                 com.quickmare.typingkeyboard.neurope  2013-07-17     1.0
# 28                      Technicaljar.BluetoothAppBinder  2013-07-17     1.0
# 29               com.jiubang.goscreenlock.theme.lighter  2013-07-17     1.0
# ...                                                 ...         ...     ...
# 971                  com.miresoftware.sexyamateurs2free  2013-07-17     1.2
# 972             Alfasoft.Widgets.PsychedelicAnalogClock  2013-07-17     1.2
# 973                            com.Kaneosmare.BoeingC17  2013-07-17     1.0
# 974                                     adit.weather.ta  2013-07-17     1.0
# 975             com.andbling.wallpaper.live.names.ernie  2013-07-17   1.0.0
# 976              com.coreapps.android.followme.fetc2013  2013-07-17   3.8.5
# 977                             com.crossfield.frowline  2013-07-17   1.0.3
# 978                com.mspinc.sexygirllivewallpaperLite  2013-07-17     1.0
# 979                    org.guesswork.nightstand.digital  2013-07-17     1.3
# 980                                de.wgsoft.scanmaster  2013-07-17   1.0.3
# 981                    com.appsshoppe.hairlosstreatment  2013-07-17     1.0
# 982                                      com.mobizel.ra  2013-07-17   2.0.4
# 983                          com.buildingfive.pgnhelper  2013-07-17   1.1.2
# 984                                    com.oxxo.tiendas  2013-07-17     2.0
# 985                                    org.prospekt0048  2013-07-17   1.0.1
# 986                               com.andrios.bodycards  2013-07-17   1.3.2
# 987                                    com.sportsoo.web  2013-07-17     1.1
# 988                                    org.prospekt0049  2013-07-17   1.0.1
# 989                                 za.co.McCarthy.Audi  2013-07-17    1.02
# 990                    com.enlight.santaschristmaselves  2013-07-17   1.0.0
# 991   com.gau.go.launcherex.theme.gowidget.taskmanag...  2013-07-17     1.2
# 992                                 com.gw2.legendaries  2013-07-17     2.2
# 993                              com.dontpanic.lpp.cyan  2013-07-17     1.0
# 994                 br.com.mobileninjas.pensamentododia  2013-07-17   3.2.4
# 995                         com.custom.lwp.BridgeLights  2013-07-17     1.0
# 996      com.uefa.football.champiansleague.europe.messi  2013-07-17     2.4
# 997                     com.gcsresearch.burkebiketrails  2013-07-17     1.3
# 998                                      com.Wallpaper2  2013-07-17  1.0.2e
# 999                              pt.tmn.android.vamosla  2013-07-17     1.1
# 1000                      com.mymobilebookshelf.dracula  2013-07-17     1.0
#
# [1001 rows x 3 columns]

# %% [markdown]
# # NEWUPDATED

# %%
@require(iter_json_gzip,gzip,datetime,re,csv)
def NEWUPDATED(file_in,out_base,compress=1):
    headers = ['app_id','updated',]
    out_filename = out_base.format('NEWUPDATED')
    with gzip.open(out_filename,'wt',compress) as out_file:
        csv_writer = csv.writer(out_file)
        csv_writer.writerow(headers)
        running = {}
        nowhite = re.compile(r"\s+")
        for json in iter_json_gzip(file_in):
            updated = json.get('updated','')
            if isinstance(updated,str):
                updated = updated.strip()
                if running.get(json['app_id'],'')!=updated and len(updated)>0:
                    running[json['app_id']] = updated
                    date = datetime.datetime.strptime(updated,'%B %d, %Y')
                    date = date.strftime('%Y-%m-%d')
                    obs = (json['app_id'],date)
                    csv_writer.writerow(obs)
    return out_filename

# %%
df_debug = None
if DEBUG:
    df_debug = read_csv(NEWUPDATED(RAW_FILE,OUT_BASE,COMPRESS_LEVEL),compression='gzip',header=0)
df_debug
# Out:
#                                                  app_id     updated
# 0                                com.touchtype.swiftkey  2013-07-01
# 1                   com.gameloft.android.ANMP.GloftDMHM  2013-07-16
# 2                           com.ibm.events.android.usga  2013-06-14
# 3                                      com.dama.camera2  2013-07-03
# 4                           com.disney.scribblefree_goo  2013-07-03
# 5                                 com.gau.go.launcherex  2013-07-17
# 6                              com.teslacoilsw.launcher  2013-06-11
# 7                          com.levelup.beautifulwidgets  2013-07-16
# 8           com.socialnmobile.dictdata.chinese.stardict  2009-10-14
# 9                               com.mdb.android.xiangqi  2013-05-16
# 10                                   io.avocado.android  2013-07-12
# 11                                        flipboard.app  2013-07-17
# 12                      com.mobincube.android.app_20866  2012-08-28
# 13                                         com.at.proxi  2012-02-26
# 14                      shopcoffeetable.com.coffeetable  2011-03-06
# 15                          com.mini.flowers.angryfatty  2013-07-09
# 16                            com.and.Wuthering_Heights  2012-03-08
# 17                                     com.loltv.layout  2013-04-25
# 18                         com.stopnplayapps.angryshark  2013-03-20
# 19                           say.hello.worldsnookernews  2013-06-16
# 20                                com.wolterskluwer.lsq  2012-06-13
# 21           com.themesfordroid.hunterthemegolauncherex  2013-02-14
# 22                          com.boxyz.androidteam.tsubo  2013-05-17
# 23                             twig.nguyen.d2_runewords  2013-06-23
# 24                                           com.Netter  2012-01-12
# 25                                 com.gunvald.bigpenis  2013-01-16
# 26                                     com.prapps.tokay  2012-04-19
# 27                 com.quickmare.typingkeyboard.neurope  2011-12-16
# 28                      Technicaljar.BluetoothAppBinder  2011-01-03
# 29               com.jiubang.goscreenlock.theme.lighter  2012-02-21
# ...                                                 ...         ...
# 971                  com.miresoftware.sexyamateurs2free  2011-05-02
# 972             Alfasoft.Widgets.PsychedelicAnalogClock  2011-07-02
# 973                            com.Kaneosmare.BoeingC17  2013-06-07
# 974                                     adit.weather.ta  2013-05-30
# 975             com.andbling.wallpaper.live.names.ernie  2011-05-29
# 976              com.coreapps.android.followme.fetc2013  2013-01-29
# 977                             com.crossfield.frowline  2013-06-21
# 978                com.mspinc.sexygirllivewallpaperLite  2012-06-25
# 979                    org.guesswork.nightstand.digital  2011-10-24
# 980                                de.wgsoft.scanmaster  2013-05-20
# 981                    com.appsshoppe.hairlosstreatment  2013-04-13
# 982                                      com.mobizel.ra  2013-06-04
# 983                          com.buildingfive.pgnhelper  2013-01-12
# 984                                    com.oxxo.tiendas  2013-07-02
# 985                                    org.prospekt0048  2011-07-19
# 986                               com.andrios.bodycards  2012-01-16
# 987                                    com.sportsoo.web  2013-05-22
# 988                                    org.prospekt0049  2011-07-19
# 989                                 za.co.McCarthy.Audi  2013-07-03
# 990                    com.enlight.santaschristmaselves  2012-12-09
# 991   com.gau.go.launcherex.theme.gowidget.taskmanag...  2013-04-07
# 992                                 com.gw2.legendaries  2013-05-16
# 993                              com.dontpanic.lpp.cyan  2011-05-19
# 994                 br.com.mobileninjas.pensamentododia  2013-05-15
# 995                         com.custom.lwp.BridgeLights  2011-04-20
# 996      com.uefa.football.champiansleague.europe.messi  2013-04-12
# 997                     com.gcsresearch.burkebiketrails  2012-04-24
# 998                                      com.Wallpaper2  2013-03-20
# 999                              pt.tmn.android.vamosla  2012-04-20
# 1000                      com.mymobilebookshelf.dracula  2011-05-21
#
# [1001 rows x 2 columns]

# %% [markdown]
# # NEWREQ

# %%
@require(iter_json_gzip,gzip,datetime,re,csv)
def NEWREQ(file_in,out_base,compress=1):
    headers = ['app_id','date','requires']
    out_filename = out_base.format('NEWREQ')
    with gzip.open(out_filename,'wt',compress) as out_file:
        csv_writer = csv.writer(out_file)
        csv_writer.writerow(headers)
        running = {}
        nowhite = re.compile(r"\s+")
        and_up = re.compile(r" and up")
        for json in iter_json_gzip(file_in):
            requires = json.get('requires','')
            if isinstance(requires,str):
                if len(requires)>0:
                    requires = requires.lower().strip()
                    requires = requires.replace('varies with device','varies')
                    requires = and_up.sub('+',requires)
                    requires = nowhite.sub('',requires)
                    if running.get(json['app_id'],'')!=requires and len(requires)>0:
                        running[json['app_id']] = requires
                        day = datetime.datetime.fromtimestamp(int(json['timestamp']))\
                                .strftime('%Y-%m-%d')
                        obs = (json['app_id'],day,requires)
                        csv_writer.writerow(obs)
    return out_filename

# %%
df_debug = None
if DEBUG:
    df_debug = read_csv(NEWREQ(RAW_FILE,OUT_BASE,COMPRESS_LEVEL),compression='gzip',header=0)
df_debug
# Out:
#                                                  app_id        date requires
# 0                                com.touchtype.swiftkey  2013-07-17   varies
# 1                   com.gameloft.android.ANMP.GloftDMHM  2013-07-17     2.3+
# 2                           com.ibm.events.android.usga  2013-07-17     2.2+
# 3                                      com.dama.camera2  2013-07-17   4.0.3+
# 4                           com.disney.scribblefree_goo  2013-07-17     2.2+
# 5                                 com.gau.go.launcherex  2013-07-17   varies
# 6                              com.teslacoilsw.launcher  2013-07-17     4.0+
# 7                          com.levelup.beautifulwidgets  2013-07-17     2.2+
# 8           com.socialnmobile.dictdata.chinese.stardict  2013-07-17     1.5+
# 9                               com.mdb.android.xiangqi  2013-07-17     1.5+
# 10                                   io.avocado.android  2013-07-17     2.2+
# 11                                        flipboard.app  2013-07-17   varies
# 12                      com.mobincube.android.app_20866  2013-07-17     2.1+
# 13                                         com.at.proxi  2013-07-17     2.2+
# 14                      shopcoffeetable.com.coffeetable  2013-07-17     2.0+
# 15                          com.mini.flowers.angryfatty  2013-07-17     1.6+
# 16                            com.and.Wuthering_Heights  2013-07-17     2.1+
# 17                                     com.loltv.layout  2013-07-17     4.0+
# 18                         com.stopnplayapps.angryshark  2013-07-17     2.3+
# 19                           say.hello.worldsnookernews  2013-07-17     1.5+
# 20                                com.wolterskluwer.lsq  2013-07-17     2.1+
# 21           com.themesfordroid.hunterthemegolauncherex  2013-07-17     2.1+
# 22                          com.boxyz.androidteam.tsubo  2013-07-17     1.6+
# 23                             twig.nguyen.d2_runewords  2013-07-17     1.6+
# 24                                           com.Netter  2013-07-17     2.2+
# 25                                 com.gunvald.bigpenis  2013-07-17     1.6+
# 26                                     com.prapps.tokay  2013-07-17     1.6+
# 27                 com.quickmare.typingkeyboard.neurope  2013-07-17     2.2+
# 28                      Technicaljar.BluetoothAppBinder  2013-07-17     2.1+
# 29               com.jiubang.goscreenlock.theme.lighter  2013-07-17     1.6+
# ...                                                 ...         ...      ...
# 971                  com.miresoftware.sexyamateurs2free  2013-07-17     1.6+
# 972             Alfasoft.Widgets.PsychedelicAnalogClock  2013-07-17     1.5+
# 973                            com.Kaneosmare.BoeingC17  2013-07-17     2.1+
# 974                                     adit.weather.ta  2013-07-17     3.0+
# 975             com.andbling.wallpaper.live.names.ernie  2013-07-17     2.1+
# 976              com.coreapps.android.followme.fetc2013  2013-07-17     2.2+
# 977                             com.crossfield.frowline  2013-07-17     2.2+
# 978                com.mspinc.sexygirllivewallpaperLite  2013-07-17     1.6+
# 979                    org.guesswork.nightstand.digital  2013-07-17     2.2+
# 980                                de.wgsoft.scanmaster  2013-07-17     2.1+
# 981                    com.appsshoppe.hairlosstreatment  2013-07-17     2.2+
# 982                                      com.mobizel.ra  2013-07-17     2.2+
# 983                          com.buildingfive.pgnhelper  2013-07-17     2.2+
# 984                                    com.oxxo.tiendas  2013-07-17     2.2+
# 985                                    org.prospekt0048  2013-07-17     1.6+
# 986                               com.andrios.bodycards  2013-07-17     1.6+
# 987                                    com.sportsoo.web  2013-07-17     2.2+
# 988                                    org.prospekt0049  2013-07-17     1.6+
# 989                                 za.co.McCarthy.Audi  2013-07-17     2.2+
# 990                    com.enlight.santaschristmaselves  2013-07-17     1.6+
# 991   com.gau.go.launcherex.theme.gowidget.taskmanag...  2013-07-17     2.2+
# 992                                 com.gw2.legendaries  2013-07-17     3.0+
# 993                              com.dontpanic.lpp.cyan  2013-07-17     2.0+
# 994                 br.com.mobileninjas.pensamentododia  2013-07-17     2.2+
# 995                         com.custom.lwp.BridgeLights  2013-07-17     2.1+
# 996      com.uefa.football.champiansleague.europe.messi  2013-07-17     1.6+
# 997                     com.gcsresearch.burkebiketrails  2013-07-17     2.2+
# 998                                      com.Wallpaper2  2013-07-17     2.1+
# 999                              pt.tmn.android.vamosla  2013-07-17     2.2+
# 1000                      com.mymobilebookshelf.dracula  2013-07-17     1.6+
#
# [1001 rows x 3 columns]

# %% [markdown]
# # NEWINSTALL

# %%
@require(iter_json_gzip,gzip,datetime,re,csv)
def NEWINSTALL(file_in,out_base,compress=1):
    headers = ['app_id','date','installs']
    out_filename = out_base.format('NEWINSTALL')
    with gzip.open(out_filename,'wt',compress) as out_file:
        csv_writer = csv.writer(out_file)
        csv_writer.writerow(headers)
        nowhite = re.compile(r"\s+")
        running = {}
        for json in iter_json_gzip(file_in):
            installs = json.get('installs','')
            if isinstance(installs,str):
                installs = nowhite.sub('',installs)
                if running.get(json['app_id'],'')!=installs and len(installs)>0:
                    running[json['app_id']] = installs
                    day = datetime.datetime.fromtimestamp(int(json['timestamp']))\
                            .strftime('%Y-%m-%d')
                    obs = (json['app_id'],day,installs)
                    csv_writer.writerow(obs)
    return out_filename

# %%
df_debug = None
if DEBUG:
    df_debug = read_csv(NEWINSTALL(RAW_FILE,OUT_BASE,COMPRESS_LEVEL),compression='gzip',header=0)
df_debug
# Out:
#                                                 app_id        date  \
# 0                               com.touchtype.swiftkey  2013-07-17
# 1                  com.gameloft.android.ANMP.GloftDMHM  2013-07-17
# 2                          com.ibm.events.android.usga  2013-07-17
# 3                                     com.dama.camera2  2013-07-17
# 4                          com.disney.scribblefree_goo  2013-07-17
# 5                                com.gau.go.launcherex  2013-07-17
# 6                             com.teslacoilsw.launcher  2013-07-17
# 7                         com.levelup.beautifulwidgets  2013-07-17
# 8          com.socialnmobile.dictdata.chinese.stardict  2013-07-17
# 9                              com.mdb.android.xiangqi  2013-07-17
# 10                                  io.avocado.android  2013-07-17
# 11                                       flipboard.app  2013-07-17
# 12                     com.mobincube.android.app_20866  2013-07-17
# 13                                        com.at.proxi  2013-07-17
# 14                     shopcoffeetable.com.coffeetable  2013-07-17
# 15                         com.mini.flowers.angryfatty  2013-07-17
# 16                           com.and.Wuthering_Heights  2013-07-17
# 17                                    com.loltv.layout  2013-07-17
# 18                        com.stopnplayapps.angryshark  2013-07-17
# 19                          say.hello.worldsnookernews  2013-07-17
# 20                               com.wolterskluwer.lsq  2013-07-17
# 21          com.themesfordroid.hunterthemegolauncherex  2013-07-17
# 22                         com.boxyz.androidteam.tsubo  2013-07-17
# 23                            twig.nguyen.d2_runewords  2013-07-17
# 24                                          com.Netter  2013-07-17
# 25                                com.gunvald.bigpenis  2013-07-17
# 26                                    com.prapps.tokay  2013-07-17
# 27                com.quickmare.typingkeyboard.neurope  2013-07-17
# 28                     Technicaljar.BluetoothAppBinder  2013-07-17
# 29              com.jiubang.goscreenlock.theme.lighter  2013-07-17
# ..                                                 ...         ...
# 958                 com.miresoftware.sexyamateurs2free  2013-07-17
# 959            Alfasoft.Widgets.PsychedelicAnalogClock  2013-07-17
# 960                           com.Kaneosmare.BoeingC17  2013-07-17
# 961                                    adit.weather.ta  2013-07-17
# 962            com.andbling.wallpaper.live.names.ernie  2013-07-17
# 963             com.coreapps.android.followme.fetc2013  2013-07-17
# 964                            com.crossfield.frowline  2013-07-17
# 965               com.mspinc.sexygirllivewallpaperLite  2013-07-17
# 966                   org.guesswork.nightstand.digital  2013-07-17
# 967                               de.wgsoft.scanmaster  2013-07-17
# 968                   com.appsshoppe.hairlosstreatment  2013-07-17
# 969                                     com.mobizel.ra  2013-07-17
# 970                         com.buildingfive.pgnhelper  2013-07-17
# 971                                   com.oxxo.tiendas  2013-07-17
# 972                                   org.prospekt0048  2013-07-17
# 973                              com.andrios.bodycards  2013-07-17
# 974                                   com.sportsoo.web  2013-07-17
# 975                                   org.prospekt0049  2013-07-17
# 976                                za.co.McCarthy.Audi  2013-07-17
# 977                   com.enlight.santaschristmaselves  2013-07-17
# 978  com.gau.go.launcherex.theme.gowidget.taskmanag...  2013-07-17
# 979                                com.gw2.legendaries  2013-07-17
# 980                             com.dontpanic.lpp.cyan  2013-07-17
# 981                br.com.mobileninjas.pensamentododia  2013-07-17
# 982                        com.custom.lwp.BridgeLights  2013-07-17
# 983     com.uefa.football.champiansleague.europe.messi  2013-07-17
# 984                    com.gcsresearch.burkebiketrails  2013-07-17
# 985                                     com.Wallpaper2  2013-07-17
# 986                             pt.tmn.android.vamosla  2013-07-17
# 987                      com.mymobilebookshelf.dracula  2013-07-17
#
#                    installs
# 0       1,000,000-5,000,000
# 1     10,000,000-50,000,000
# 2           100,000-500,000
# 3             10,000-50,000
# 4         500,000-1,000,000
# 5    50,000,000-100,000,000
# 6      5,000,000-10,000,000
# 7       1,000,000-5,000,000
# 8           100,000-500,000
# 9             10,000-50,000
# 10        500,000-1,000,000
# 11   50,000,000-100,000,000
# 12                   50-100
# 13                  100-500
# 14              1,000-5,000
# 15          100,000-500,000
# 16                      1-5
# 17              1,000-5,000
# 18              1,000-5,000
# 19           50,000-100,000
# 20                500-1,000
# 21            10,000-50,000
# 22              1,000-5,000
# 23            10,000-50,000
# 24           50,000-100,000
# 25            10,000-50,000
# 26              1,000-5,000
# 27                  100-500
# 28              1,000-5,000
# 29      1,000,000-5,000,000
# ..                      ...
# 958          50,000-100,000
# 959          50,000-100,000
# 960                 100-500
# 961                 100-500
# 962                     1-5
# 963               500-1,000
# 964             1,000-5,000
# 965             1,000-5,000
# 966             1,000-5,000
# 967          50,000-100,000
# 968                 100-500
# 969                 100-500
# 970               500-1,000
# 971           10,000-50,000
# 972                     1-5
# 973           10,000-50,000
# 974                 100-500
# 975                    5-10
# 976                  50-100
# 977               500-1,000
# 978          50,000-100,000
# 979             1,000-5,000
# 980           10,000-50,000
# 981          50,000-100,000
# 982                 100-500
# 983             1,000-5,000
# 984               500-1,000
# 985            5,000-10,000
# 986               500-1,000
# 987                     1-5
#
# [988 rows x 3 columns]

# %% [markdown]
# # NEWNAME

# %%
@require(iter_json_gzip,gzip,datetime,re,csv)
def NEWNAME(file_in,out_base,compress=1):
    headers = ['app_id', 'date', 'name'] # list of column names
    out_filename = out_base.format('NEWNAME')
    running = {}
    with gzip.open(out_filename,'wt',compress) as out_file:
        csv_writer = csv.writer(out_file)
        csv_writer.writerow(headers)
        for json in iter_json_gzip(file_in):
            name = json.get('app_name','')
            if isinstance(name,str):
                name = name.strip()
                if running.get(json['app_id'],'')!=name and len(name)>0:
                    running[json['app_id']] = name
                    obs = [json['app_id'], str(datetime.date.fromtimestamp(int(json.get('timestamp', '')))), name]
                    csv_writer.writerow(obs)
    return out_filename

# %%
df_debug = None
if DEBUG:
    df_debug = read_csv(NEWNAME(RAW_FILE,OUT_BASE,COMPRESS_LEVEL),compression='gzip',header=0)
df_debug
# Out:
#                                                  app_id        date  \
# 0                                com.touchtype.swiftkey  2013-07-17
# 1                   com.gameloft.android.ANMP.GloftDMHM  2013-07-17
# 2                           com.ibm.events.android.usga  2013-07-17
# 3                                      com.dama.camera2  2013-07-17
# 4                           com.disney.scribblefree_goo  2013-07-17
# 5                                 com.gau.go.launcherex  2013-07-17
# 6                              com.teslacoilsw.launcher  2013-07-17
# 7                          com.levelup.beautifulwidgets  2013-07-17
# 8           com.socialnmobile.dictdata.chinese.stardict  2013-07-17
# 9                               com.mdb.android.xiangqi  2013-07-17
# 10                                   io.avocado.android  2013-07-17
# 11                                        flipboard.app  2013-07-17
# 12                      com.mobincube.android.app_20866  2013-07-17
# 13                                         com.at.proxi  2013-07-17
# 14                      shopcoffeetable.com.coffeetable  2013-07-17
# 15                          com.mini.flowers.angryfatty  2013-07-17
# 16                            com.and.Wuthering_Heights  2013-07-17
# 17                                     com.loltv.layout  2013-07-17
# 18                         com.stopnplayapps.angryshark  2013-07-17
# 19                           say.hello.worldsnookernews  2013-07-17
# 20                                com.wolterskluwer.lsq  2013-07-17
# 21           com.themesfordroid.hunterthemegolauncherex  2013-07-17
# 22                          com.boxyz.androidteam.tsubo  2013-07-17
# 23                             twig.nguyen.d2_runewords  2013-07-17
# 24                                           com.Netter  2013-07-17
# 25                                 com.gunvald.bigpenis  2013-07-17
# 26                                     com.prapps.tokay  2013-07-17
# 27                 com.quickmare.typingkeyboard.neurope  2013-07-17
# 28                      Technicaljar.BluetoothAppBinder  2013-07-17
# 29               com.jiubang.goscreenlock.theme.lighter  2013-07-17
# ...                                                 ...         ...
# 971                  com.miresoftware.sexyamateurs2free  2013-07-17
# 972             Alfasoft.Widgets.PsychedelicAnalogClock  2013-07-17
# 973                            com.Kaneosmare.BoeingC17  2013-07-17
# 974                                     adit.weather.ta  2013-07-17
# 975             com.andbling.wallpaper.live.names.ernie  2013-07-17
# 976              com.coreapps.android.followme.fetc2013  2013-07-17
# 977                             com.crossfield.frowline  2013-07-17
# 978                com.mspinc.sexygirllivewallpaperLite  2013-07-17
# 979                    org.guesswork.nightstand.digital  2013-07-17
# 980                                de.wgsoft.scanmaster  2013-07-17
# 981                    com.appsshoppe.hairlosstreatment  2013-07-17
# 982                                      com.mobizel.ra  2013-07-17
# 983                          com.buildingfive.pgnhelper  2013-07-17
# 984                                    com.oxxo.tiendas  2013-07-17
# 985                                    org.prospekt0048  2013-07-17
# 986                               com.andrios.bodycards  2013-07-17
# 987                                    com.sportsoo.web  2013-07-17
# 988                                    org.prospekt0049  2013-07-17
# 989                                 za.co.McCarthy.Audi  2013-07-17
# 990                    com.enlight.santaschristmaselves  2013-07-17
# 991   com.gau.go.launcherex.theme.gowidget.taskmanag...  2013-07-17
# 992                                 com.gw2.legendaries  2013-07-17
# 993                              com.dontpanic.lpp.cyan  2013-07-17
# 994                 br.com.mobileninjas.pensamentododia  2013-07-17
# 995                         com.custom.lwp.BridgeLights  2013-07-17
# 996      com.uefa.football.champiansleague.europe.messi  2013-07-17
# 997                     com.gcsresearch.burkebiketrails  2013-07-17
# 998                                      com.Wallpaper2  2013-07-17
# 999                              pt.tmn.android.vamosla  2013-07-17
# 1000                      com.mymobilebookshelf.dracula  2013-07-17
#
#                                 name
# 0                  SwiftKey Keyboard
# 1                      Despicable Me
# 2        U.S. Open Golf Championship
# 3                           Camera 2
# 4                        ScribbleMix
# 5                     GO Launcher EX
# 6                      Nova Launcher
# 7              Beautiful Widgets Pro
# 8      English Chinese Dictionary 辞典
# 9           中国象棋 : The chinese chess
# 10                           Avocado
# 11     Flipboard: Your News Magazine
# 12                       Dallas Jazz
# 13                          ProxiOrb
# 14                      Coffee Table
# 15                       Angry Fatty
# 16                      [무비랑] 폭풍의 언덕
# 17                         Legend TV
# 18                       Angry Shark
# 19           World Snooker News 2013
# 20                               LSQ
# 21       Go Launcher EX Hunter Theme
# 22                      Asian Health
# 23                Diablo 2 Runewords
# 24                            Netter
# 25                     Elephant Dick
# 26       Tokay Teaser Practical Joke
# 27      TKB - North European Layouts
# 28                Settings Automator
# 29           Lighter Theme GO Locker
# ...                              ...
# 971             Sexy Amateurs 2 FREE
# 972         Psychedelic Analog Clock
# 973            Boeing C17 Wallpapers
# 974                       eL Weather
# 975                   Ernie Name Tag
# 976     FETC & Learning Environments
# 977                         FlowLine
# 978    Sexy Gorgeous Girls wallpaper
# 979               Digital Nightstand
# 980                  ScanMaster Lite
# 981               Hair Loss Remedies
# 982                  Rennes Atalante
# 983                 Chess PGN Helper
# 984                 OXXO siempre ahí
# 985          Gavriiliada. AS Pushkin
# 986                       Body Cards
# 987           Sportsoo Sports online
# 988             History of Pugachev.
# 989                    McCarthy Audi
# 990   Santas Elves Color in Workshop
# 991     Love Theme GO TaskManager EX
# 992          Legendary Weapons (GW2)
# 993                    LPP Skin Cyan
# 994       Pensamento do dia (Grátis)
# 995     Bridge Lights Live Wallpaper
# 996   Champions league football quiz
# 997     Burke Vermont Bike Trail Map
# 998       Virgin Mary Wallpaper Free
# 999                         Vamos lá
# 1000          Dracula Ebook (no ads)
#
# [1001 rows x 3 columns]

# %% [markdown]
# # NEWINAPP

# %%
@require(iter_json_gzip,gzip,datetime,re,csv)
def NEWINAPP(file_in,out_base,compress=1):
    headers = ['app_id', 'date', 'has_inapp'] # list of column names
    out_filename = out_base.format('NEWINAPP')
    running = {}
    with gzip.open(out_filename,'wt',compress) as out_file:
        csv_writer = csv.writer(out_file)
        csv_writer.writerow(headers)
        for json in iter_json_gzip(file_in):
            if int(json.get('timestamp')) < 1402901976: #June 15 2014 11:59 PM
                continue
            name = str(json.get('in_app', ''))
            if name.isdigit():
                name = str(bool(int(name)))
            else:
                name = ''
            if isinstance(name,str):
                if running.get(json['app_id'],'')!=name and len(name)>0:
                    running[json['app_id']] = name
                    obs = [json['app_id'], str(datetime.date.fromtimestamp(int(json.get('timestamp', '')))), name]
                    csv_writer.writerow(obs)
    return out_filename

# %%
df_debug = None
if DEBUG:
    df_debug = read_csv(NEWINAPP(RAW_FILE_NEWDATA,OUT_BASE,COMPRESS_LEVEL),compression='gzip',header=0)
df_debug
# Out:
#                                   app_id        date has_inapp
# 0               com.icbs.catchme.english  2015-02-26      True
# 1          com.iceflakestudios.piraterun  2015-02-26      True
# 2       com.iccwct202012.iccworldt202012  2015-02-26      True
# 3             com.iceapps.animalpictures  2015-02-26      True
# 4                  com.iceberg.flippyjet  2015-02-26      True
# 5              com.iceberg.testdrivecar2  2015-02-26      True
# 6              com.iceberg.testdrivecar3  2015-02-26      True
# 7              com.iceberg.testdrivecar4  2015-02-26      True
# 8              com.iceberg.testdrivecar6  2015-02-26      True
# 9              com.iceberg.testdrivecar5  2015-02-26      True
# 10           com.iceberg.testdriveisland  2015-02-26      True
# 11             com.iceberg.testdrivecar7  2015-02-26      True
# 12             com.icecat.hex.gamenomads  2015-02-26      True
# 13                 com.icechen1.whereami  2015-02-26      True
# 14                        com.icecat.hex  2015-02-26      True
# 15   com.icecoldapps.synchronizeultimate  2015-02-26      True
# 16             com.iceflame.SoccerRally2  2015-02-26      True
# 17            com.icecoldapps.ultiserver  2015-02-26      True
# 18              com.icecream.flopstudios  2015-02-26      True
# 19                   com.icecry.icecream  2015-02-26      True
# 20                     com.icedap.icedap  2015-02-26      True
# 21               com.icecry.jetflydesert  2015-02-26      True
# 22               com.icedoutapps.highlow  2015-02-26      True
# 23                 com.icee.panicfingers  2015-02-26      True
# 24                    com.icefang.g.amtp  2015-02-26      True
# 25                 com.icefang.g.mahjong  2015-02-26      True
# 26              com.icefang.g.mahjongzen  2015-02-26      True
# 27                  com.icefang.g.snacks  2015-02-26      True
# 28               com.ichoose.bettercalls  2015-02-26      True
# 29       com.iceflakestudios.premiumgolf  2015-02-26      True
# ..                                   ...         ...       ...
# 85    com.iconic.celebrity.leg.spa.salon  2015-02-26      True
# 86           com.iconic.bunny.stomp.king  2015-02-26      True
# 87    com.iconic.crazy.beard.shave.salon  2015-02-26      True
# 88         com.iconic.cotton.candy.maker  2015-02-26      True
# 89               com.iconic.cookie.party  2015-02-26      True
# 90                 com.iconic.candycatch  2015-02-26      True
# 91     com.iconic.crazy.monster.hospital  2015-02-26      True
# 92        com.iconic.duke.monster.empire  2015-02-26      True
# 93        com.iconic.emily.fashion.salon  2015-02-26      True
# 94                    com.iconic.find.it  2015-02-26      True
# 95      com.iconic.giraffe.dressup.mania  2015-02-26      True
# 96          com.iconic.giraffe.spa.salon  2015-02-26      True
# 97      com.iconic.giraffe.weddind.dress  2015-02-26      True
# 98              com.iconic.hundred.balls  2015-02-26      True
# 99     com.iconic.ice.cream.cake.factory  2015-02-26      True
# 100  com.iconic.kims.leg.spa.and.dressup  2015-02-26      True
# 101           com.iconic.kids.lunch.food  2015-02-26      True
# 102           com.iconic.leo.pony.doctor  2015-02-26      True
# 103              com.iconic.park.my.ride  2015-02-26      True
# 104       com.iconic.jelly.cupcake.maker  2015-02-26      True
# 105         com.iconic.mias.leg.foot.spa  2015-02-26      True
# 106  com.iconic.princess.giraffe.stylist  2015-02-26      True
# 107              com.iconic.popcorn.time  2015-02-26      True
# 108   com.iconic.princess.mia.doll.house  2015-02-26      True
# 109             com.iconic.pudding.maker  2015-02-26      True
# 110               com.iconic.tap.spot.it  2015-02-26      True
# 111        com.iconic.witch.candy.potion  2015-02-26      True
# 112                com.iconic.tap.rabbit  2015-02-26      True
# 113            com.iconic.crush.the.mole  2015-02-26      True
# 114       com.iconic.pet.vet.pony.doctor  2015-02-26      True
#
# [115 rows x 3 columns]

# %% [markdown]
# # DAILYSCRAPE

# %%
@require(iter_json_gzip,gzip,datetime,re,csv)
def DAILYSCRAPE(file_in,out_base,compress=1):
    headers = ['app_id', 'date'] # list of column names
    out_filename = out_base.format('DAILYSCRAPE')
    running = {}
    with gzip.open(out_filename,'wt',compress) as out_file:
        csv_writer = csv.writer(out_file)
        csv_writer.writerow(headers)
        for json in iter_json_gzip(file_in):
            day = str(datetime.date.fromtimestamp(json.get('timestamp','')))
            if isinstance(day,str):
                day = day.strip()
                if running.get(json['app_id'],'')!=day and len(day)>0:
                    running[json['app_id']] = day
                    obs = [json['app_id'], day]
                    csv_writer.writerow(obs)
    return out_filename

# %%
df_debug = None
if DEBUG:
    df_debug = read_csv(DAILYSCRAPE(RAW_FILE,OUT_BASE,COMPRESS_LEVEL),compression='gzip',header=0)
df_debug
# Out:
#                                                  app_id        date
# 0                                com.touchtype.swiftkey  2013-07-17
# 1                   com.gameloft.android.ANMP.GloftDMHM  2013-07-17
# 2                           com.ibm.events.android.usga  2013-07-17
# 3                                      com.dama.camera2  2013-07-17
# 4                           com.disney.scribblefree_goo  2013-07-17
# 5                                 com.gau.go.launcherex  2013-07-17
# 6                              com.teslacoilsw.launcher  2013-07-17
# 7                          com.levelup.beautifulwidgets  2013-07-17
# 8           com.socialnmobile.dictdata.chinese.stardict  2013-07-17
# 9                               com.mdb.android.xiangqi  2013-07-17
# 10                                   io.avocado.android  2013-07-17
# 11                                        flipboard.app  2013-07-17
# 12                      com.mobincube.android.app_20866  2013-07-17
# 13                                         com.at.proxi  2013-07-17
# 14                      shopcoffeetable.com.coffeetable  2013-07-17
# 15                          com.mini.flowers.angryfatty  2013-07-17
# 16                            com.and.Wuthering_Heights  2013-07-17
# 17                                     com.loltv.layout  2013-07-17
# 18                         com.stopnplayapps.angryshark  2013-07-17
# 19                           say.hello.worldsnookernews  2013-07-17
# 20                                com.wolterskluwer.lsq  2013-07-17
# 21           com.themesfordroid.hunterthemegolauncherex  2013-07-17
# 22                          com.boxyz.androidteam.tsubo  2013-07-17
# 23                             twig.nguyen.d2_runewords  2013-07-17
# 24                                           com.Netter  2013-07-17
# 25                                 com.gunvald.bigpenis  2013-07-17
# 26                                     com.prapps.tokay  2013-07-17
# 27                 com.quickmare.typingkeyboard.neurope  2013-07-17
# 28                      Technicaljar.BluetoothAppBinder  2013-07-17
# 29               com.jiubang.goscreenlock.theme.lighter  2013-07-17
# ...                                                 ...         ...
# 971                  com.miresoftware.sexyamateurs2free  2013-07-17
# 972             Alfasoft.Widgets.PsychedelicAnalogClock  2013-07-17
# 973                            com.Kaneosmare.BoeingC17  2013-07-17
# 974                                     adit.weather.ta  2013-07-17
# 975             com.andbling.wallpaper.live.names.ernie  2013-07-17
# 976              com.coreapps.android.followme.fetc2013  2013-07-17
# 977                             com.crossfield.frowline  2013-07-17
# 978                com.mspinc.sexygirllivewallpaperLite  2013-07-17
# 979                    org.guesswork.nightstand.digital  2013-07-17
# 980                                de.wgsoft.scanmaster  2013-07-17
# 981                    com.appsshoppe.hairlosstreatment  2013-07-17
# 982                                      com.mobizel.ra  2013-07-17
# 983                          com.buildingfive.pgnhelper  2013-07-17
# 984                                    com.oxxo.tiendas  2013-07-17
# 985                                    org.prospekt0048  2013-07-17
# 986                               com.andrios.bodycards  2013-07-17
# 987                                    com.sportsoo.web  2013-07-17
# 988                                    org.prospekt0049  2013-07-17
# 989                                 za.co.McCarthy.Audi  2013-07-17
# 990                    com.enlight.santaschristmaselves  2013-07-17
# 991   com.gau.go.launcherex.theme.gowidget.taskmanag...  2013-07-17
# 992                                 com.gw2.legendaries  2013-07-17
# 993                              com.dontpanic.lpp.cyan  2013-07-17
# 994                 br.com.mobileninjas.pensamentododia  2013-07-17
# 995                         com.custom.lwp.BridgeLights  2013-07-17
# 996      com.uefa.football.champiansleague.europe.messi  2013-07-17
# 997                     com.gcsresearch.burkebiketrails  2013-07-17
# 998                                      com.Wallpaper2  2013-07-17
# 999                              pt.tmn.android.vamosla  2013-07-17
# 1000                      com.mymobilebookshelf.dracula  2013-07-17
#
# [1001 rows x 2 columns]

# %% [markdown]
# # MONTHLYSCRAPE

# %%
@require(iter_json_gzip,gzip,datetime,re,csv)
def MONTHLYSCRAPE(file_in,out_base,compress=1):
    headers = ['app_id', 'year', 'month'] # list of column names
    out_filename = out_base.format('MONTHLYSCRAPE')
    running = {}
    with gzip.open(out_filename,'wt',compress) as out_file:
        csv_writer = csv.writer(out_file)
        csv_writer.writerow(headers)
        for json in iter_json_gzip(file_in):
            month = (str(datetime.date.fromtimestamp(json.get('timestamp','')).month).strip(), str(datetime.date.fromtimestamp(json.get('timestamp','')).year).strip())
            if isinstance(month,tuple):
                if running.get(json['app_id'],'')!=month and len(month)>0:
                    running[json['app_id']] = month
                    obs = [json['app_id'], month[1], month[0]]
                    csv_writer.writerow(obs)
    return out_filename

# %%
df_debug = None
if DEBUG:
    df_debug = read_csv(MONTHLYSCRAPE(RAW_FILE,OUT_BASE,COMPRESS_LEVEL),compression='gzip',header=0)
df_debug
# Out:
#                                                  app_id  year  month
# 0                                com.touchtype.swiftkey  2013      7
# 1                   com.gameloft.android.ANMP.GloftDMHM  2013      7
# 2                           com.ibm.events.android.usga  2013      7
# 3                                      com.dama.camera2  2013      7
# 4                           com.disney.scribblefree_goo  2013      7
# 5                                 com.gau.go.launcherex  2013      7
# 6                              com.teslacoilsw.launcher  2013      7
# 7                          com.levelup.beautifulwidgets  2013      7
# 8           com.socialnmobile.dictdata.chinese.stardict  2013      7
# 9                               com.mdb.android.xiangqi  2013      7
# 10                                   io.avocado.android  2013      7
# 11                                        flipboard.app  2013      7
# 12                      com.mobincube.android.app_20866  2013      7
# 13                                         com.at.proxi  2013      7
# 14                      shopcoffeetable.com.coffeetable  2013      7
# 15                          com.mini.flowers.angryfatty  2013      7
# 16                            com.and.Wuthering_Heights  2013      7
# 17                                     com.loltv.layout  2013      7
# 18                         com.stopnplayapps.angryshark  2013      7
# 19                           say.hello.worldsnookernews  2013      7
# 20                                com.wolterskluwer.lsq  2013      7
# 21           com.themesfordroid.hunterthemegolauncherex  2013      7
# 22                          com.boxyz.androidteam.tsubo  2013      7
# 23                             twig.nguyen.d2_runewords  2013      7
# 24                                           com.Netter  2013      7
# 25                                 com.gunvald.bigpenis  2013      7
# 26                                     com.prapps.tokay  2013      7
# 27                 com.quickmare.typingkeyboard.neurope  2013      7
# 28                      Technicaljar.BluetoothAppBinder  2013      7
# 29               com.jiubang.goscreenlock.theme.lighter  2013      7
# ...                                                 ...   ...    ...
# 971                  com.miresoftware.sexyamateurs2free  2013      7
# 972             Alfasoft.Widgets.PsychedelicAnalogClock  2013      7
# 973                            com.Kaneosmare.BoeingC17  2013      7
# 974                                     adit.weather.ta  2013      7
# 975             com.andbling.wallpaper.live.names.ernie  2013      7
# 976              com.coreapps.android.followme.fetc2013  2013      7
# 977                             com.crossfield.frowline  2013      7
# 978                com.mspinc.sexygirllivewallpaperLite  2013      7
# 979                    org.guesswork.nightstand.digital  2013      7
# 980                                de.wgsoft.scanmaster  2013      7
# 981                    com.appsshoppe.hairlosstreatment  2013      7
# 982                                      com.mobizel.ra  2013      7
# 983                          com.buildingfive.pgnhelper  2013      7
# 984                                    com.oxxo.tiendas  2013      7
# 985                                    org.prospekt0048  2013      7
# 986                               com.andrios.bodycards  2013      7
# 987                                    com.sportsoo.web  2013      7
# 988                                    org.prospekt0049  2013      7
# 989                                 za.co.McCarthy.Audi  2013      7
# 990                    com.enlight.santaschristmaselves  2013      7
# 991   com.gau.go.launcherex.theme.gowidget.taskmanag...  2013      7
# 992                                 com.gw2.legendaries  2013      7
# 993                              com.dontpanic.lpp.cyan  2013      7
# 994                 br.com.mobileninjas.pensamentododia  2013      7
# 995                         com.custom.lwp.BridgeLights  2013      7
# 996      com.uefa.football.champiansleague.europe.messi  2013      7
# 997                     com.gcsresearch.burkebiketrails  2013      7
# 998                                      com.Wallpaper2  2013      7
# 999                              pt.tmn.android.vamosla  2013      7
# 1000                      com.mymobilebookshelf.dracula  2013      7
#
# [1001 rows x 3 columns]

# %% [markdown]
# # NEWSIZE

# %%
@require(iter_json_gzip,gzip,datetime,re,csv)
def NEWSIZE(file_in,out_base,compress=1):
    headers = ['app_id', 'date', 'size'] # list of column names
    out_filename = out_base.format('NEWSIZE')
    running = {}
    with gzip.open(out_filename,'wt',compress) as out_file:
        csv_writer = csv.writer(out_file)
        csv_writer.writerow(headers)
        for json in iter_json_gzip(file_in):
            size = json.get('size','').lower()
            size = size.replace('varies with device','varies')
            if isinstance(size,str):
                size = size.strip()
                if running.get(json['app_id'],'')!=size and len(size)>0:
                    running[json['app_id']] = size
                    obs = [json['app_id'], str(datetime.date.fromtimestamp(int(json.get('timestamp', '')))), size]
                    csv_writer.writerow(obs)
    return out_filename

# %%
df_debug = None
if DEBUG:
    df_debug = read_csv(NEWSIZE(RAW_FILE,OUT_BASE,COMPRESS_LEVEL),compression='gzip',header=0)
df_debug
# Out:
#                                                  app_id        date    size
# 0                                com.touchtype.swiftkey  2013-07-17  varies
# 1                   com.gameloft.android.ANMP.GloftDMHM  2013-07-17     11m
# 2                           com.ibm.events.android.usga  2013-07-17     11m
# 3                                      com.dama.camera2  2013-07-17    5.1m
# 4                           com.disney.scribblefree_goo  2013-07-17     16m
# 5                                 com.gau.go.launcherex  2013-07-17  varies
# 6                              com.teslacoilsw.launcher  2013-07-17    2.9m
# 7                          com.levelup.beautifulwidgets  2013-07-17     12m
# 8           com.socialnmobile.dictdata.chinese.stardict  2013-07-17    1.1m
# 9                               com.mdb.android.xiangqi  2013-07-17    1.0m
# 10                                   io.avocado.android  2013-07-17    6.0m
# 11                                        flipboard.app  2013-07-17  varies
# 12                      com.mobincube.android.app_20866  2013-07-17    266k
# 13                                         com.at.proxi  2013-07-17    116k
# 14                      shopcoffeetable.com.coffeetable  2013-07-17    350k
# 15                          com.mini.flowers.angryfatty  2013-07-17    7.2m
# 16                            com.and.Wuthering_Heights  2013-07-17    6.8m
# 17                                     com.loltv.layout  2013-07-17    3.2m
# 18                         com.stopnplayapps.angryshark  2013-07-17    7.4m
# 19                           say.hello.worldsnookernews  2013-07-17    1.0m
# 20                                com.wolterskluwer.lsq  2013-07-17    841k
# 21           com.themesfordroid.hunterthemegolauncherex  2013-07-17    1.5m
# 22                          com.boxyz.androidteam.tsubo  2013-07-17    2.3m
# 23                             twig.nguyen.d2_runewords  2013-07-17    130k
# 24                                           com.Netter  2013-07-17     31m
# 25                                 com.gunvald.bigpenis  2013-07-17    438k
# 26                                     com.prapps.tokay  2013-07-17    746k
# 27                 com.quickmare.typingkeyboard.neurope  2013-07-17     73k
# 28                      Technicaljar.BluetoothAppBinder  2013-07-17    176k
# 29               com.jiubang.goscreenlock.theme.lighter  2013-07-17    461k
# ...                                                 ...         ...     ...
# 971                  com.miresoftware.sexyamateurs2free  2013-07-17    3.6m
# 972             Alfasoft.Widgets.PsychedelicAnalogClock  2013-07-17     95k
# 973                            com.Kaneosmare.BoeingC17  2013-07-17    1.1m
# 974                                     adit.weather.ta  2013-07-17    4.0m
# 975             com.andbling.wallpaper.live.names.ernie  2013-07-17    674k
# 976              com.coreapps.android.followme.fetc2013  2013-07-17    1.6m
# 977                             com.crossfield.frowline  2013-07-17     16m
# 978                com.mspinc.sexygirllivewallpaperLite  2013-07-17    5.7m
# 979                    org.guesswork.nightstand.digital  2013-07-17    1.4m
# 980                                de.wgsoft.scanmaster  2013-07-17    1.5m
# 981                    com.appsshoppe.hairlosstreatment  2013-07-17    5.4m
# 982                                      com.mobizel.ra  2013-07-17    4.1m
# 983                          com.buildingfive.pgnhelper  2013-07-17    178k
# 984                                    com.oxxo.tiendas  2013-07-17     21m
# 985                                    org.prospekt0048  2013-07-17    1.7m
# 986                               com.andrios.bodycards  2013-07-17    2.8m
# 987                                    com.sportsoo.web  2013-07-17    227k
# 988                                    org.prospekt0049  2013-07-17    1.2m
# 989                                 za.co.McCarthy.Audi  2013-07-17     10m
# 990                    com.enlight.santaschristmaselves  2013-07-17    3.2m
# 991   com.gau.go.launcherex.theme.gowidget.taskmanag...  2013-07-17    611k
# 992                                 com.gw2.legendaries  2013-07-17    1.9m
# 993                              com.dontpanic.lpp.cyan  2013-07-17     96k
# 994                 br.com.mobileninjas.pensamentododia  2013-07-17    1.1m
# 995                         com.custom.lwp.BridgeLights  2013-07-17    190k
# 996      com.uefa.football.champiansleague.europe.messi  2013-07-17    837k
# 997                     com.gcsresearch.burkebiketrails  2013-07-17    6.3m
# 998                                      com.Wallpaper2  2013-07-17    4.9m
# 999                              pt.tmn.android.vamosla  2013-07-17     27m
# 1000                      com.mymobilebookshelf.dracula  2013-07-17    4.7m
#
# [1001 rows x 3 columns]

# %% [markdown]
# # WEEKLYSCRAPE

# %%
@require(iter_json_gzip,gzip,datetime,re,csv)
def WEEKLYSCRAPE(file_in,out_base,compress=1):
    headers = ['app_id', 'year', 'week'] # list of column names
    out_filename = out_base.format('WEEKLYSCRAPE')
    running = {}
    with gzip.open(out_filename,'wt',compress) as out_file:
        csv_writer = csv.writer(out_file)
        csv_writer.writerow(headers)
        for json in iter_json_gzip(file_in):
            date = (str(datetime.date.fromtimestamp(json.get('timestamp','')).year), str(datetime.date.fromtimestamp(json.get('timestamp','')).isocalendar()[1]))
            if isinstance(date,tuple):
                if running.get(json['app_id'],'')!=date and len(date)>0:
                    running[json['app_id']] = date
                    obs = [json['app_id'], date[0], date[1]]
                    csv_writer.writerow(obs)
    return out_filename

# %%
df_debug = None
if DEBUG:
    df_debug = read_csv(WEEKLYSCRAPE(RAW_FILE,OUT_BASE,COMPRESS_LEVEL),compression='gzip',header=0)
df_debug
# Out:
#                                                  app_id  year  week
# 0                                com.touchtype.swiftkey  2013    29
# 1                   com.gameloft.android.ANMP.GloftDMHM  2013    29
# 2                           com.ibm.events.android.usga  2013    29
# 3                                      com.dama.camera2  2013    29
# 4                           com.disney.scribblefree_goo  2013    29
# 5                                 com.gau.go.launcherex  2013    29
# 6                              com.teslacoilsw.launcher  2013    29
# 7                          com.levelup.beautifulwidgets  2013    29
# 8           com.socialnmobile.dictdata.chinese.stardict  2013    29
# 9                               com.mdb.android.xiangqi  2013    29
# 10                                   io.avocado.android  2013    29
# 11                                        flipboard.app  2013    29
# 12                      com.mobincube.android.app_20866  2013    29
# 13                                         com.at.proxi  2013    29
# 14                      shopcoffeetable.com.coffeetable  2013    29
# 15                          com.mini.flowers.angryfatty  2013    29
# 16                            com.and.Wuthering_Heights  2013    29
# 17                                     com.loltv.layout  2013    29
# 18                         com.stopnplayapps.angryshark  2013    29
# 19                           say.hello.worldsnookernews  2013    29
# 20                                com.wolterskluwer.lsq  2013    29
# 21           com.themesfordroid.hunterthemegolauncherex  2013    29
# 22                          com.boxyz.androidteam.tsubo  2013    29
# 23                             twig.nguyen.d2_runewords  2013    29
# 24                                           com.Netter  2013    29
# 25                                 com.gunvald.bigpenis  2013    29
# 26                                     com.prapps.tokay  2013    29
# 27                 com.quickmare.typingkeyboard.neurope  2013    29
# 28                      Technicaljar.BluetoothAppBinder  2013    29
# 29               com.jiubang.goscreenlock.theme.lighter  2013    29
# ...                                                 ...   ...   ...
# 971                  com.miresoftware.sexyamateurs2free  2013    29
# 972             Alfasoft.Widgets.PsychedelicAnalogClock  2013    29
# 973                            com.Kaneosmare.BoeingC17  2013    29
# 974                                     adit.weather.ta  2013    29
# 975             com.andbling.wallpaper.live.names.ernie  2013    29
# 976              com.coreapps.android.followme.fetc2013  2013    29
# 977                             com.crossfield.frowline  2013    29
# 978                com.mspinc.sexygirllivewallpaperLite  2013    29
# 979                    org.guesswork.nightstand.digital  2013    29
# 980                                de.wgsoft.scanmaster  2013    29
# 981                    com.appsshoppe.hairlosstreatment  2013    29
# 982                                      com.mobizel.ra  2013    29
# 983                          com.buildingfive.pgnhelper  2013    29
# 984                                    com.oxxo.tiendas  2013    29
# 985                                    org.prospekt0048  2013    29
# 986                               com.andrios.bodycards  2013    29
# 987                                    com.sportsoo.web  2013    29
# 988                                    org.prospekt0049  2013    29
# 989                                 za.co.McCarthy.Audi  2013    29
# 990                    com.enlight.santaschristmaselves  2013    29
# 991   com.gau.go.launcherex.theme.gowidget.taskmanag...  2013    29
# 992                                 com.gw2.legendaries  2013    29
# 993                              com.dontpanic.lpp.cyan  2013    29
# 994                 br.com.mobileninjas.pensamentododia  2013    29
# 995                         com.custom.lwp.BridgeLights  2013    29
# 996      com.uefa.football.champiansleague.europe.messi  2013    29
# 997                     com.gcsresearch.burkebiketrails  2013    29
# 998                                      com.Wallpaper2  2013    29
# 999                              pt.tmn.android.vamosla  2013    29
# 1000                      com.mymobilebookshelf.dracula  2013    29
#
# [1001 rows x 3 columns]

# %% [markdown]
# #SNAPSHOTQUARTERLY

# %%
@require(iter_json_gzip,gzip,datetime,re,csv)
def SNAPSHOTQUARTERLY(file_in,out_base,compress=1):
    headers = ['app_id', 'quarter'] # list of column names
    out_filename = out_base.format('SNAPSHOTQUARTERLY')
    running = {}
    year = datetime.date.fromtimestamp(json.get('timestamp', '')).year
    with gzip.open(out_filename,'wt',compress) as out_file:
        csv_writer = csv.writer(out_file)
        csv_writer.writerow(headers)
        for json in iter_json_gzip(file_in):
            date = (str(datetime.date.fromtimestamp(json.get('timestamp','')).year), str(datetime.date.fromtimestamp(json.get('timestamp','')).isocalendar()[1]))
            quarter = str(date.year)+'-Q'+str(date.month/4+1)
            if isinstance(quarter, str):
                if running.get(json['app_id'],'')!=quarter and len(quarter)>0:
                    running[json['app_id']] = quarter
                    obs = [json['app_id'], quarter]
                    csv_writer.writerow(obs)
    return out_filename

# %%
df_debug = None
if DEBUG:
    df_debug = read_csv(SNAPSHOTQUARTERLY(RAW_FILE,OUT_BASE,COMPRESS_LEVEL),compression='gzip',header=0)
df_debug

# %% [markdown]
# # Run them all!

# %%
print("starting processing Google Data Request")
# Out:
# starting processing Google Data Request

# %%
specific_tables = """
NEWNAME
NEWINAPP
DAILYSCRAPE
MONTHLYSCRAPE
WEEKLYSCRAPE
""".split()

all_tables = [x for x in globals() 
              if callable(globals()[x]) 
              and x.isupper()]
all_tables
# Out:
# ['NEWUPDATED',
#  'MONTHLYSCRAPE',
#  'WEEKLYRATINGS',
#  'NEWSIMILAR5',
#  'NEWPRIVACYDOMAIN',
#  'DAILYSCRAPE',
#  'NEWCATEGORY',
#  'NEWSIZE',
#  'NEWWEBSITE',
#  'NEWPRICE',
#  'WEEKLYSCRAPE',
#  'NEWREQ',
#  'NEWINSTALL',
#  'NEWDEVELOPERNAME',
#  'DAILYRATINGS',
#  'MONTHLYRATINGS',
#  'NEWINAPP',
#  'NEWVERSION',
#  'NEWDEVELOPER',
#  'NEWNAME',
#  'NEWSIMILAR10',
#  'NEWSIMILAR15']

# %%
def run_function(f,RAW_FILE=RAW_FILE,OUT_BASE=OUT_BASE,COMPRESS_LEVEL=COMPRESS_LEVEL):
    return f(RAW_FILE ,OUT_BASE,COMPRESS_LEVEL)

for i,file in enumerate(map(run_function,[globals()[x] for x in all_tables])):
    print(i+1,file)
# Out:
# 1 /home/cgaray/data/out/MONTHLYRATINGS__google_play__main__2015_02_26_23_12.csv.gz
# 2 /home/cgaray/data/out/NEWDEVELOPERNAME__google_play__main__2015_02_26_23_12.csv.gz
# 3 /home/cgaray/data/out/NEWINAPP__google_play__main__2015_02_26_23_12.csv.gz
# 4 /home/cgaray/data/out/NEWSIMILAR5__google_play__main__2015_02_26_23_12.csv.gz
# 5 /home/cgaray/data/out/NEWCATEGORY__google_play__main__2015_02_26_23_12.csv.gz
# 6 /home/cgaray/data/out/NEWINSTALL__google_play__main__2015_02_26_23_12.csv.gz
# 7 /home/cgaray/data/out/WEEKLYSCRAPE__google_play__main__2015_02_26_23_12.csv.gz
# 8 /home/cgaray/data/out/NEWREQ__google_play__main__2015_02_26_23_12.csv.gz
# 9 /home/cgaray/data/out/MONTHLYSCRAPE__google_play__main__2015_02_26_23_12.csv.gz
# 10 /home/cgaray/data/out/NEWPRIVACYDOMAIN__google_play__main__2015_02_26_23_12.csv.gz
# 11 /home/cgaray/data/out/NEWUPDATED__google_play__main__2015_02_26_23_12.csv.gz
# 12 /home/cgaray/data/out/NEWDEVELOPER__google_play__main__2015_02_26_23_12.csv.gz
# 13 /home/cgaray/data/out/NEWVERSION__google_play__main__2015_02_26_23_12.csv.gz
# 14 /home/cgaray/data/out/DAILYRATINGS__google_play__main__2015_02_26_23_12.csv.gz
# 15 /home/cgaray/data/out/WEEKLYRATINGS__google_play__main__2015_02_26_23_12.csv.gz
# 16 /home/cgaray/data/out/NEWNAME__google_play__main__2015_02_26_23_12.csv.gz
# 17 /home/cgaray/data/out/NEWWEBSITE__google_play__main__2015_02_26_23_12.csv.gz
# 18 /home/cgaray/data/out/NEWPRICE__google_play__main__2015_02_26_23_12.csv.gz
# 19 /home/cgaray/data/out/NEWSIZE__google_play__main__2015_02_26_23_12.csv.gz
# 20 /home/cgaray/data/out/DAILYSCRAPE__google_play__main__2015_02_26_23_12.csv.gz
# 21 /home/cgaray/data/out/NEWSIMILAR15__google_play__main__2015_02_26_23_12.csv.gz
# 22 /home/cgaray/data/out/NEWSIMILAR10__google_play__main__2015_02_26_23_12.csv.gz

# %%
print("DONE")
# Out:
# DONE

# %%
print(len(all_tables))
# Out:
# 22
