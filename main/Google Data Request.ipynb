# %% [markdown]
# # Initialize Environment

# %% [markdown]
# ### Compatibility notes

# %% [markdown]
# The following code is only compatible with a python 3.4 kernel and the notebook must be opened with ipython 3.0+.
#
# The following libraries must be installed to run this code:
#
# ```pip install ujson```

# %%
from pdb import set_trace as debug
from pandas.io.parsers import read_csv
from IPython.parallel import Client,require
from collections import Counter

# %%
import ujson
import datetime
import re
import gzip
import csv

# %%
#--> RAW_FILE_DIR with the directory that contains google_play__main.json.gz
#--> OUT_DIR with the directory of where you want the processed files to go
#--> DEBUG whether to print out created CSV files or not
#--> COMPRESS_LEVEL gzip compression level. warning: severely impacts runtime.
#--> LINE_LIMIT how many lines to iterate through in the raw file. For debugging.
DUMP_DATE = '2015_02_26_23_12'
RAW_FILE_DIR = '/home/cgaray/data'
OUT_DIR = '/home/cgaray/data/out'
DEBUG = 1
COMPRESS_LEVEL = 1
LINE_LIMIT = 100
PARALLEL = 0

# %%
# Don't change these!
RAW_FILE = '{}/google_play__main.json.gz'.format(RAW_FILE_DIR)
OUT_BASE = OUT_DIR+'/{}__google_play__main__'+DUMP_DATE+'.csv.gz'

# %%
def iter_json_gzip(filename,LINE_LIMIT=LINE_LIMIT):
    with gzip.open(filename,'rt') as file_iter:
        c = 0
        for line in file_iter:
            c +=1
            if c > LINE_LIMIT and LINE_LIMIT>0:
                break
            yield ujson.loads(line)

# %%
# Print a couple observations to inspect daw data.
# !zcat "$RAW_FILE"|head -n 1000 | tail -n5
# Out:
# {"app_id":"com.custom.lwp.BridgeLights","ratings":[0,0,0,0,1],"month":7,"store_name":"google_play","size":"190k","content":"Everyone","hostname":"equity4.mit.edu","requires":"2.1 and up","website":"http:\/\/manumandroidapp.blogspot.com\/&sa=D&usg=AFQjCNGPFmMP-3N1t7XLfyI8TTF2lgZj9A","version":"1.0","year":2013,"category":"PERSONALIZATION","developer_name":"manum app","email":"manu_m.91@hotmail.it","screenshots":2,"timestamp":1374095742,"description":"<div>Bridge Lights is a Live Wallpaper.<p>After you have downloaded and installed it,  You need in order to set it  as a Live Wallpaper:<p>- go to your home screen;<br>- press the menu button on your device;<br>- select &quot;Wallpaper&quot;;<br>- select &quot;Live Wallpapers&quot;;<br>- search and select for this Live Wallpaper&quot;<br>- select &quot;Settings&quot; to see the settings or select &quot;Set wallpaper&quot; to activate it.<p>System Requirement:<p>any phone that came with Android OS 2.0 or later should work fine. Anything that came with 1.5 \/ 1.6 may have problems<p>Tags:Bridge Lights Live wallpapers Sky Blue Light White water city<\/div>","price":0,"badges":[],"day":17,"similar_apps":["com.marieluke.tsiangmaroad.free","mma.wallpaper.nativamericans.lite","com.marieluke.stonecuttersnight.free","com.joko.lightgridpro","fishnoodle.snowfall","com.maxelus.freshleaveslivewallpaper","com.jetblacksoftware.xmastreewallpaperpaid","com.whatsapp.wallpaper","com.live.wallpaper.autumn","fishnoodle.koipond","fishnoodle.koipond_free","fishnoodle.night_city","fishnoodle.aquarium","fishnoodle.silhouette","fishnoodle.storm","com.xllusion.livewallpaper.spectrumpro"],"recent_changes":[],"installs":"100 - 500","developer_id":"manum+app","hour":17,"updated":"April 20, 2011","app_name":"Bridge Lights Live Wallpaper","SCRAPER_VERSION":2,"developer_other":["com.custom.lwp.HeartandButterfly","com.custom.lwp.SmallTigerUndertheStars","com.custom.lwp.GlitterILoveYou","com.custom.lwp.IloveyouPink","com.custom.lwp.GlitterHearts","com.custom.lwp.BeautifulButterfly","com.custom.lwp.ILoveYouWriting","com.custom.lwp.GlitterUnicornandFairy","com.custom.lwp.Stars","com.custom.lwp.BirdandButterfly","com.custom.lwp.HorseatNight","com.custom.lwp.FadedBlueButterfly","com.custom.lwp.FlowersGlitter","com.custom.lwp.MSweetKitten","com.custom.lwp.LovelyDancer","com.custom.lwp.DiamondRose"]}
# {"app_id":"com.uefa.football.champiansleague.europe.messi","ratings":[11,2,0,1,0],"month":7,"store_name":"google_play","size":"837k","content":"Everyone","hostname":"equity5.mit.edu","requires":"1.6 and up","website":"https:\/\/www.facebook.com\/aso.lab.9&sa=D&usg=AFQjCNFpz26IH3omrFa7ETHmlwnYNDPENQ","version":"2.4","year":2013,"category":"SPORTS","developer_name":"ASO Lab","email":"aso.lab2012@gmail.com","screenshots":4,"timestamp":1374095743,"description":"<div>UEFA Champions League<br>Developed by Mahmud Hasan and Ashish Chakrabarty<p>Current champions\t Chelsea (1st title)<br>Most successful club(s)\t Real Madrid (9 titles)<br>Television broadcasters\tList of broadcasters<br>Website\tOfficial website<br>2012\u201313 UEFA Champions League<br>The UEFA Champions League \/ju\u02d0\u02c8e\u026af\u0259 \u02c8t\u0283\u00e6mpi\u0259nz \u02c8li\u02d0\u0261\/, known simply as the Champions League, and originally known as the European Champion Clubs&#39; Cup or European Cup, is an annual continental club football competition organised by the Union of European Football Associations (UEFA) since 1955 for the top football clubs in Europe.[1] It is one of the most prestigious tournaments in the world and the most prestigious club competition in European football. The final of the 2011 tournament was the most-watched UEFA Champions League final to date, as well as the most watched annual sporting event worldwide that year, drawing 178.7 million television viewers.[2]Prior to 1992, the tournament was officially called the &quot;European Champion Clubs&#39; Cup&quot;, but was usually referred to simply as the &quot;European Cup&quot;.[1] The competition was initially a straight knockout competition open only to the champion club of each country.[1] During the 1990s, the tournament began to be expanded, incorporating a round-robin group phase and more teams.[1] Europe&#39;s strongest national leagues now provide up to four teams each for the competition.[3] The UEFA Champions League should not be confused with the UEFA Europa League, formerly known as the UEFA Cup.[4]Its a quiz app consisting 100+ questions on champions leagueThe tournament consists of several stages.In the present format, it begins in mid-July with three knockout qualifying rounds and a play-off round. The 10 surviving teams join 22 seeded teams in the group stage, in which there are eight groups of four teams each. The eight group winners and eight runners-up enter the final knockout phase, which culminates with the final match in May. The winner of the UEFA Champions League qualifies for the UEFA Super Cup and the FIFA Club World Cup.Real Madrid is the most successful club in the competition&#39;s history, having won the tournament nine times, including the first five seasons it was contested.Spanish clubs have accumulated the highest number of victories, with 13 wins. The title has been won by 22 different clubs, 12 of which have won the title more than once.Since the tournament changed name and structure in 1992, no club has managed consecutive wins, with Milan being the last club to successfully defend their title, in 1990.The reigning champions of the competition are Chelsea, after beating Bayern Munich 4\u20133 on penalties, following a 1\u20131 draw after extra time.<\/div>","price":0,"badges":[],"day":17,"similar_apps":["de.motain.iliga","com.afl.ucom.view","com.blueskyapps.worldcupcountdown","de.fcbayern.android","com.mappd.footballcup","com.jalvasco.football.worldcup","com.lilait.oba.messi","com.lilait.oba.crronaldo","es.lfp.gi.main","com.appshen.frameworks.blade","bic.ronaldo.cronaldo","com.mobilefootie.fotmobpro","com.livescore","com.fivemobile.thescore","com.sabakat.vubooo","com.espn.espnfantasyfootball"],"recent_changes":[],"installs":"1,000 - 5,000","developer_id":"ASO+Lab","hour":17,"updated":"April 12, 2013","app_name":"Champions league football quiz","SCRAPER_VERSION":2,"developer_other":["com.asolab.radiohubmexico","com.asolab.jazz88","com.anikasharmin.an ...
# {"app_id":"com.gcsresearch.burkebiketrails","ratings":[2,0,0,0,1],"month":7,"store_name":"google_play","size":"6.3M","content":"Low Maturity","hostname":"equity3.mit.edu","requires":"2.2 and up","website":"http:\/\/www.gcs-research.com\/&sa=D&usg=AFQjCNG6wYAEJGbj8-lR43vWXt-WK5Qf7Q","version":"1.3","year":2013,"category":"TOOLS","developer_name":"GCS Research","email":"jwaterman@gcs-research.com","screenshots":2,"timestamp":1374095744,"description":"<div>The Burke Vermont Bike Trails App was developed by GCS Research, an award winning geospatial technology company. <p>Services provided by Esri ArcGIS Online.<p>www.gcs-research.com<\/div>","price":0,"badges":[],"day":17,"similar_apps":["com.esri.android.client","me.scan.android.client","com.promt.pmtappfree","com.gcs.mapsVT","uk.co.autotrader.androidconsumersearch","com.smsBlocker","com.promt.pmtappsale","com.vistechprojects.planimeter","com.unitedinternet.portal.android.onlinestorage.webde","com.esri.arcgis.collector","de.einsundeins.smartdrive","javalc6.thesaurus","com.sileria.alsalah","com.greatclips.android","com.h3r3t1c.onnandbup","com.ejelta.whereami"],"recent_changes":[],"installs":"500 - 1,000","developer_id":"GCS+Research","hour":17,"updated":"April 24, 2012","app_name":"Burke Vermont Bike Trail Map","SCRAPER_VERSION":2,"developer_other":["com.gcsresearch.soilmap","com.gcs.maps2","com.gcsresearch.activewildlandfires","com.gcsresearch.floodzones","com.gcsresearch.streamgauges","com.gcs.mapsSD","com.gcsresearch.oceanmap","com.gcsresearch.oil","com.gcsresearch.nuclearsites","com.gcsresearch.medianincome","com.gcsresearch.sandiegoplaces","com.gcsresearch.cameras","com.gcsresearch.totalcrimemap","com.gcsresearch.usdaenergyinvestments","com.gcsresearch.usfirehistorymap","com.gcsresearch.populationgrowth"]}
# {"app_id":"com.Wallpaper2","ratings":[16,6,0,0,2],"month":7,"store_name":"google_play","size":"4.9M","content":"Everyone","hostname":"equity5.mit.edu","requires":"2.1 and up","website":"https:\/\/sites.google.com\/site\/sightsoft\/&sa=D&usg=AFQjCNHkUHJPcGOGfQIFRYTwA6If0f-S0Q","version":"1.0.2e","year":2013,"category":"PERSONALIZATION","developer_name":"SIGHTSOFT","email":"sightsoft.8000@gmail.com","screenshots":4,"timestamp":1374095745,"description":"<div>Beautiful wallpapers of Virgin Mary Mother of our Lord Jesus Christ. Renaissance art, high definition, meticulously remastered, wide format, cover all 5 views of Android home screen. Many wall papers support 960 x 800 (480 x 800 screen), 960 x 854 (960 x 854 screen). Support moving app to SD card.<p><br>* New wall papers! Full version &quot;Virgin Mary LWP Donation&quot; has new Live Wallpapers of Virgin Mary with rotating images and prayers you know and love, and many new ones by SIGHTSOFT. In Italian (Italiano), Spanish (Espa\u00f1ol)!<p>https:\/\/market.android.com\/details?id=com.sightsoft.VirginMaryDonationLWP<p>\u2665 Holy and pure <br>\u2665 Gorgeous artworks <p>God bless you!<p>***** Wallpaper button to set wallpaper. Android device back button to go back to resolution selection.<p>Please rate and comment. Please contact me at <a href=\"mailto:sightsoft.8000@gmail.com\">sightsoft.8000@gmail.com<\/a> for bugs and suggestions.<p>Sch\u00f6ne Kunst der Renaissance Wallpaper von jungfrau Maria Mutter unseres Herrn Jesus Christus.<p>Belle carte da parati arte di rinascimentali della Vergine Maria Madre del Signore nostro Ges\u00f9 Cristo. Rinascimento italiano.<p>Live wallpaper de la Virgen Mar\u00eda, madre de nuestro Se\u00f1or Jesucristo. Oraciones a la Virgen Mar\u00eda acompa\u00f1ada de obras de arte hermosas del Alto Renacimiento.<p>Vergine Maria Live Wallpaper, bella, arte, sacro e puro.<p>\u8056\u6bcd\u30de\u30ea\u30a2\u7f8e\u3057\u3044\u30e9\u30a4\u30d6\u58c1\u7d19\u3002<p>\uc131\ubaa8 \ub9c8\ub9ac\uc544 \uac70\ub8e9\ud55c, \uc544\ub984\ub2e4\uc6b4 \ub77c\uc774\ube0c \ubcbd\uc9c0.<p>\u6211\u4eec\u7684\u4e3b\u8036\u7a23\u57fa\u7763\u5723\u6bcd\u739b\u5229\u4e9a\u7684\u6bcd\u4eb2\u7f8e\u4e3d\uff0c\u5723\u6d01\u548c\u7eaf\u51c0\u7684\u58c1\u7eb8\u3002<p>More paintings, more supported screen sizes coming soon.<p>Artists:<br>Carlo Dolci<br>Raphael, Raffaello Sanzio da Urbino<br>Giovanni Battista Salvi da Sassoferrato<p>christian, god, Madonna, church, bible, fine art, pre-raphaelite, gallery, High Renaissance, prayers, liturgy, heaven, catholic, Maria, light, heaven, faith, spirituality, religious, religion, consecration, sacred<\/div>","price":0,"badges":[],"day":17,"similar_apps":["com.flyingfox.supercube_virginmary_free","com.sunshineapps.virginmary","com.certificomobile.virginmarylivewallpaper","net.zedge.android","com.gannicus.android.tablet.wallpapersbay","fishnoodle.koipond_free","pterry.android.bibleverses.livewallpaper","fishnoodle.aquarium","fishnoodle.koipond","com.srsdev.wallpapers","fishnoodle.aquarium_free","kov.theme.tersus","com.androidwasabi.livewallpaper.dandelion","fishnoodle.fire","com.androidesk","com.tribok.android.livewallpaper.xdiamond.pro"],"recent_changes":["03\/20\/2013, Version 1.0.2e","* Minor bug fixes.","* Please try new free game Chicken Defense Free from SIGHTSOFT, hilarious funny!","https:\/\/play.google.com\/store\/apps\/details?id=com.sightsoft.BarnYardDefenseFree"],"installs":"5,000 - 10,000","developer_id":"SIGHTSOFT","hour":17,"updated":"March 20, 2013","app_name":"Virgin Mary Wallpaper Free","SCRAPER_VERSION":2,"developer_other":["com.sightsoft.VirginMaryLWP","com.sightsoft.GoldenDawnFree","com.sightsoft.FirstKissFree","com.sightsoft.WoodLand","com.sightsoft.HeartsAndFlowersLWPFree","com.sightsoft.HailMaryLite","com.sightsoft.PrayersPsalmsLite","com.sightsoft.CrossesLWPFree","com.sightsoft.VirginMaryDonationLWP","com.sightsoft.SmileysFree","com.sightsoft.JesusChristInArt","com.sightsoft.FirstKiss","com.sightsoft.EnchantedForest", ...
# {"app_id":"pt.tmn.android.vamosla","ratings":[6,0,0,0,3],"month":7,"store_name":"google_play","size":"27M","content":"Everyone","hostname":"stanfordscrape1","requires":"2.2 and up","website":"http:\/\/vamosla.pt&sa=D&usg=AFQjCNE_Sh10AztP4G0BDhZe5cUDjjtK5g","version":"1.1","year":2013,"category":"ENTERTAINMENT","developer_name":"PT Comunica\u00e7\u00f5es","email":"sapomobile@sapo.pt","screenshots":5,"timestamp":1374095746,"description":"<div>A App TMN &quot;Vamos l\u00e1.&quot; permite-lhe consultar a nova campanha a partir do seu smartphone.<p>Surpreenda-se com conte\u00fados exclusivos que criamos para si atrav\u00e9s de Realidade Aumentada totalmente inovadora.<p>Siga as instru\u00e7\u00f5es e aponte a c\u00e2mara do seu smartphone para os rostos da nova campanha da TMN &quot;Vamos L\u00e1.&quot;, aceda a imagens e filmes com testemunhos de pessoas que acreditaram e marcaram a diferen\u00e7a.<p>Visualize os v\u00eddeos, onde os rostos da campanha prestam o seu testemunho.<p>Leia o nosso manifesto, veja o filme da campanha e entre na galeria onde se encontram todas as imagens daqueles que acreditam.<p>Divirta-se partilhando a App com os seus amigos.<p>- Clips<br>- Manifesto<br>- Spot<br>- Galeria<p>Portugal est\u00e1 a chamar.<p>Vamos l\u00e1.<p>O SAPO, TMN, MEO, PT NEG\u00d3CIOS E PT PRIME s\u00e3o marcas do Grupo Portugal Telecom.<\/div>","price":0,"badges":[],"day":17,"similar_apps":["de.fastline.kinoradar","pt.ptinovacao.rma.meomobile","com.td.prisa.los40","de.filmstarts.android","de.burgerking.kingfinder","com.spodtronic.radio.energydeutschland","com.td.prisa.maxima","com.greatclips.android","com.appturbo.appturboSE","de.krankikom.uci_kinowelt","com.ityis.mobile.recetas","br.com.rommel.detectormentiras","com.airunapps.animales","se.mtg.freetv.nova_bg","de.radio.android.prime","pt.meo.android.meocode"],"recent_changes":["Actualiza\u00e7\u00e3o apenas para correc\u00e7\u00e3o de pequenos erros de aplica\u00e7\u00e3o:","- Feedback em partilha via facebook;","- Inclus\u00e3o de tutorial da aplica\u00e7\u00e3o;","- Correc\u00e7\u00f5es de navegabilidade nas fotos e v\u00eddeos."],"installs":"500 - 1,000","developer_id":"PT+Comunica%C3%A7%C3%B5es","hour":17,"updated":"April 20, 2012","app_name":"Vamos l\u00e1","SCRAPER_VERSION":2,"developer_other":["pt.sapo.mobile.android.newsstand","pt.sapo.mobile.android.dezoitovinte","pt.sapo.mobile.android.futebol","pt.sapo.mobile.android.sapomobile","com.ndrive.androidtmndrive","pt.sapo.mobile.android.sapostore","pt.sapo.mobile.android.tmn.it","pt.sapo.mobile.android.pesquisa","pt.tmn.android.ptcenter","pt.sapo.android.cloudpt","pt.sapo.mobile.android.cinema","com.ndrive.androidtmndrivehd","pt.sapo.mobile.android.ptwifi","pt.sapo.mobile.android.sabores","pt.sapo.android.transportes","pt.sapo.mobile.android.energiatmn"]}
#
# gzip: stdout: Broken pipe

# %% [markdown]
# #Initialize Parallel Processing

# %%
if PARALLEL:
    ipython_parallel = Client()
    print("{} active computing engines".format(len(ipython_parallel.ids)))

    lbv = ipython_parallel.load_balanced_view()

    map = lambda f,itertable:lbv.map(f,itertable,\
    block =False,\
    ordered =False)

    @require('socket')
    def host(dummy):
        return socket.gethostname()
    
    nodes = list(lbv.map(host,ipython_parallel.ids))
    nodes = [int(x.split('equity')[1].split(".")[0]) for x in nodes]
    nodes = sorted(nodes)

    print(list(Counter(nodes).items()))

# %% [markdown]
# # Daily Ratings -- DAILYRATINGS

# %%
@require(iter_json_gzip,'ujson','datetime','re','gzip','csv')
def DAILYRATINGS(file_in,out_base,compress=1):
    headers = ['app_id','date','rating5','rating4','rating3','rating2','rating1']
    out_filename = out_base.format('DAILYRATINGS')
    unique_daily_rating = set()
    with gzip.open(out_filename,'wt',compress) as out_file:
        csv_writer = csv.writer(out_file)
        csv_writer.writerow(headers)
        for json in iter_json_gzip(file_in):
            day = datetime.datetime.fromtimestamp(int(json['timestamp']))\
                                .strftime('%Y-%m-%d')
            rating = json.get('ratings',None)
            if rating:
                obs = (json['app_id'],day,tuple(rating),)
                if hash(obs) not in unique_daily_rating:
                    unique_daily_rating.add(hash(obs))
                    csv_writer.writerow([json['app_id'],day]+rating)
    return out_filename

# %%
df_debug = None
if DEBUG:
    df_debug = read_csv(DAILYRATINGS(RAW_FILE,OUT_BASE,COMPRESS_LEVEL),compression='gzip',header=0)
df_debug
# Out:
#                                                app_id        date  rating5  \
# 0                              com.touchtype.swiftkey  2013-07-17   162422
# 1                 com.gameloft.android.ANMP.GloftDMHM  2013-07-17   291722
# 2                         com.ibm.events.android.usga  2013-07-17      420
# 3                                    com.dama.camera2  2013-07-17      152
# 4                         com.disney.scribblefree_goo  2013-07-17     1209
# 5                               com.gau.go.launcherex  2013-07-17  1011807
# 6                            com.teslacoilsw.launcher  2013-07-17    59107
# 7                        com.levelup.beautifulwidgets  2013-07-17    53501
# 8         com.socialnmobile.dictdata.chinese.stardict  2013-07-17      481
# 9                             com.mdb.android.xiangqi  2013-07-17       40
# 10                                 io.avocado.android  2013-07-17     2067
# 11                                      flipboard.app  2013-07-17   153386
# 12                    com.mobincube.android.app_20866  2013-07-17        1
# 13                                       com.at.proxi  2013-07-17        4
# 14                    shopcoffeetable.com.coffeetable  2013-07-17        2
# 15                        com.mini.flowers.angryfatty  2013-07-17      323
# 16                          com.and.Wuthering_Heights  2013-07-17        0
# 17                                   com.loltv.layout  2013-07-17       15
# 18                       com.stopnplayapps.angryshark  2013-07-17        1
# 19                         say.hello.worldsnookernews  2013-07-17      237
# 20                              com.wolterskluwer.lsq  2013-07-17        0
# 21         com.themesfordroid.hunterthemegolauncherex  2013-07-17       11
# 22                        com.boxyz.androidteam.tsubo  2013-07-17       14
# 23                           twig.nguyen.d2_runewords  2013-07-17       77
# 24                                         com.Netter  2013-07-17       35
# 25                               com.gunvald.bigpenis  2013-07-17       37
# 26                                   com.prapps.tokay  2013-07-17        6
# 27               com.quickmare.typingkeyboard.neurope  2013-07-17        0
# 28                    Technicaljar.BluetoothAppBinder  2013-07-17        4
# 29             com.jiubang.goscreenlock.theme.lighter  2013-07-17     1021
# ..                                                ...         ...      ...
# 70                          com.futurek.android.ShoDo  2013-07-17       90
# 71                                 com.nuyork.adwblue  2013-07-17     1528
# 72                            jp.stack.android.ko104a  2013-07-17        3
# 73                          com.bestapproach.greyrock  2013-07-17        0
# 74                                   com.ft451.madrid  2013-07-17        6
# 75                              com.appmakr.app492132  2013-07-17        0
# 76                   com.leslivresoublies.conjugaison  2013-07-17        4
# 77                              com.appmakr.app155827  2013-07-17        0
# 78  com.gau.go.launcherex.theme.theme.end.of.the.w...  2013-07-17       13
# 79                                com.wallpaper.Brand  2013-07-17        1
# 80                 com.hd.wallpapers.polar.white.bear  2013-07-17        1
# 81                         com.assister.JigSaw.Luntik  2013-07-17        4
# 82                com.foundero.countryfacts.Australia  2013-07-17        7
# 83                       com.isc.arbor.toefl.adv.rev1  2013-07-17        1
# 84                     com.springcitysoftware.fenelon  2013-07-17        6
# 85                              com.jw.android.nfcpro  2013-07-17        9
# 86                                   tv.iam.magicalch  2013-07-17        0
# 87                           com.fo0lb0xpro.techbench  2013-07-17        0
# 88                                          com.voval  2013-07-17        7
# 89                            air.YourDailyMotivation  2013-07-17        6
# 90                       com.dreamoholic.connect.four  2013-07-17       45
# 91                                  com.vecal.vco.rda  2013-07-17        1
# 92                        com.teriidi.kristinkreuklwp  2013-07-17        4
# 93                              com.hoaxoantim.nhn365  2013-07-17        9
# 94         csl.virtual.inspection.scissor.free.market  2013-07-17        5
# 95    air.com.GoldCupGames.KitchenCatPickmeupTiramisu  2013-07-17        0
# 96                                 com.and.SevenSeven  2013-07-17        0
# 97                        com.pocket.lambforthedragon  2013-07-17      151
# 98                 com.enyetech.radio.coca_cola.fm_hn  2013-07-17        2
# 99                                  com.stiga.mirmult  2013-07-17      217
#
#     rating4  rating3  rating2  rating1
# 0     33001     6799     2879     4429
# 1     45460    13064     4439    18714
# 2        97       65       46       87
# 3        49       23       10        9
# 4       219      178      139      713
# 5    233232    79681    22214    44348
# 6     11001     2450      764     1113
# 7     15796     5546     3248     6737
# 8       253      129       36       58
# 9        20        8        5       23
# 10      955      536      227      322
# 11    50762    10884     2876     5652
# 12        0        0        0        0
# 13        0        0        0        1
# 14        0        3        0       10
# 15       79       58       19       81
# 16        0        0        0        0
# 17        7        1        0        0
# 18        0        0        0        0
# 19      179      242       86      104
# 20        0        0        0        0
# 21        5        2        0        4
# 22       17        6        3        4
# 23       12        6        2       10
# 24       11       14        7        9
# 25        4        2        0        6
# 26        2        0        0        0
# 27        0        0        0        0
# 28        2        1        1        1
# 29      239      102       41       84
# ..      ...      ...      ...      ...
# 70       74       50       19       24
# 71      470      207       66      125
# 72        0        0        0        0
# 73        0        0        0        0
# 74        0        0        1        1
# 75        0        0        0        0
# 76        0        1        0        1
# 77        0        0        0        0
# 78        2        0        0        1
# 79        0        0        0        0
# 80        0        0        0        0
# 81        0        0        0        3
# 82        1        0        0        0
# 83        0        0        1        0
# 84        0        0        0        0
# 85        2        0        0        2
# 86        0        0        0        0
# 87        0        0        0        0
# 88        0        0        0        1
# 89        1        1        0        1
# 90        0        1        1        1
# 91        0        0        0        0
# 92        1        0        0        0
# 93        2        0        1        1
# 94        0        1        0        0
# 95        0        0        0        0
# 96        0        0        0        0
# 97       27       14        3       30
# 98        0        0        0        1
# 99       33       17        6       52
#
# [100 rows x 7 columns]

# %% [markdown]
# # Developer - app_id -- NEWDEVELOPER

# %%
@require(iter_json_gzip,'ujson','datetime','re','gzip','csv')
def NEWDEVELOPER(file_in,out_base,compress=1):
    headers = ['app_id','date','dev_id']
    out_filename = out_base.format('NEWDEVELOPER')
    running = {}
    with gzip.open(out_filename,'wt',compress) as out_file:
        csv_writer = csv.writer(out_file)
        csv_writer.writerow(headers)
        for json in iter_json_gzip(file_in):
            developer = json.get('developer_id','')
            if developer == None:
                continue
            developer = developer.strip()
            if running.get(json['app_id'],'')!=developer:
                running[json['app_id']] = developer
                day = datetime.datetime.fromtimestamp(int(json['timestamp']))\
                        .strftime('%Y-%m-%d')
                obs = (json['app_id'],day,developer)
                csv_writer.writerow(obs) 
    return out_filename

# %%
df_debug = None
if DEBUG:
    df_debug = read_csv(NEWDEVELOPER(RAW_FILE,OUT_BASE,COMPRESS_LEVEL),compression='gzip',header=0)
df_debug
# Out:
#                                                app_id        date  \
# 0                              com.touchtype.swiftkey  2013-07-17
# 1                 com.gameloft.android.ANMP.GloftDMHM  2013-07-17
# 2                         com.ibm.events.android.usga  2013-07-17
# 3                                    com.dama.camera2  2013-07-17
# 4                         com.disney.scribblefree_goo  2013-07-17
# 5                               com.gau.go.launcherex  2013-07-17
# 6                            com.teslacoilsw.launcher  2013-07-17
# 7                        com.levelup.beautifulwidgets  2013-07-17
# 8         com.socialnmobile.dictdata.chinese.stardict  2013-07-17
# 9                             com.mdb.android.xiangqi  2013-07-17
# 10                                 io.avocado.android  2013-07-17
# 11                                      flipboard.app  2013-07-17
# 12                    com.mobincube.android.app_20866  2013-07-17
# 13                                       com.at.proxi  2013-07-17
# 14                    shopcoffeetable.com.coffeetable  2013-07-17
# 15                        com.mini.flowers.angryfatty  2013-07-17
# 16                          com.and.Wuthering_Heights  2013-07-17
# 17                                   com.loltv.layout  2013-07-17
# 18                       com.stopnplayapps.angryshark  2013-07-17
# 19                         say.hello.worldsnookernews  2013-07-17
# 20                              com.wolterskluwer.lsq  2013-07-17
# 21         com.themesfordroid.hunterthemegolauncherex  2013-07-17
# 22                        com.boxyz.androidteam.tsubo  2013-07-17
# 23                           twig.nguyen.d2_runewords  2013-07-17
# 24                                         com.Netter  2013-07-17
# 25                               com.gunvald.bigpenis  2013-07-17
# 26                                   com.prapps.tokay  2013-07-17
# 27               com.quickmare.typingkeyboard.neurope  2013-07-17
# 28                    Technicaljar.BluetoothAppBinder  2013-07-17
# 29             com.jiubang.goscreenlock.theme.lighter  2013-07-17
# ..                                                ...         ...
# 70                          com.futurek.android.ShoDo  2013-07-17
# 71                                 com.nuyork.adwblue  2013-07-17
# 72                            jp.stack.android.ko104a  2013-07-17
# 73                          com.bestapproach.greyrock  2013-07-17
# 74                                   com.ft451.madrid  2013-07-17
# 75                              com.appmakr.app492132  2013-07-17
# 76                   com.leslivresoublies.conjugaison  2013-07-17
# 77                              com.appmakr.app155827  2013-07-17
# 78  com.gau.go.launcherex.theme.theme.end.of.the.w...  2013-07-17
# 79                                com.wallpaper.Brand  2013-07-17
# 80                 com.hd.wallpapers.polar.white.bear  2013-07-17
# 81                         com.assister.JigSaw.Luntik  2013-07-17
# 82                com.foundero.countryfacts.Australia  2013-07-17
# 83                       com.isc.arbor.toefl.adv.rev1  2013-07-17
# 84                     com.springcitysoftware.fenelon  2013-07-17
# 85                              com.jw.android.nfcpro  2013-07-17
# 86                                   tv.iam.magicalch  2013-07-17
# 87                           com.fo0lb0xpro.techbench  2013-07-17
# 88                                          com.voval  2013-07-17
# 89                            air.YourDailyMotivation  2013-07-17
# 90                       com.dreamoholic.connect.four  2013-07-17
# 91                                  com.vecal.vco.rda  2013-07-17
# 92                        com.teriidi.kristinkreuklwp  2013-07-17
# 93                              com.hoaxoantim.nhn365  2013-07-17
# 94         csl.virtual.inspection.scissor.free.market  2013-07-17
# 95    air.com.GoldCupGames.KitchenCatPickmeupTiramisu  2013-07-17
# 96                                 com.and.SevenSeven  2013-07-17
# 97                        com.pocket.lambforthedragon  2013-07-17
# 98                 com.enyetech.radio.coca_cola.fm_hn  2013-07-17
# 99                                  com.stiga.mirmult  2013-07-17
#
#                                   dev_id
# 0                               SwiftKey
# 1                               Gameloft
# 2   United+States+Golf+Association,+USGA
# 3                              JFDP+Labs
# 4                                 Disney
# 5                   GO+Launcher+Dev+Team
# 6                     TeslaCoil+Software
# 7                         LevelUp+Studio
# 8                                  Notes
# 9                          MDB+Softwares
# 10                Avocado+Software,+Inc.
# 11                             Flipboard
# 12                                 Husic
# 13                          AboveThought
# 14                     Real+Valuable+LLC
# 15                          Mini+Flowers
# 16                             KijuI%26T
# 17                             Darr2cool
# 18                    Stop+'N'+Play+Apps
# 19                   sayhellowavegoodbye
# 20                 Wolters+Kluwer+France
# 21                      Themes+For+Droid
# 22                            Boxyz,inc.
# 23                           Twig+Nguyen
# 24                   Elsevier+Masson+SAS
# 25                        Mikkel+Gunvald
# 26                    PrApps+Development
# 27                     Quickmare+Studios
# 28                      Technicaljar.com
# 29                                ZT.art
# ..                                   ...
# 70                           Futurek.Inc
# 71                             Sean+York
# 72                            STACK+inc.
# 73                         Best+Approach
# 74        Free+Travel+%26+Tourist+Guides
# 75               GLM+Omnimedia+Group+LLC
# 76                               Olivier
# 77                         Murice+Miller
# 78                               CL+TEAM
# 79                             Ofic+S.L.
# 80                               cupcina
# 81                                 Kutin
# 82                              Foundero
# 83                          iStudyCampus
# 84          Spring+City+Software+Company
# 85                             Brian8701
# 86        %EF%BC%88%E6%A0%AA%EF%BC%89IAM
# 87                        TechBench,+LLC
# 88                          parker87tinh
# 89                                 Ficho
# 90                                  PacQ
# 91                         Vecal+Company
# 92                   Teriidi+Development
# 93                          Hoa+Xoan+Tim
# 94                                   CSL
# 95                           Kitchen+Cat
# 96                             KijuI%26T
# 97                         Pocket+Wolves
# 98                     ENYE+TECHNOLOGIES
# 99                             MSK+Media
#
# [100 rows x 3 columns]

# %% [markdown]
# # Category - app_id -- NEWCATEGORY

# %%
@require(iter_json_gzip,'ujson','datetime','re','gzip','csv')
def NEWCATEGORY(file_in,out_base,compress=1):
    headers = ['app_id','date','category']
    out_filename = out_base.format('NEWCATEGORY')
    running = {}
    with gzip.open(out_filename,'wt',compress) as out_file:
        csv_writer = csv.writer(out_file)
        csv_writer.writerow(headers)
        for json in iter_json_gzip(file_in):
            category = json.get('category','')
            if category == None:
                continue
            category = category.strip()
            if running.get(json['app_id'],'')!=category:
                running[json['app_id']] = category
                day = datetime.datetime.fromtimestamp(int(json['timestamp']))\
                        .strftime('%Y-%m-%d')
                obs = (json['app_id'],day,category)
                csv_writer.writerow(obs) 
    return out_filename

# %%
df_debug = None
if DEBUG:
    df_debug = read_csv(NEWCATEGORY(RAW_FILE,OUT_BASE,COMPRESS_LEVEL),compression='gzip',header=0)
df_debug
# Out:
#                                                app_id        date  \
# 0                              com.touchtype.swiftkey  2013-07-17
# 1                 com.gameloft.android.ANMP.GloftDMHM  2013-07-17
# 2                         com.ibm.events.android.usga  2013-07-17
# 3                                    com.dama.camera2  2013-07-17
# 4                         com.disney.scribblefree_goo  2013-07-17
# 5                               com.gau.go.launcherex  2013-07-17
# 6                            com.teslacoilsw.launcher  2013-07-17
# 7                        com.levelup.beautifulwidgets  2013-07-17
# 8         com.socialnmobile.dictdata.chinese.stardict  2013-07-17
# 9                             com.mdb.android.xiangqi  2013-07-17
# 10                                 io.avocado.android  2013-07-17
# 11                                      flipboard.app  2013-07-17
# 12                    com.mobincube.android.app_20866  2013-07-17
# 13                                       com.at.proxi  2013-07-17
# 14                    shopcoffeetable.com.coffeetable  2013-07-17
# 15                        com.mini.flowers.angryfatty  2013-07-17
# 16                          com.and.Wuthering_Heights  2013-07-17
# 17                                   com.loltv.layout  2013-07-17
# 18                       com.stopnplayapps.angryshark  2013-07-17
# 19                         say.hello.worldsnookernews  2013-07-17
# 20                              com.wolterskluwer.lsq  2013-07-17
# 21         com.themesfordroid.hunterthemegolauncherex  2013-07-17
# 22                        com.boxyz.androidteam.tsubo  2013-07-17
# 23                           twig.nguyen.d2_runewords  2013-07-17
# 24                                         com.Netter  2013-07-17
# 25                               com.gunvald.bigpenis  2013-07-17
# 26                                   com.prapps.tokay  2013-07-17
# 27               com.quickmare.typingkeyboard.neurope  2013-07-17
# 28                    Technicaljar.BluetoothAppBinder  2013-07-17
# 29             com.jiubang.goscreenlock.theme.lighter  2013-07-17
# ..                                                ...         ...
# 70                          com.futurek.android.ShoDo  2013-07-17
# 71                                 com.nuyork.adwblue  2013-07-17
# 72                            jp.stack.android.ko104a  2013-07-17
# 73                          com.bestapproach.greyrock  2013-07-17
# 74                                   com.ft451.madrid  2013-07-17
# 75                              com.appmakr.app492132  2013-07-17
# 76                   com.leslivresoublies.conjugaison  2013-07-17
# 77                              com.appmakr.app155827  2013-07-17
# 78  com.gau.go.launcherex.theme.theme.end.of.the.w...  2013-07-17
# 79                                com.wallpaper.Brand  2013-07-17
# 80                 com.hd.wallpapers.polar.white.bear  2013-07-17
# 81                         com.assister.JigSaw.Luntik  2013-07-17
# 82                com.foundero.countryfacts.Australia  2013-07-17
# 83                       com.isc.arbor.toefl.adv.rev1  2013-07-17
# 84                     com.springcitysoftware.fenelon  2013-07-17
# 85                              com.jw.android.nfcpro  2013-07-17
# 86                                   tv.iam.magicalch  2013-07-17
# 87                           com.fo0lb0xpro.techbench  2013-07-17
# 88                                          com.voval  2013-07-17
# 89                            air.YourDailyMotivation  2013-07-17
# 90                       com.dreamoholic.connect.four  2013-07-17
# 91                                  com.vecal.vco.rda  2013-07-17
# 92                        com.teriidi.kristinkreuklwp  2013-07-17
# 93                              com.hoaxoantim.nhn365  2013-07-17
# 94         csl.virtual.inspection.scissor.free.market  2013-07-17
# 95    air.com.GoldCupGames.KitchenCatPickmeupTiramisu  2013-07-17
# 96                                 com.and.SevenSeven  2013-07-17
# 97                        com.pocket.lambforthedragon  2013-07-17
# 98                 com.enyetech.radio.coca_cola.fm_hn  2013-07-17
# 99                                  com.stiga.mirmult  2013-07-17
#
#                category
# 0          PRODUCTIVITY
# 1                CASUAL
# 2                SPORTS
# 3           PHOTOGRAPHY
# 4                 BRAIN
# 5       PERSONALIZATION
# 6       PERSONALIZATION
# 7       PERSONALIZATION
# 8   BOOKS_AND_REFERENCE
# 9                 BRAIN
# 10               SOCIAL
# 11   NEWS_AND_MAGAZINES
# 12      MUSIC_AND_AUDIO
# 13               SOCIAL
# 14             SHOPPING
# 15               RACING
# 16            EDUCATION
# 17        ENTERTAINMENT
# 18               ARCADE
# 19               SPORTS
# 20               SOCIAL
# 21      PERSONALIZATION
# 22   HEALTH_AND_FITNESS
# 23               ARCADE
# 24              MEDICAL
# 25        ENTERTAINMENT
# 26        ENTERTAINMENT
# 27         PRODUCTIVITY
# 28         PRODUCTIVITY
# 29      PERSONALIZATION
# ..                  ...
# 70      MEDIA_AND_VIDEO
# 71      PERSONALIZATION
# 72      PERSONALIZATION
# 73               SPORTS
# 74     TRAVEL_AND_LOCAL
# 75      MUSIC_AND_AUDIO
# 76            EDUCATION
# 77            EDUCATION
# 78      PERSONALIZATION
# 79      PERSONALIZATION
# 80        ENTERTAINMENT
# 81                BRAIN
# 82     TRAVEL_AND_LOCAL
# 83  BOOKS_AND_REFERENCE
# 84            LIFESTYLE
# 85               SPORTS
# 86               COMICS
# 87         PRODUCTIVITY
# 88               COMICS
# 89            LIFESTYLE
# 90                BRAIN
# 91                TOOLS
# 92      PERSONALIZATION
# 93  BOOKS_AND_REFERENCE
# 94                TOOLS
# 95            LIFESTYLE
# 96            EDUCATION
# 97               ARCADE
# 98      MUSIC_AND_AUDIO
# 99        ENTERTAINMENT
#
# [100 rows x 3 columns]

# %% [markdown]
# # Price changes -- NEWPRICE

# %%
@require(iter_json_gzip,'ujson','datetime','re','gzip','csv')
def NEWPRICE(file_in,out_base,compress=1):
    headers = ['app_id','date','price']
    out_filename = out_base.format('NEWPRICE')
    running = {}
    with gzip.open(out_filename,'wt',compress) as out_file:
        csv_writer = csv.writer(out_file)
        csv_writer.writerow(headers)
        for json in iter_json_gzip(file_in):
            price = json.get('price',None)
            if running.get(json['app_id'],None)!=price:
                running[json['app_id']] = price
                day = datetime.datetime.fromtimestamp(int(json['timestamp']))\
                        .strftime('%Y-%m-%d')
                obs = (json['app_id'],day,price)
                csv_writer.writerow(obs)
    return out_filename

# %%
df_debug = None
if DEBUG:
    df_debug = read_csv(NEWPRICE(RAW_FILE,OUT_BASE,COMPRESS_LEVEL),compression='gzip',header=0)
df_debug
# Out:
#                                                app_id        date  price
# 0                              com.touchtype.swiftkey  2013-07-17   3.99
# 1                 com.gameloft.android.ANMP.GloftDMHM  2013-07-17   0.00
# 2                         com.ibm.events.android.usga  2013-07-17   0.00
# 3                                    com.dama.camera2  2013-07-17   2.99
# 4                         com.disney.scribblefree_goo  2013-07-17   0.00
# 5                               com.gau.go.launcherex  2013-07-17   0.00
# 6                            com.teslacoilsw.launcher  2013-07-17   0.00
# 7                        com.levelup.beautifulwidgets  2013-07-17   2.59
# 8         com.socialnmobile.dictdata.chinese.stardict  2013-07-17   0.00
# 9                             com.mdb.android.xiangqi  2013-07-17   0.00
# 10                                 io.avocado.android  2013-07-17   0.00
# 11                                      flipboard.app  2013-07-17   0.00
# 12                    com.mobincube.android.app_20866  2013-07-17   0.00
# 13                                       com.at.proxi  2013-07-17   0.00
# 14                    shopcoffeetable.com.coffeetable  2013-07-17   0.00
# 15                        com.mini.flowers.angryfatty  2013-07-17   0.00
# 16                          com.and.Wuthering_Heights  2013-07-17   7.97
# 17                                   com.loltv.layout  2013-07-17   0.00
# 18                       com.stopnplayapps.angryshark  2013-07-17   0.00
# 19                         say.hello.worldsnookernews  2013-07-17   0.00
# 20                              com.wolterskluwer.lsq  2013-07-17   0.00
# 21         com.themesfordroid.hunterthemegolauncherex  2013-07-17   0.00
# 22                        com.boxyz.androidteam.tsubo  2013-07-17   4.75
# 23                           twig.nguyen.d2_runewords  2013-07-17   0.00
# 24                                         com.Netter  2013-07-17   0.00
# 25                               com.gunvald.bigpenis  2013-07-17   0.00
# 26                                   com.prapps.tokay  2013-07-17   0.00
# 27               com.quickmare.typingkeyboard.neurope  2013-07-17   0.00
# 28                    Technicaljar.BluetoothAppBinder  2013-07-17   0.00
# 29             com.jiubang.goscreenlock.theme.lighter  2013-07-17   0.00
# ..                                                ...         ...    ...
# 70                          com.futurek.android.ShoDo  2013-07-17   0.00
# 71                                 com.nuyork.adwblue  2013-07-17   0.00
# 72                            jp.stack.android.ko104a  2013-07-17   0.00
# 73                          com.bestapproach.greyrock  2013-07-17   0.00
# 74                                   com.ft451.madrid  2013-07-17   0.00
# 75                              com.appmakr.app492132  2013-07-17   0.00
# 76                   com.leslivresoublies.conjugaison  2013-07-17   0.00
# 77                              com.appmakr.app155827  2013-07-17   0.00
# 78  com.gau.go.launcherex.theme.theme.end.of.the.w...  2013-07-17   0.00
# 79                                com.wallpaper.Brand  2013-07-17   0.00
# 80                 com.hd.wallpapers.polar.white.bear  2013-07-17   0.00
# 81                         com.assister.JigSaw.Luntik  2013-07-17   0.00
# 82                com.foundero.countryfacts.Australia  2013-07-17   0.00
# 83                       com.isc.arbor.toefl.adv.rev1  2013-07-17   2.50
# 84                     com.springcitysoftware.fenelon  2013-07-17   0.00
# 85                              com.jw.android.nfcpro  2013-07-17   0.00
# 86                                   tv.iam.magicalch  2013-07-17   1.00
# 87                           com.fo0lb0xpro.techbench  2013-07-17   3.99
# 88                                          com.voval  2013-07-17   0.00
# 89                            air.YourDailyMotivation  2013-07-17   0.00
# 90                       com.dreamoholic.connect.four  2013-07-17   0.00
# 91                                  com.vecal.vco.rda  2013-07-17   0.00
# 92                        com.teriidi.kristinkreuklwp  2013-07-17   0.00
# 93                              com.hoaxoantim.nhn365  2013-07-17   0.00
# 94         csl.virtual.inspection.scissor.free.market  2013-07-17   0.00
# 95    air.com.GoldCupGames.KitchenCatPickmeupTiramisu  2013-07-17   0.00
# 96                                 com.and.SevenSeven  2013-07-17   7.97
# 97                        com.pocket.lambforthedragon  2013-07-17   0.00
# 98                 com.enyetech.radio.coca_cola.fm_hn  2013-07-17   0.00
# 99                                  com.stiga.mirmult  2013-07-17   0.00
#
# [100 rows x 3 columns]

# %% [markdown]
# # Version changes  -- NEWVERSION

# %%
@require(iter_json_gzip,'ujson','datetime','re','gzip','csv')
def NEWVERSION(file_in,out_base,compress=1):
    headers = ['app_id','date','version']
    out_filename = out_base.format('NEWVERSION')
    with gzip.open(out_filename,'wt',compress,) as out_file:
        csv_writer = csv.writer(out_file)
        csv_writer.writerow(headers)
        running = {}
        nowhite = re.compile(r"\s+")
        for json in iter_json_gzip(file_in):
            version = json.get('version','')
            version = version.replace('Varies with device','varies')
            version = nowhite.sub('',version).lower()
            if running.get(json['app_id'],'')!=version:
                running[json['app_id']] = version
                day = datetime.datetime.fromtimestamp(int(json['timestamp']))\
                        .strftime('%Y-%m-%d')
                obs = (json['app_id'],day,version)
                csv_writer.writerow(obs)
    return out_filename

# %%
df_debug = None
if DEBUG:
    df_debug = read_csv(NEWVERSION(RAW_FILE,OUT_BASE,COMPRESS_LEVEL),compression='gzip',header=0)
df_debug
# Out:
#                                                app_id        date    version
# 0                              com.touchtype.swiftkey  2013-07-17     varies
# 1                 com.gameloft.android.ANMP.GloftDMHM  2013-07-17      1.0.0
# 2                         com.ibm.events.android.usga  2013-07-17        2.2
# 3                                    com.dama.camera2  2013-07-17      1.0.6
# 4                         com.disney.scribblefree_goo  2013-07-17      1.0.2
# 5                               com.gau.go.launcherex  2013-07-17     varies
# 6                            com.teslacoilsw.launcher  2013-07-17      2.1.1
# 7                        com.levelup.beautifulwidgets  2013-07-17      5.3.1
# 8         com.socialnmobile.dictdata.chinese.stardict  2013-07-17      1.0.4
# 9                             com.mdb.android.xiangqi  2013-07-17     2.6.12
# 10                                 io.avocado.android  2013-07-17        1.8
# 11                                      flipboard.app  2013-07-17     varies
# 12                    com.mobincube.android.app_20866  2013-07-17          6
# 13                                       com.at.proxi  2013-07-17       beta
# 14                    shopcoffeetable.com.coffeetable  2013-07-17       1.01
# 15                        com.mini.flowers.angryfatty  2013-07-17        2.6
# 16                          com.and.Wuthering_Heights  2013-07-17        1.0
# 17                                   com.loltv.layout  2013-07-17        1.1
# 18                       com.stopnplayapps.angryshark  2013-07-17        2.0
# 19                         say.hello.worldsnookernews  2013-07-17       24.0
# 20                              com.wolterskluwer.lsq  2013-07-17        1.0
# 21         com.themesfordroid.hunterthemegolauncherex  2013-07-17        1.0
# 22                        com.boxyz.androidteam.tsubo  2013-07-17      1.2.8
# 23                           twig.nguyen.d2_runewords  2013-07-17        1.5
# 24                                         com.Netter  2013-07-17      1.0.1
# 25                               com.gunvald.bigpenis  2013-07-17        2.2
# 26                                   com.prapps.tokay  2013-07-17        1.6
# 27               com.quickmare.typingkeyboard.neurope  2013-07-17        1.0
# 28                    Technicaljar.BluetoothAppBinder  2013-07-17        1.0
# 29             com.jiubang.goscreenlock.theme.lighter  2013-07-17        1.0
# ..                                                ...         ...        ...
# 70                          com.futurek.android.ShoDo  2013-07-17      0.4.1
# 71                                 com.nuyork.adwblue  2013-07-17        1.8
# 72                            jp.stack.android.ko104a  2013-07-17      1.0.0
# 73                          com.bestapproach.greyrock  2013-07-17        1.0
# 74                                   com.ft451.madrid  2013-07-17        4.7
# 75                              com.appmakr.app492132  2013-07-17     192534
# 76                   com.leslivresoublies.conjugaison  2013-07-17        1.2
# 77                              com.appmakr.app155827  2013-07-17          9
# 78  com.gau.go.launcherex.theme.theme.end.of.the.w...  2013-07-17        1.1
# 79                                com.wallpaper.Brand  2013-07-17        1.2
# 80                 com.hd.wallpapers.polar.white.bear  2013-07-17        1.7
# 81                         com.assister.JigSaw.Luntik  2013-07-17          1
# 82                com.foundero.countryfacts.Australia  2013-07-17        1.1
# 83                       com.isc.arbor.toefl.adv.rev1  2013-07-17      0.8.5
# 84                     com.springcitysoftware.fenelon  2013-07-17          1
# 85                              com.jw.android.nfcpro  2013-07-17       1.32
# 86                                   tv.iam.magicalch  2013-07-17      1.0.1
# 87                           com.fo0lb0xpro.techbench  2013-07-17    version
# 88                                          com.voval  2013-07-17        1.0
# 89                            air.YourDailyMotivation  2013-07-17      1.0.0
# 90                       com.dreamoholic.connect.four  2013-07-17      1.0.3
# 91                                  com.vecal.vco.rda  2013-07-17     2.0.16
# 92                        com.teriidi.kristinkreuklwp  2013-07-17       1.00
# 93                              com.hoaxoantim.nhn365  2013-07-17        1.0
# 94         csl.virtual.inspection.scissor.free.market  2013-07-17        1.0
# 95    air.com.GoldCupGames.KitchenCatPickmeupTiramisu  2013-07-17      1.558
# 96                                 com.and.SevenSeven  2013-07-17        1.0
# 97                        com.pocket.lambforthedragon  2013-07-17        1.6
# 98                 com.enyetech.radio.coca_cola.fm_hn  2013-07-17  1.3.41353
# 99                                  com.stiga.mirmult  2013-07-17     varies
#
# [100 rows x 3 columns]

# %% [markdown]
# # Updated Changes -- NEWUPDATED

# %%
@require(iter_json_gzip,'ujson','datetime','re','gzip','csv')
def NEWUPDATED(file_in,out_base,compress=1):
    headers = ['app_id','updated',]
    out_filename = out_base.format('NEWUPDATED')
    with gzip.open(out_filename,'wt',compress) as out_file:
        csv_writer = csv.writer(out_file)
        csv_writer.writerow(headers)
        running = {}
        nowhite = re.compile(r"\s+")
        for json in iter_json_gzip(file_in):
            updated = json.get('updated','')
            if updated == None:
                continue
            updated = updated.strip()
            if running.get(json['app_id'],'')!=updated and ''!= updated and None !=updated:
                running[json['app_id']] = updated
                date = datetime.datetime.strptime(updated,'%B %d, %Y')
                date = date.strftime('%Y-%m-%d')
                obs = (json['app_id'],date)
                csv_writer.writerow(obs)
    return out_filename

# %%
df_debug = None
if DEBUG:
    df_debug = read_csv(NEWUPDATED(RAW_FILE,OUT_BASE,COMPRESS_LEVEL),compression='gzip',header=0)
df_debug
# Out:
#                                                app_id     updated
# 0                              com.touchtype.swiftkey  2013-07-01
# 1                 com.gameloft.android.ANMP.GloftDMHM  2013-07-16
# 2                         com.ibm.events.android.usga  2013-06-14
# 3                                    com.dama.camera2  2013-07-03
# 4                         com.disney.scribblefree_goo  2013-07-03
# 5                               com.gau.go.launcherex  2013-07-17
# 6                            com.teslacoilsw.launcher  2013-06-11
# 7                        com.levelup.beautifulwidgets  2013-07-16
# 8         com.socialnmobile.dictdata.chinese.stardict  2009-10-14
# 9                             com.mdb.android.xiangqi  2013-05-16
# 10                                 io.avocado.android  2013-07-12
# 11                                      flipboard.app  2013-07-17
# 12                    com.mobincube.android.app_20866  2012-08-28
# 13                                       com.at.proxi  2012-02-26
# 14                    shopcoffeetable.com.coffeetable  2011-03-06
# 15                        com.mini.flowers.angryfatty  2013-07-09
# 16                          com.and.Wuthering_Heights  2012-03-08
# 17                                   com.loltv.layout  2013-04-25
# 18                       com.stopnplayapps.angryshark  2013-03-20
# 19                         say.hello.worldsnookernews  2013-06-16
# 20                              com.wolterskluwer.lsq  2012-06-13
# 21         com.themesfordroid.hunterthemegolauncherex  2013-02-14
# 22                        com.boxyz.androidteam.tsubo  2013-05-17
# 23                           twig.nguyen.d2_runewords  2013-06-23
# 24                                         com.Netter  2012-01-12
# 25                               com.gunvald.bigpenis  2013-01-16
# 26                                   com.prapps.tokay  2012-04-19
# 27               com.quickmare.typingkeyboard.neurope  2011-12-16
# 28                    Technicaljar.BluetoothAppBinder  2011-01-03
# 29             com.jiubang.goscreenlock.theme.lighter  2012-02-21
# ..                                                ...         ...
# 70                          com.futurek.android.ShoDo  2010-04-14
# 71                                 com.nuyork.adwblue  2010-12-12
# 72                            jp.stack.android.ko104a  2011-12-06
# 73                          com.bestapproach.greyrock  2012-09-22
# 74                                   com.ft451.madrid  2013-06-17
# 75                              com.appmakr.app492132  2012-07-07
# 76                   com.leslivresoublies.conjugaison  2013-07-03
# 77                              com.appmakr.app155827  2011-05-24
# 78  com.gau.go.launcherex.theme.theme.end.of.the.w...  2013-06-30
# 79                                com.wallpaper.Brand  2013-05-29
# 80                 com.hd.wallpapers.polar.white.bear  2013-05-28
# 81                         com.assister.JigSaw.Luntik  2013-06-27
# 82                com.foundero.countryfacts.Australia  2012-03-07
# 83                       com.isc.arbor.toefl.adv.rev1  2009-06-08
# 84                     com.springcitysoftware.fenelon  2011-02-18
# 85                              com.jw.android.nfcpro  2012-06-28
# 86                                   tv.iam.magicalch  2013-06-10
# 87                           com.fo0lb0xpro.techbench  2013-05-06
# 88                                          com.voval  2012-04-21
# 89                            air.YourDailyMotivation  2013-03-18
# 90                       com.dreamoholic.connect.four  2012-12-17
# 91                                  com.vecal.vco.rda  2012-05-11
# 92                        com.teriidi.kristinkreuklwp  2013-04-25
# 93                              com.hoaxoantim.nhn365  2013-06-07
# 94         csl.virtual.inspection.scissor.free.market  2011-07-08
# 95    air.com.GoldCupGames.KitchenCatPickmeupTiramisu  2012-09-19
# 96                                 com.and.SevenSeven  2012-02-08
# 97                        com.pocket.lambforthedragon  2013-07-10
# 98                 com.enyetech.radio.coca_cola.fm_hn  2013-03-22
# 99                                  com.stiga.mirmult  2013-06-04
#
# [100 rows x 2 columns]

# %% [markdown]
# # Requires Version Changes -- NEWREQ

# %%
@require(iter_json_gzip,'ujson','datetime','re','gzip','csv')
def NEWREQ(file_in,out_base,compress=1):
    headers = ['app_id','date','requires']
    out_filename = out_base.format('NEWREQ')
    with gzip.open(out_filename,'wt',compress) as out_file:
        csv_writer = csv.writer(out_file)
        csv_writer.writerow(headers)
        running = {}
        nowhite = re.compile(r"\s+")
        and_up = re.compile(r" and up")
        for json in iter_json_gzip(file_in):
            requires = json.get('requires','')
            if requires == None:
                continue
            requires = requires.lower().strip()
            requires = requires.replace('varies with device','varies')
            requires = and_up.sub('+',requires)
            requires = nowhite.sub('',requires)
            if running.get(json['app_id'],'')!=requires and None !=requires:
                running[json['app_id']] = requires
                day = datetime.datetime.fromtimestamp(int(json['timestamp']))\
                        .strftime('%Y-%m-%d')
                obs = (json['app_id'],day,requires)
                csv_writer.writerow(obs)
    return out_filename

# %%
df_debug = None
if DEBUG:
    df_debug = read_csv(NEWREQ(RAW_FILE,OUT_BASE,COMPRESS_LEVEL),compression='gzip',header=0)
df_debug
# Out:
#                                                app_id        date requires
# 0                              com.touchtype.swiftkey  2013-07-17   varies
# 1                 com.gameloft.android.ANMP.GloftDMHM  2013-07-17     2.3+
# 2                         com.ibm.events.android.usga  2013-07-17     2.2+
# 3                                    com.dama.camera2  2013-07-17   4.0.3+
# 4                         com.disney.scribblefree_goo  2013-07-17     2.2+
# 5                               com.gau.go.launcherex  2013-07-17   varies
# 6                            com.teslacoilsw.launcher  2013-07-17     4.0+
# 7                        com.levelup.beautifulwidgets  2013-07-17     2.2+
# 8         com.socialnmobile.dictdata.chinese.stardict  2013-07-17     1.5+
# 9                             com.mdb.android.xiangqi  2013-07-17     1.5+
# 10                                 io.avocado.android  2013-07-17     2.2+
# 11                                      flipboard.app  2013-07-17   varies
# 12                    com.mobincube.android.app_20866  2013-07-17     2.1+
# 13                                       com.at.proxi  2013-07-17     2.2+
# 14                    shopcoffeetable.com.coffeetable  2013-07-17     2.0+
# 15                        com.mini.flowers.angryfatty  2013-07-17     1.6+
# 16                          com.and.Wuthering_Heights  2013-07-17     2.1+
# 17                                   com.loltv.layout  2013-07-17     4.0+
# 18                       com.stopnplayapps.angryshark  2013-07-17     2.3+
# 19                         say.hello.worldsnookernews  2013-07-17     1.5+
# 20                              com.wolterskluwer.lsq  2013-07-17     2.1+
# 21         com.themesfordroid.hunterthemegolauncherex  2013-07-17     2.1+
# 22                        com.boxyz.androidteam.tsubo  2013-07-17     1.6+
# 23                           twig.nguyen.d2_runewords  2013-07-17     1.6+
# 24                                         com.Netter  2013-07-17     2.2+
# 25                               com.gunvald.bigpenis  2013-07-17     1.6+
# 26                                   com.prapps.tokay  2013-07-17     1.6+
# 27               com.quickmare.typingkeyboard.neurope  2013-07-17     2.2+
# 28                    Technicaljar.BluetoothAppBinder  2013-07-17     2.1+
# 29             com.jiubang.goscreenlock.theme.lighter  2013-07-17     1.6+
# ..                                                ...         ...      ...
# 70                          com.futurek.android.ShoDo  2013-07-17     1.6+
# 71                                 com.nuyork.adwblue  2013-07-17     2.1+
# 72                            jp.stack.android.ko104a  2013-07-17     2.1+
# 73                          com.bestapproach.greyrock  2013-07-17     2.1+
# 74                                   com.ft451.madrid  2013-07-17     2.1+
# 75                              com.appmakr.app492132  2013-07-17     2.1+
# 76                   com.leslivresoublies.conjugaison  2013-07-17     2.3+
# 77                              com.appmakr.app155827  2013-07-17     2.1+
# 78  com.gau.go.launcherex.theme.theme.end.of.the.w...  2013-07-17     2.0+
# 79                                com.wallpaper.Brand  2013-07-17     2.2+
# 80                 com.hd.wallpapers.polar.white.bear  2013-07-17     1.6+
# 81                         com.assister.JigSaw.Luntik  2013-07-17     2.2+
# 82                com.foundero.countryfacts.Australia  2013-07-17     2.2+
# 83                       com.isc.arbor.toefl.adv.rev1  2013-07-17     1.1+
# 84                     com.springcitysoftware.fenelon  2013-07-17     1.6+
# 85                              com.jw.android.nfcpro  2013-07-17     1.5+
# 86                                   tv.iam.magicalch  2013-07-17     2.0+
# 87                           com.fo0lb0xpro.techbench  2013-07-17     1.6+
# 88                                          com.voval  2013-07-17     2.1+
# 89                            air.YourDailyMotivation  2013-07-17     2.2+
# 90                       com.dreamoholic.connect.four  2013-07-17     2.1+
# 91                                  com.vecal.vco.rda  2013-07-17     1.5+
# 92                        com.teriidi.kristinkreuklwp  2013-07-17     2.1+
# 93                              com.hoaxoantim.nhn365  2013-07-17     2.2+
# 94         csl.virtual.inspection.scissor.free.market  2013-07-17     2.1+
# 95    air.com.GoldCupGames.KitchenCatPickmeupTiramisu  2013-07-17     2.2+
# 96                                 com.and.SevenSeven  2013-07-17     2.1+
# 97                        com.pocket.lambforthedragon  2013-07-17     1.5+
# 98                 com.enyetech.radio.coca_cola.fm_hn  2013-07-17     2.1+
# 99                                  com.stiga.mirmult  2013-07-17   varies
#
# [100 rows x 3 columns]

# %% [markdown]
# # Installs Changes -- NEWINSTALL

# %%
@require(iter_json_gzip,'ujson','datetime','re','gzip','csv')
def NEWINSTALL(file_in,out_base,compress=1):
    headers = ['app_id','date','installs']
    out_filename = out_base.format('NEWINSTALL')
    
    with gzip.open(out_filename,'wt',compress) as out_file:
        csv_writer = csv.writer(out_file)
        csv_writer.writerow(headers)
        nowhite = re.compile(r"\s+")
        running = {}
        for json in iter_json_gzip(file_in):
            installs = nowhite.sub('',json.get('installs',''))
            if running.get(json['app_id'],'')!=installs and None != installs:
                running[json['app_id']] = installs
                day = datetime.datetime.fromtimestamp(int(json['timestamp']))\
                        .strftime('%Y-%m-%d')
                obs = (json['app_id'],day,installs)
                csv_writer.writerow(obs)
    return out_filename

# %%
df_debug = None
if DEBUG:
    df_debug = read_csv(NEWINSTALL(RAW_FILE,OUT_BASE,COMPRESS_LEVEL),compression='gzip',header=0)
df_debug
# Out:
#                                                app_id        date  \
# 0                              com.touchtype.swiftkey  2013-07-17
# 1                 com.gameloft.android.ANMP.GloftDMHM  2013-07-17
# 2                         com.ibm.events.android.usga  2013-07-17
# 3                                    com.dama.camera2  2013-07-17
# 4                         com.disney.scribblefree_goo  2013-07-17
# 5                               com.gau.go.launcherex  2013-07-17
# 6                            com.teslacoilsw.launcher  2013-07-17
# 7                        com.levelup.beautifulwidgets  2013-07-17
# 8         com.socialnmobile.dictdata.chinese.stardict  2013-07-17
# 9                             com.mdb.android.xiangqi  2013-07-17
# 10                                 io.avocado.android  2013-07-17
# 11                                      flipboard.app  2013-07-17
# 12                    com.mobincube.android.app_20866  2013-07-17
# 13                                       com.at.proxi  2013-07-17
# 14                    shopcoffeetable.com.coffeetable  2013-07-17
# 15                        com.mini.flowers.angryfatty  2013-07-17
# 16                          com.and.Wuthering_Heights  2013-07-17
# 17                                   com.loltv.layout  2013-07-17
# 18                       com.stopnplayapps.angryshark  2013-07-17
# 19                         say.hello.worldsnookernews  2013-07-17
# 20                              com.wolterskluwer.lsq  2013-07-17
# 21         com.themesfordroid.hunterthemegolauncherex  2013-07-17
# 22                        com.boxyz.androidteam.tsubo  2013-07-17
# 23                           twig.nguyen.d2_runewords  2013-07-17
# 24                                         com.Netter  2013-07-17
# 25                               com.gunvald.bigpenis  2013-07-17
# 26                                   com.prapps.tokay  2013-07-17
# 27               com.quickmare.typingkeyboard.neurope  2013-07-17
# 28                    Technicaljar.BluetoothAppBinder  2013-07-17
# 29             com.jiubang.goscreenlock.theme.lighter  2013-07-17
# ..                                                ...         ...
# 68                                com.sexygirlhotwash  2013-07-17
# 69                               com.agame.ZombieRoad  2013-07-17
# 70                          com.futurek.android.ShoDo  2013-07-17
# 71                                 com.nuyork.adwblue  2013-07-17
# 72                            jp.stack.android.ko104a  2013-07-17
# 73                          com.bestapproach.greyrock  2013-07-17
# 74                                   com.ft451.madrid  2013-07-17
# 75                              com.appmakr.app492132  2013-07-17
# 76                   com.leslivresoublies.conjugaison  2013-07-17
# 77                              com.appmakr.app155827  2013-07-17
# 78  com.gau.go.launcherex.theme.theme.end.of.the.w...  2013-07-17
# 79                                com.wallpaper.Brand  2013-07-17
# 80                 com.hd.wallpapers.polar.white.bear  2013-07-17
# 81                         com.assister.JigSaw.Luntik  2013-07-17
# 82                com.foundero.countryfacts.Australia  2013-07-17
# 83                       com.isc.arbor.toefl.adv.rev1  2013-07-17
# 84                     com.springcitysoftware.fenelon  2013-07-17
# 85                              com.jw.android.nfcpro  2013-07-17
# 86                           com.fo0lb0xpro.techbench  2013-07-17
# 87                                          com.voval  2013-07-17
# 88                            air.YourDailyMotivation  2013-07-17
# 89                       com.dreamoholic.connect.four  2013-07-17
# 90                                  com.vecal.vco.rda  2013-07-17
# 91                        com.teriidi.kristinkreuklwp  2013-07-17
# 92                              com.hoaxoantim.nhn365  2013-07-17
# 93         csl.virtual.inspection.scissor.free.market  2013-07-17
# 94    air.com.GoldCupGames.KitchenCatPickmeupTiramisu  2013-07-17
# 95                        com.pocket.lambforthedragon  2013-07-17
# 96                 com.enyetech.radio.coca_cola.fm_hn  2013-07-17
# 97                                  com.stiga.mirmult  2013-07-17
#
#                   installs
# 0      1,000,000-5,000,000
# 1    10,000,000-50,000,000
# 2          100,000-500,000
# 3            10,000-50,000
# 4        500,000-1,000,000
# 5   50,000,000-100,000,000
# 6     5,000,000-10,000,000
# 7      1,000,000-5,000,000
# 8          100,000-500,000
# 9            10,000-50,000
# 10       500,000-1,000,000
# 11  50,000,000-100,000,000
# 12                  50-100
# 13                 100-500
# 14             1,000-5,000
# 15         100,000-500,000
# 16                     1-5
# 17             1,000-5,000
# 18             1,000-5,000
# 19          50,000-100,000
# 20               500-1,000
# 21           10,000-50,000
# 22             1,000-5,000
# 23           10,000-50,000
# 24          50,000-100,000
# 25           10,000-50,000
# 26             1,000-5,000
# 27                 100-500
# 28             1,000-5,000
# 29     1,000,000-5,000,000
# ..                     ...
# 68           10,000-50,000
# 69           10,000-50,000
# 70         100,000-500,000
# 71         100,000-500,000
# 72               500-1,000
# 73                  50-100
# 74             1,000-5,000
# 75                 100-500
# 76             1,000-5,000
# 77                 100-500
# 78            5,000-10,000
# 79                 100-500
# 80                 100-500
# 81            5,000-10,000
# 82             1,000-5,000
# 83                  50-100
# 84               500-1,000
# 85             1,000-5,000
# 86                   10-50
# 87             1,000-5,000
# 88               500-1,000
# 89            5,000-10,000
# 90               500-1,000
# 91               500-1,000
# 92             1,000-5,000
# 93               500-1,000
# 94                  50-100
# 95           10,000-50,000
# 96               500-1,000
# 97          50,000-100,000
#
# [98 rows x 3 columns]

# %% [markdown]
# # Run them all!

# %%
programs = """
NEWDEVELOPER
NEWCATEGORY
NEWPRICE
NEWVERSION
NEWUPDATED
NEWREQ
NEWINSTALL
DAILYRATINGS
""".split()

def run_function(f,RAW_FILE=RAW_FILE,OUT_BASE=OUT_BASE,COMPRESS_LEVEL=COMPRESS_LEVEL):
    return f(RAW_FILE ,OUT_BASE,COMPRESS_LEVEL)

for file in map(run_function,[globals()[x] for x in programs]):
    print(file)
print("DONE")
# Out:
# /home/cgaray/data/out/NEWDEVELOPER__google_play__main__2015_02_26_23_12.csv.gz
# /home/cgaray/data/out/NEWCATEGORY__google_play__main__2015_02_26_23_12.csv.gz
# /home/cgaray/data/out/NEWPRICE__google_play__main__2015_02_26_23_12.csv.gz
# /home/cgaray/data/out/NEWVERSION__google_play__main__2015_02_26_23_12.csv.gz
# /home/cgaray/data/out/NEWUPDATED__google_play__main__2015_02_26_23_12.csv.gz
# /home/cgaray/data/out/NEWREQ__google_play__main__2015_02_26_23_12.csv.gz
# /home/cgaray/data/out/NEWINSTALL__google_play__main__2015_02_26_23_12.csv.gz
# /home/cgaray/data/out/DAILYRATINGS__google_play__main__2015_02_26_23_12.csv.gz
# DONE
