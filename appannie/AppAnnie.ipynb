# %%
# Don't change the style of these imports.
# They must be imported this way for parallelization
# to work correctly.
import lxml.html
import ujson
import gzip
import csv
import datetime

# %%
from pdb import set_trace as debug
from IPython.parallel import Client,require
from collections import Counter
from pandas.io.parsers import read_csv

# %%
#--> RAW_FILE_DIR with the directory that contains google_play__main.json.gz
#--> OUT_DIR with the directory of where you want the processed files to go
#--> DEBUG whether to print out created CSV files or not
#--> COMPRESS_LEVEL gzip compression level. warning: severely impacts runtime.
#--> LINE_LIMIT how many lines to iterate through in the raw file. For debugging.
DUMP_DATE = '2015_03_21_23_12'
RAW_FILE_DIR = '/Users/kushagrasharma/Coding/data'
OUT_DIR = '/Users/kushagrasharma/Coding/data/out'
DEBUG = 1
COMPRESS_LEVEL = 1
LINE_LIMIT = -1 # -1 means run for the entire file
PARALLEL = 0

# %%
# Don't change these!
RAW_FILE_IPHONE = '{}/test_appannie__iphone.json.gz'.format(RAW_FILE_DIR)
RAW_FILE_IPAD = '{}/test_appannie__ipad.json.gz'.format(RAW_FILE_DIR)
RAW_FILE_GOOGLE = '{}/test_appannie__google.json.gz'.format(RAW_FILE_DIR)
RAW_FILE_HISTORICALRANKINGS = '{}/appannie__historical_rankings.json.gz'.format(RAW_FILE_DIR)
RAW_FILE_HISTORICALEVENTS = '{}/appannie__historical_events.json.gz'.format(RAW_FILE_DIR)

OUT_BASE = OUT_DIR+'/{}__'+DUMP_DATE+'.csv.gz'

# %%
# ! zcat "$RAW_FILE_IPHONE" | head -n1
# ! zcat "$RAW_FILE_IPAD" | head -n1
# ! zcat "$RAW_FILE_GOOGLE" | head -n1

# %%
def iter_json_gzip(filename,LINE_LIMIT=LINE_LIMIT,no_verify_appid_time=1):
    with gzip.open(filename,'rt') as file_iter:
        c = 0
        for line in file_iter:
            c +=1
            if c > LINE_LIMIT and LINE_LIMIT>0:
                break
            if isinstance(line,str):
                if len(line)>0:        
                    out = ujson.loads(line)
                    if isinstance(out,dict):
                        if 'app_id' in out and 'timestamp' in out \
                        or no_verify_appid_time:
                            yield out

# %%
if PARALLEL:
    ipython_parallel = Client()
    print("{} active computing engines".format(len(ipython_parallel.ids)))

    lbv = ipython_parallel.load_balanced_view()

    map = lambda f,itertable:lbv.map(f,itertable,\
    block =False,\
    ordered =False)

    @require('socket')
    def host(dummy):
        return socket.gethostname()
    
    nodes = list(lbv.map(host,ipython_parallel.ids))
    nodes = [int(x.split('equity')[1].split(".")[0]) for x in nodes]
    nodes = nodes

    print(sorted(list(Counter(nodes).items())))

# %% [markdown]
# # RANKINGS_IPHONE

# %%
@require(iter_json_gzip,'ujson','gzip','csv','lxml.html')
def RANKINGS_IPHONE(file_in,out_base,compress=1):
    headers = ['app_id', 'chart', 'date', 'country', 'rank']
    out_filename = out_base.format('RANKINGS_IPHONE')
    with gzip.open(out_filename,'wt',compress) as out_file:
        csv_writer = csv.writer(out_file)
        csv_writer.writerow(headers)
        for json in iter_json_gzip(file_in):
            tree = lxml.html.fromstring(json['html'])
            app_ids = tree.xpath("//span[@style='display:none']")
            chart = ['free', 'paid', 'grossing']
            for i,app in enumerate(app_ids):
                app_info = [app.text_content(), chart[i%3], json['date'], 'United States', int(((i/3)+1))]
                csv_writer.writerow(app_info)
    return out_filename

# %%
df_debug = None
if DEBUG:
    df_debug = read_csv

    with gzip.open(out_filename,'wt',compress) as out_file:
        csv_writer = csv.writer(out_file)
        csv_writer.writerow(headers)
        for json in iter_json_gzip(file_in):
            tree = lxml.html.fromstring(json['html'])
            app_ids = tree.xpath("//span[@style='display:none']")
            chart = ['free', 'paid', 'grossing', 'new_free', 'new_paid']
            for i,app in enumerate(app_ids):
                app_info = [app.text_content(), chart[i%5], json['date'], 'United States', int(((i/5)+1))]
                csv_writer.writerow(app_info)
    return out_filename

# %%
df_debug = None
if DEBUG:
    df_debug = read_csv(RANKINGS_GOOGLE(RAW_FILE_GOOGLE,OUT_BASE,COMPRESS_LEVEL),compression='gzip',header=0)
df_debug
# Out:
#                                                    app_id     chart  \
# 0                                     com.facebook.katana      free
# 1                                  com.mojang.minecraftpe      paid
# 2                              com.supercell.clashofclans  grossing
# 3                            it.junglestudios.splashyfish  new_free
# 4                           com.FireproofStudios.TheRoom2  new_paid
# 5                                     com.pandora.android      free
# 6                                  com.touchtype.swiftkey      paid
# 7                                 com.king.candycrushsaga  grossing
# 8       com.square_enix.android_googleplay.deadmanscro...  new_free
# 9                                 com.mtvn.sbmigoogleplay  new_paid
# 10                                      com.facebook.orca      free
# 11                        com.keramidas.TitaniumBackupPro      paid
# 12                                com.king.farmheroessaga  grossing
# 13                                  com.lego.city.my_city  new_free
# 14                                   com.tocaboca.tocalab  new_paid
# 15                                  com.instagram.android      free
# 16                         com.teslacoilsw.launcher.prime      paid
# 17                                   com.supercell.hayday  grossing
# 18                                   com.magicyang.doodle  new_free
# 19                                      com.dotemu.rtype2  new_paid
# 20                                com.king.candycrushsaga      free
# 21                          com.maxmpz.audioplayer.unlock      paid
# 22                                 com.king.petrescuesaga  grossing
# 23                     com.turborilla.MadSkillsMotocross2  new_free
# 24                            com.marvel.runjumpsmash_goo  new_paid
# 25                                com.netflix.mediaclient      free
# 26                                          com.foxfi.key      paid
# 27                                    com.igg.castleclash  grossing
# 28                                com.xtpl.kingsAndCannon  new_free
# 29                                         net.broapp.app  new_paid
# ...                                                   ...       ...
# 908695                  com.prgames.texasholdem.livepoker      free
# 908696                          com.johnemulators.johngbc      paid
# 908697                com.gameloft.android.ANMP.GloftGGHM  grossing
# 908698                         com.vg.PoliceBoatSimulator  new_free
# 908699                                 air.com.dmg.medmed  new_paid
# 908700                              com.stylem.wallpapers      free
# 908701                                 com.realarcade.CL4      paid
# 908702                          com.zentertain.slotsvegas  grossing
# 908703                                com.anall.wp8.theme  new_free
# 908704      air.com.differencegames.aljelementalguardians  new_paid
# 908705                                  com.pixlr.express      free
# 908706                          com.mylegalheat.legalheat      paid
# 908707                   kr.co.feverstudio.apps.everytown  grossing
# 908708                      com.slushpupie.deskclock.m200  new_free
# 908709  next.launcher.tapanilab.theme.glaslightbluedeluxe  new_paid
# 908710                                     com.repostwhiz      free
# 908711                   uk.co.neilandtheresa.NewVignette      paid
# 908712                               com.gamevil.elements  grossing
# 908713                     com.threeaplay.slotskingarther  new_free
# 908714                           com.smurfinc.LauncPadPro  new_paid
# 908715                           ppl.unity.JuiceCubesBeta      free
# 908716                                   com.hp.pregnancy      paid
# 908717                        com.sixwaves.wonderlandepic  grossing
# 908718            com.TrudyHerkenratt.PhotoEditorCutPaste  new_free
# 908719                                 com.bigfish.flatty  new_paid
# 908720                                   com.calfordcn.gu      free
# 908721               com.wildtangent.polarbowleradventure      paid
# 908722                         com.zynga.bubblesafari.ent  grossing
# 908723                           tools.browser.webbrowser  new_free
# 908724  com.wallpaper.livewallpaper.AquariumLiveWallpa...  new_paid
#
#               date        country  rank
# 0       2014-03-01  United States     1
# 1       2014-03-01  United States     1
# 2       2014-03-01  United States     1
# 3       2014-03-01  United States     1
# 4       2014-03-01  United States     1
# 5       2014-03-01  United States     2
# 6       2014-03-01  United States     2
# 7       2014-03-01  United States     2
# 8       2014-03-01  United States     2
# 9       2014-03-01  United States     2
# 10      2014-03-01  United States     3
# 11      2014-03-01  United States     3
# 12      2014-03-01  United States     3
# 13      2014-03-01  United States     3
# 14      2014-03-01  United States     3
# 15      2014-03-01  United States     4
# 16      2014-03-01  United States     4
# 17      2014-03-01  United States     4
# 18      2014-03-01  United States     4
# 19      2014-03-01  United States     4
# 20      2014-03-01  United States     5
# 21      2014-03-01  United States     5
# 22      2014-03-01  United States     5
# 23      2014-03-01  United States     5
# 24      2014-03-01  United States     5
# 25      2014-03-01  United States     6
# 26      2014-03-01  United States     6
# 27      2014-03-01  United States     6
# 28      2014-03-01  United States     6
# 29      2014-03-01  United States     6
# ...            ...            ...   ...
# 908695  2014-06-09  United States   495
# 908696  2014-06-09  United States   495
# 908697  2014-06-09  United States   495
# 908698  2014-06-09  United States   495
# 908699  2014-06-09  United States   495
# 908700  2014-06-09  United States   496
# 908701  2014-06-09  United States   496
# 908702  2014-06-09  United States   496
# 908703  2014-06-09  United States   496
# 908704  2014-06-09  United States   496
# 908705  2014-06-09  United States   497
# 908706  2014-06-09  United States   497
# 908707  2014-06-09  United States   497
# 908708  2014-06-09  United States   497
# 908709  2014-06-09  United States   497
# 908710  2014-06-09  United States   498
# 908711  2014-06-09  United States   498
# 908712  2014-06-09  United States   498
# 908713  2014-06-09  United States   498
# 908714  2014-06-09  United States   498
# 908715  2014-06-09  United States   499
# 908716  2014-06-09  United States   499
# 908717  2014-06-09  United States   499
# 908718  2014-06-09  United States   499
# 908719  2014-06-09  United States   499
# 908720  2014-06-09  United States   500
# 908721  2014-06-09  United States   500
# 908722  2014-06-09  United States   500
# 908723  2014-06-09  United States   500
# 908724  2014-06-09  United States   500
#
# [908725 rows x 5 columns]

# %% [markdown]
# # RANKINGS_IPAD

# %%
@require(iter_json_gzip,'ujson','gzip','csv','lxml.html')
def RANKINGS_IPAD(file_in,out_base,compress=1):
    headers = ['app_id', 'chart', 'date', 'country', 'rank']
    out_filename = out_base.format('RANKINGS_IPAD')
    with gzip.open(out_filename,'wt',compress) as out_file:
        csv_writer = csv.writer(out_file)
        csv_writer.writerow(headers)
        for json in iter_json_gzip(file_in):
            tree = lxml.html.fromstring(json['html'])
            app_ids = tree.xpath("//span[@style='display:none']")
            chart = ['free', 'paid', 'grossing']
            for i,app in enumerate(app_ids):
                app_info = [app.text_content(), chart[i%3], json['date'], 'United States', int(((i/3)+1))]
                csv_writer.writerow(app_info)
    return out_filename

# %%
df_debug = None
if DEBUG:
    print(type(RANKINGS_IPAD(RAW_FILE_IPAD,OUT_BASE,COMPRESS_LEVEL)))
    df_debug = read_csv(RANKINGS_IPAD(RAW_FILE_IPAD,OUT_BASE,COMPRESS_LEVEL),compression='gzip',header=0)
df_debug
# Out:
# 348299  593448569  grossing  2014-10-25  United States   200
#
# [348300 rows x 5 columns]

# %% [markdown]
# # APPANNIEHISTORICALEVENTS

# %% [markdown]
# Make sure that date is of the format `2014-03-01`. See this [Google Notebook](http://nbviewer.ipython.org/github/mobileinnovationgroup/data_requests/blob/master/main/Google%20Data%20Request.ipynb) for examples of how to do this conversion correctly.

# %%
@require(iter_json_gzip,'ujson','gzip','csv','datetime')
def APPANNIEHISTORICALEVENTS(file_in,out_base,compress=1):
    headers = ['event_type', 'app_id', 'version', 'date']
    out_filename_ios = out_base.format('APPANNIEHISTORICALEVENTS_IOS')
    out_filename_google = out_base.format('APPANNIEHISTORICALEVENTS_GOOGLE')
    with gzip.open(out_filename_ios,'wt',compress) as out_file_ios:
        with gzip.open(out_filename_google,'wt',compress) as out_file_google:
            csv_writer_ios = csv.writer(out_file_ios)
            csv_writer_google = csv.writer(out_file_google)
            csv_writer_ios.writerow(headers)
            csv_writer_google.writerow(headers)
            for json in iter_json_gzip(file_in):
                if 'version' in json.keys():   #some data entries do not have the version data
                    version = json['version']
                else:
                    version = None
                data = [json['event_type'], json['app_id'], version, json['date']]
                if json['store'] == 'ios':
                    csv_writer_ios.writerow(data)
                else:
                    csv_writer_google.writerow(data)
    return [out_filename_ios, out_filename_google]

# %%
df_debug = None
if DEBUG:
    csvs = APPANNIEHISTORICALEVENTS(RAW_FILE_HISTORICALEVENTS,OUT_BASE,COMPRESS_LEVEL)
    df_debug_google = read_csv(csvs[1],compression='gzip',header=0)
    df_debug_ios = read_csv(csvs[0],compression='gzip',header=0)
df_debug_ios
# Out:
#           event_type     app_id                       version        date
# 0     version_change  281704574  4.1.1 (iphone os 3.0 tested)  2010-02-11
# 1    initial_release  362348516                           NaN  2010-03-31
# 2     version_change  281704574  4.1.2 (iphone os 3.0 tested)  2010-02-16
# 3     version_change  362348516                           1.1  2010-04-28
# 4    initial_release  520777858                           NaN  2012-05-15
# 5    initial_release  717142133                           NaN  2013-10-17
# 6     version_change  281704574                         4.2.1  2010-03-10
# 7     version_change  362348516                           1.2  2010-06-03
# 8     version_change  520777858                          1.02  2012-05-23
# 9     version_change  362348516                           1.3  2010-07-17
# 10    version_change  281704574                         4.2.2  2010-04-06
# 11    version_change  520777858                          1.03  2012-06-26
# 12    version_change  281704574                         4.3.1  2010-04-21
# 13    version_change  520777858                          1.04  2012-07-10
# 14    version_change  281704574                         4.3.2  2010-05-15
# 15    version_change  520777858                          1.05  2012-09-18
# 16    version_change  362348516                           1.4  2010-08-06
# 17    version_change  520777858                         1.051  2012-09-27
# 18    version_change  362348516                           2.0  2010-12-22
# 19    version_change  281704574                         4.3.3  2010-07-03
# 20    version_change  520777858                         1.052  2012-10-30
# 21    version_change  362348516                           2.1  2011-03-03
# 22    version_change  281704574                         4.3.4  2010-08-09
# 23    version_change  520777858                           1.1  2012-12-14
# 24    version_change  362348516                           2.2  2011-03-26
# 25    version_change  281704574                         4.3.5  2010-08-17
# 26    version_change  520777858                         1.101  2013-01-23
# 27    version_change  362348516                           2.3  2011-07-19
# 28    version_change  520777858                         1.150  2013-03-13
# 29    version_change  362348516                           2.4  2011-08-20
# ..               ...        ...                           ...         ...
# 355   version_change  281913144                         1.2.5  2010-04-09
# 356   version_change  281913144                         1.2.6  2010-05-12
# 357   version_change  281913144                         2.0.1  2010-10-20
# 358   version_change  281913144                         2.1.0  2011-04-22
# 359   version_change  281913144                         2.1.1  2011-06-15
# 360   version_change  281913144                         2.1.2  2011-08-02
# 361   version_change  281913144                         3.0.1  2011-10-22
# 362   version_change  281913144                         3.0.2  2012-04-21
# 363   version_change  281913144                         3.0.3  2012-07-30
# 364   version_change  281913144                         3.0.4  2012-09-29
# 365   version_change  748095052                           1.2  2013-12-02
# 366  initial_release  748095052                           NaN  2013-12-02
# 367   version_change  281913144                         4.0.8  2013-08-07
# 368   version_change  281913144                        4.1.77  2014-01-22
# 369   version_change  748095052                           1.3  2013-12-12
# 370   version_change  748095052                           1.4  2014-01-02
# 371   version_change  748095052                           1.5  2014-01-24
# 372     price_change  748095052                           NaN  2014-04-25
# 373     price_change  748095052                           NaN  2014-04-27
# 374  initial_release  468993411                           NaN  2011-10-05
# 375   version_change  468993411                           1.1  2011-10-17
# 376   version_change  468993411                           1.2  2012-01-09
# 377   version_change  468993411                           1.3  2012-01-19
# 378   version_change  468993411                           1.4  2012-06-22
# 379   version_change  468993411                         1.4.1  2012-10-01
# 380   version_change  468993411                         1.4.2  2012-10-24
# 381   version_change  468993411                         1.4.3  2013-03-06
# 382   version_change  468993411                           2.0  2013-07-04
# 383   version_change  468993411                           2.1  2013-11-14
# 384   version_change  468993411                           2.2  2013-12-10
#
# [385 rows x 4 columns]

# %%
df_debug_google
# Out:
#           event_type                                             app_id  \
# 0     version_change                       com.gau.go.launcher.lwp.core
# 1    initial_release                     air.com.dpflashes.clearvision3
# 2     version_change                   com.azumio.instantheartrate.full
# 3    initial_release                       com.gau.go.launcher.lwp.core
# 4     version_change                     air.com.dpflashes.clearvision3
# 5     version_change                   com.azumio.instantheartrate.full
# 6     version_change                     air.com.dpflashes.clearvision3
# 7     version_change                   com.azumio.instantheartrate.full
# 8    initial_release  com.mobage.ww.a956.MARVEL_Card_Battle_Heroes_A...
# 9     version_change  com.mobage.ww.a956.MARVEL_Card_Battle_Heroes_A...
# 10   initial_release                   com.azumio.instantheartrate.full
# 11    version_change                   com.azumio.instantheartrate.full
# 12    version_change  com.mobage.ww.a956.MARVEL_Card_Battle_Heroes_A...
# 13    version_change                   com.azumio.instantheartrate.full
# 14    version_change  com.mobage.ww.a956.MARVEL_Card_Battle_Heroes_A...
# 15    version_change  com.mobage.ww.a956.MARVEL_Card_Battle_Heroes_A...
# 16    version_change                   com.azumio.instantheartrate.full
# 17    version_change  com.mobage.ww.a956.MARVEL_Card_Battle_Heroes_A...
# 18    version_change  com.mobage.ww.a956.MARVEL_Card_Battle_Heroes_A...
# 19      price_change                   com.azumio.instantheartrate.full
# 20    version_change  com.mobage.ww.a956.MARVEL_Card_Battle_Heroes_A...
# 21      price_change                   com.azumio.instantheartrate.full
# 22    version_change  com.mobage.ww.a956.MARVEL_Card_Battle_Heroes_A...
# 23      price_change                   com.azumio.instantheartrate.full
# 24    version_change                   com.azumio.instantheartrate.full
# 25    version_change  com.mobage.ww.a956.MARVEL_Card_Battle_Heroes_A...
# 26    version_change                   com.azumio.instantheartrate.full
# 27    version_change  com.mobage.ww.a956.MARVEL_Card_Battle_Heroes_A...
# 28    version_change  com.mobage.ww.a956.MARVEL_Card_Battle_Heroes_A
# 614                 NaN  2013-08-02
#
# [615 rows x 4 columns]

# %% [markdown]
# # APPANNIEHISTORICALRANKINGS

# %%
@require(iter_json_gzip,'ujson','gzip','csv','datetime')
def APPANNIEHISTORICALRANKINGS(file_in,out_base,compress=1):
    headers = ['category', 'country', 'app_id', 'rank', 'date']
    out_filename_ios = out_base.format('APPANNIEHISTORICALRANKINGS_IOS')
    out_filename_google = out_base.format('APPANNIEHISTORICALRANKINGS_GOOGLE')
    with gzip.open(out_filename_ios,'wt',compress) as out_file_ios:
        with gzip.open(out_filename_google,'wt',compress) as out_file_google:
            csv_writer_ios = csv.writer(out_file_ios)
            csv_writer_google = csv.writer(out_file_google)
            csv_writer_ios.writerow(headers)
            csv_writer_google.writerow(headers)
            for json in iter_json_gzip(file_in):
                data = [json['category'], json['country'], json['app_id'], json['rank'], json['date']]
                if json['store'] == 'ios':
                    csv_writer_ios.writerow(data)
                else:
                    csv_writer_google.writerow(data)
    return [out_filename_ios, out_filename_google]

# %%
df_debug = None
if DEBUG:
    csvs = APPANNIEHISTORICALRANKINGS(RAW_FILE_HISTORICALRANKINGS,OUT_BASE,COMPRESS_LEVEL)
    df_debug_google = read_csv(csvs[1],compression='gzip',header=0)
    df_debug_ios = read_csv(csvs[0],compression='gzip',header=0)
df_debug_ios
# Out:
#       category        country     app_id  rank        date
# 0      overall  united states  717142133   425  2013-10-17
# 1      overall  united states  717142133   233  2013-10-18
# 2      overall  united states  717142133   118  2013-10-19
# 3      overall  united states  717142133    81  2013-10-20
# 4      overall  united states  717142133   113  2013-10-21
# 5      overall  united states  717142133   150  2013-10-22
# 6      overall  united states  717142133   177  2013-10-23
# 7      overall  united states  717142133   244  2013-10-24
# 8      overall  united states  717142133   327  2013-10-25
# 9      overall  united states  717142133   321  2013-10-26
# 10     overall  united states  717142133   350  2013-10-27
# 11     overall  united states  717142133   481  2013-10-28
# 12     overall  united states  717142133   621  2013-10-29
# 13     overall  united states  717142133   750  2013-10-30
# 14     overall  united states  717142133   825  2013-10-31
# 15     overall  united states  717142133   644  2013-11-01
# 16     overall  united states  717142133   428  2013-11-02
# 17     overall  united states  717142133   412  2013-11-03
# 18     overall  united states  717142133   551  2013-11-04
# 19     overall  united states  717142133   625  2013-11-05
# 20     overall  united states  717142133   697  2013-11-06
# 21     overall  united states  717142133   718  2013-11-07
# 22     overall  united states  717142133   604  2013-11-08
# 23     overall  united states  717142133   826  2013-11-09
# 24     overall  united states  717142133  1132  2013-11-10
# 25     overall  united states  362348516   740  2010-04-01
# 26     overall  united states  717142133  1339  2013-11-11
# 27     overall  united states  362348516   361  2010-04-02
# 28       games  united states  717142133   118  2013-10-17
# 29     overall        armenia  520777858    32  2012-05-16
# ..         ...            ...        ...   ...         ...
# 427    overall  united states  362348516   533  2010-07-12
# 428    overall  united states  362348516   526  2010-07-13
# 429  education  united states  717142133   215  2013-12-14
# 430      games        armenia  520777858  1100  2013-08-04
# 431  education  united states  717142133   208  2013-12-15
# 432    overall  united states  362348516   502  2010-07-14
# 433  education  united states  717142133   227  2013-12-16
# 434    overall  united states  281704574   157  2010-05-20
# 435    overall  united states  281704574   159  2010-05-21
# 436    overall  united states  362348516   524  2010-07-15
# 437      games        armenia  520777858  1085  2013-08-05
# 438  education  united states  717142133   232  2013-12-17
# 439    overall  united states  281704574   173  2010-05-22
# 440    overall  united states  362348516   489  2010-07-16
# 441    overall  united states  362348516   498  2010-07-17
# 442      games        armenia  520777858  1183  2013-08-06
# 443      games        armenia  520777858  1143  2013-08-07
# 444      games        armenia  520777858  1238  2013-08-08
# 445      games        armenia  520777858   976  2013-08-09
# 446    overall  united states  362348516   497  2010-07-18
# 447    overall  united states  281704574   174  2010-05-23
# 448  education  united states  717142133   237  2013-12-18
# 449    overall  united states  281704574   172  2010-05-24
# 450      games        armenia  520777858  1214  2013-08-10
# 451    overall  united states  362348516   553  2010-07-19
# 452  education  united states  717142133   252  2013-12-19
# 453      games        armenia  520777858   234  2013-08-20
# 454    overall  united states  362348516   545  2010-07-20
# 455      games        armenia  520777858   940  2013-08-21
# 456  education  united states  717142133   232  2013-12-20
#
# [457 rows x 5 columns]

# %%
df_debug_google
# Out:
#             category        country  \
# 0     live wallpaper  united states
# 1            overall  united states
# 2     live wallpaper  united states
# 3     live wallpaper  united states
# 4     live wallpaper  united states
# 5            overall  united states
# 6     live wallpaper  united states
# 7            overall  united states
# 8     live wallpaper  united states
# 9            overall  united states
# 10    live wallpaper  united states
# 11           overall  united states
# 12    live wallpaper  united states
# 13    live wallpaper  united states
# 14           overall  united states
# 15    live wallpaper  united states
# 16           overall  united states
# 17    live wallpaper  united states
# 18    live wallpaper  united states
# 19           overall  united states
# 20    live wallpaper  united states
# 21           overall  united states
# 22           overall  united states
# 23    live wallpaper  united states
# 24           overall  united states
# 25           overall      argentina
# 26    live wallpaper  united states
# 27           overall  united states
# 28           overall      argentina
# 29    live wallpaper  united states
# ..               ...            ...
# 513  personalization  united states
# 514            games  united states
# 515  personalization  united states
# 516          overall      argentina
# 517            games  united states
# 518            games  united states
# 519  personalization  united states
# 520  personalization  united states
# 521            games  united states
# 522          overall      argentina
# 523  personalization  united states
# 524            games      argentina
# 525          overall      argentina
# 526            games  united states
# 527          overall      argentina
# 528  personalization  united states
# 529            games      argentina
# 530            games  united states
# 531          overall      argentina
# 532  personalization  united states
# 533            games      argentina
# 534            games  united states
# 535          overall      argentina
# 536            games      argentina
# 537            games  united states
# 538          overall      argentina
# 539            games  united states
# 540          overall      argentina
# 541            games      argentina
# 542            games  united states
#
#                                                 app_id  rank        date
# 0                         com.gau.go.launcher.lwp.core   383  2014-04-02
# 1                       air.com.dpflashes.clearvision3   505  2014-02-01
# 2                         com.gau.go.launcher.lwp.core   167  2014-04-03
# 3                         com.gau.go.launcher.lwp.core   135  2014-04-04
# 4                         com.gau.go.launcher.lwp.core   135  2014-04-05
# 5                       air.com.dpflashes.clearvision3   468  2014-02-02
# 6                         com.gau.go.launcher.lwp.core    76  2014-04-06
# 7                       air.com.dpflashes.clearvision3   416  2014-02-03
# 8                         com.gau.go.launcher.lwp.core    60  2014-04-07
# 9                       air.com.dpflashes.clearvision3   375  2014-02-04
# 10                        com.gau.go.launcher.lwp.core    53  2014-04-08
# 11                      air.com.dpflashes.clearvision3   357  2014-02-05
# 12                        com.gau.go.launcher.lwp.core    48  2014-04-09
# 13                        com.gau.go.launcher.lwp.core    42  2014-04-10
# 14                      air.com.dpflashes.clearvision3   357  2014-02-06
# 15                        com.gau.go.launcher.lwp.core    38  2014-04-11
# 16                      air.com.dpflashes.clearvision3   303  2014-02-07
# 17                        com.gau.go.launcher.lwp.core    35  2014-04-12
# 18                        com.gau.go.launcher.lwp.core    32  2014-04-13
# 19                      air.com.dpflashes.clearvision3   278  2014-02-08
# 20                        com.gau.go.launcher.lwp.core    30  2014-04-14
# 21                      air.com.dpflashes.clearvision3   230  2014-02-09
# 22                      air.com.dpflashes.clearvision3   196  2014-02-10
# 23                        com.gau.go.launcher.lwp.core    30  2014-04-15
# 24                      air.com.dpflashes.clearvision3   168  2014-02-11
# 25   com.mobage.ww.a956.MARVEL_Card_Battle_Heroes_A...   493  2012-12-10
# 26                        com.gau.go.launcher.lwp.core    33  2014-04-16
# 27                      air.com.dpflashes.clearvision3   144  2014-02-12
# 28   com.mobage.ww.a956.MARVEL_Card_Battle_Heroes_A...   465  2012-12-11
# 29                        com.gau.go.launcher.lwp.core    33  2014-04-17
# ..                                                 ...   ...         ...
# 513                       com.gau.go.launcher.lwp.core   126  2014-05-22
# 514                     air.com.dpflashes.clearvision3   451  2014-05-05
# 515                       com.gau.go.launcher.lwp.core   131  2014-05-23
# 516                   com.azumio.instantheartrate.full   125  2012-04-28
# 517                     air.com.dpflashes.clearvision3   455  2014-05-06
# 518                     air.com.dpflashes.clearvision3   461  2014-05-07
# 519                       com.gau.go.launcher.lwp.core   135  2014-05-24
# 520                       com.gau.go.launcher.lwp.core   134  2014-05-25
# 521                     air.com.dpflashes.clearvision3   456  2014-05-08
# 522                   com.azumio.instantheartrate.full   131  2012-04-29
# 523                       com.gau.go.launcher.lwp.core   145  2014-05-26
# 524  com.mobage.ww.a956.MARVEL_Card_Battle_Heroes_A...   220  2013-01-20
# 525                   com.azumio.instantheartrate.full   133  2012-04-30
# 526                     air.com.dpflashes.clearvision3   454  2014-05-09
# 527                   com.azumio.instantheartrate.full   136  2012-05-01
# 528                       com.gau.go.launcher.lwp.core   142  2014-05-27
# 529  com.mobage.ww.a956.MARVEL_Card_Battle_Heroes_A...   206  2013-01-21
# 530                     air.com.dpflashes.clearvision3   455  2014-05-10
# 531                   com.azumio.instantheartrate.full   138  2012-05-02
# 532                       com.gau.go.launcher.lwp.core   141  2014-05-28
# 533  com.mobage.ww.a956.MARVEL_Card_Battle_Heroes_A...   191  2013-01-22
# 534                     air.com.dpflashes.clearvision3   460  2014-05-11
# 535                   com.azumio.instantheartrate.full   142  2012-05-03
# 536  com.mobage.ww.a956.MARVEL_Card_Battle_Heroes_A...   191  2013-01-23
# 537                     air.com.dpflashes.clearvision3   452  2014-05-12
# 538                   com.azumio.instantheartrate.full   142  2012-05-04
# 539                     air.com.dpflashes.clearvision3   456  2014-05-13
# 540                   com.azumio.instantheartrate.full   142  2012-05-05
# 541  com.mobage.ww.a956.MARVEL_Card_Battle_Heroes_A...   150  2013-01-24
# 542                     air.com.dpflashes.clearvision3   457  2014-05-14
#
# [543 rows x 5 columns]
